# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils_printable import printable



abbreviations = {"RAC1P": "RAC", "White alone": "White", "Reference person": "Ref person", \
"Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions": "Empl. for-profit-c",\
"Employee of a private not-for-profit, tax-exempt, or charitable organization": "Empl. no-profit-c",
"Self-employed in own not incorporated business, professional practice, or farm": "Self-Empl. not incorp" ,     
"Self-employed in own incorporated business, professional practice or farm": "Self-Empl. incorp" ,
"Local government employee (city, county, etc.)" : "Local gov. Empl. ",
"Federal government employee": "Federal gov.  Empl.",
"California/CA":"CA", "Never married or under 15 years old": "Never married/<15yrs", 
"Biological son or daughter": "Son/daughter", "Regular high school diploma":"HS", \
"Asian alone":"Asian", "1 or more years of college credit":"1+ collage cr",
"Some Other Race alone": "Other", "Bachelor's degree": "Bachelor", "Master's degree": "Master", 
                "Some college, but less than 1 year": "<1y collage",
                "Associate's degree":"Associate",
"Noninstitutionalized group quarters population": "Noninstit. GQs", 
"OCCP=CMM-Software Developers": "OCCP=CMM-SW Dev", 
                 "Professional degree beyond a bachelor's degree": "Prof beyond bachelor"}

# %%
def printable_with_ratio(df_pr, abbreviations = {}, show_weighted_ratio = False):
    out_cols = ["itemsets", "sup", "Δ_outcome", "t_outcome", "ratio"]
    df_pr["ratio"] = df_pr["outcome"]/mean_outcome
    if show_weighted_ratio:
        out_cols = out_cols + ["wlogr"]
    df_pr = printable(df_pr, abbreviations=abbreviations)
    return df_pr[out_cols]

# %% [markdown]
# # Load data

# %%
from folktables import ACSDataSource, ACSIncome

data_source = ACSDataSource(survey_year='2018', horizon='1-Year', survey='person')
acs_data = data_source.get_data(states=["CA"], download=True)
features, label, group = ACSIncome.df_to_numpy(acs_data)
# Out:
# Downloading data for 2018 1-Year person survey for CA...

# %%
from folktables.acs import adult_filter
from folktables import BasicProblem
import numpy as np

feature_names = [
        'AGEP',
        'COW',
        'SCHL',
        'MAR',
        'OCCP',
        'POBP',
        'RELP',
        'WKHP',
        'SEX',
        'RAC1P'
    ]

target='PINCP'

ACSIncome_outcome = BasicProblem(
    features=feature_names,
    target=target,
    #target_transform=lambda x: x > 50000,    
    group='RAC1P',
    preprocess=adult_filter,
    #postprocess=lambda x: np.nan_to_num(x, -1),
)

# %%
features, label, group = ACSIncome_outcome.df_to_numpy(acs_data)

# %%
continuous_attributes = ['AGEP', 'WKHP']

# %%
categorical_attributes = list(set(feature_names)-set(continuous_attributes))

# %%
import pandas as pd


df = pd.DataFrame(features, columns=feature_names)
df["income"] = label
df.head()
# Out:
#    AGEP  COW  SCHL  MAR    OCCP  POBP  RELP  WKHP  SEX  RAC1P   income
# 0  30.0  6.0  14.0  1.0  9610.0   6.0  16.0  40.0  1.0    8.0  48500.0
# 1  21.0  4.0  16.0  5.0  1970.0   6.0  17.0  20.0  1.0    1.0   7700.0
# 2  65.0  2.0  22.0  5.0  2040.0   6.0  17.0   8.0  1.0    1.0  17200.0
# 3  33.0  1.0  14.0  3.0  9610.0  36.0  16.0  40.0  1.0    1.0  12000.0
# 4  18.0  2.0  19.0  5.0  1021.0   6.0  17.0  18.0  2.0    1.0    300.0

# %% [markdown]
# # Remap columns

# %% [markdown]
# From label encoding to interpretable notation: e.g., 0, 1 to "male", "female"

# %%
import pandas as pd
import os
filename = os.path.join(os.path.curdir, "datasets", "ACSPUMS", "PUMS_Data_Dictionary_2018.csv")

# %%
df_mappings = pd.read_csv(filename)

# %%
remapping_cols = {}

# %%
orig_col = "1"
new_col = "Record Type"
cols_i = [orig_col, new_col]

#col_name = "OCCP"
for col_name in categorical_attributes:
    dict_i = df_mappings.loc["VAL"].loc[col_name][cols_i].set_index(orig_col).to_dict()[new_col]
    dict_i = {float(k) if (k not in ["b", "bb", 'bbb', 'bbbb']) else -1 :v for k,v in dict_i.items()}
    remapping_cols[col_name] = dict_i

# %%
from copy import deepcopy

df_renamed = deepcopy(df)

for column_name in remapping_cols:
    df_renamed[column_name] = df[column_name].replace(remapping_cols[column_name])

# %% [markdown]
# We substituite nan with string "NaN"

# %%
for c in df_renamed:
    if df_renamed[c].isna().any():
        print(c)
        df_renamed[c].fillna('NaN', inplace=True)

# %%
df_renamed.head()
# Out:
#    AGEP                                                COW  \
# 0  30.0  Self-employed in own not incorporated business...
# 1  21.0                          State government employee
# 2  65.0  Employee of a private not-for-profit, tax-exem...
# 3  33.0  Employee of a private for-profit company or bu...
# 4  18.0  Employee of a private not-for-profit, tax-exem...
#
#                                            SCHL  \
# 0                                      Grade 11
# 1                   Regular high school diploma
# 2                               Master's degree
# 3                                      Grade 11
# 4  1 or more years of college credit, no degree
#
#                                    MAR  \
# 0                              Married
# 1  Never married or under 15 years old
# 2  Never married or under 15 years old
# 3                             Divorced
# 4  Never married or under 15 years old
#
#                                                 OCCP           POBP  \
# 0             TRN-Cleaners Of Vehicles And Equipment  California/CA
# 1  SCI-Other Life, Physical, And Social Science T...  California/CA
# 2                                         CMS-Clergy  California/CA
# 3             TRN-Cleaners Of Vehicles And Equipment    New York/NY
# 4                            CMM-Software Developers  California/CA
#
#                                              RELP  WKHP     SEX  \
# 0     Institutionalized group quarters population  40.0    Male
# 1  Noninstitutionalized group quarters population  20.0    Male
# 2  Noninstitutionalized group quarters population   8.0    Male
# 3     Institutionalized group quarters population  40.0    Male
# 4  Noninstitutionalized group quarters population  18.0  Female
#
#                    RAC1P   income
# 0  Some Other Race alone  48500.0
# 1            White alone   7700.0
# 2            White alone  17200.0
# 3            White alone  12000.0
# 4            White alone    300.0

# %%
[i for i in df_renamed["OCCP"].unique() if "MGR" in i]
# Out:
# ['MGR-Lodging Managers',
#  'MGR-Food Service Managers',
#  'MGR-Social And Community Service Managers',
#  'MGR-Other Managers',
#  'MGR-Medical And Health Services Managers',
#  'MGR-Human Resources Managers',
#  'MGR-Sales Managers',
#  'MGR-Farmers, Ranchers, And Other Agricultural Managers',
#  'MGR-Education And Childcare Administrators',
#  'MGR-General And Operations Managers',
#  'MGR-Training And Development Managers',
#  'MGR-Chief Executives And Legislators',
#  'MGR-Property, Real Estate, And Community Association Managers',
#  'MGR-Marketing Managers',
#  'MGR-Industrial Production Managers',
#  'MGR-Construction Managers',
#  'MGR-Entertainment and Recreation Managers',
#  'MGR-Financial Managers',
#  'MGR-Computer And Information Systems Managers',
#  'MGR-Architectural And Engineering Managers',
#  'MGR-Purchasing Managers',
#  'MGR-Public Relations And Fundraising Managers',
#  'MGR-Advertising And Promotions Managers',
#  'MGR-Administrative Services Managers',
#  'MGR-Transportation, Storage, And Distribution Managers',
#  'MGR-Facilities Managers',
#  'MGR-Emergency Management Directors',
#  'MGR-Natural Sciences Managers',
#  'MGR-Compensation And Benefits Managers']

# %%
import pickle

with open(
    os.path.join(os.path.curdir, "datasets", "ACSPUMS", "census_column_mapping.pickle"),
    "wb",
) as fp:
    pickle.dump(remapping_cols, fp)

# %%
from copy import deepcopy

df_analysis = deepcopy(df_renamed)

# %%
df_analysis.to_csv(os.path.join(os.path.curdir, "datasets", "ACSPUMS", "adult_dataset_income.csv"), index=False)

# %%
continuous_attributes = ['AGEP', 'WKHP']

# %%
df_analysis.shape
# Out:
# (195665, 11)

# %% [markdown]
# # Taxonomy

# %%
df_analysis_proc = deepcopy(df_analysis)

# %% [markdown]
# ## Occupation

# %%
attr = "OCCP"
from copy import deepcopy

#generalization_dict_tax = deepcopy(generalization_dict)
generalization_dict_tax = {}
generalization_dict_tax[attr] = {x: x.split("-")[0] for x in df_analysis_proc[attr].values if "-" in x}

# %% [markdown]
# ## Mean of transport

# %%
attr = "JWTR"

if attr in df_analysis_proc.columns:
    print(df_analysis_proc[attr].value_counts()/len(df_analysis_proc))
    generalization_dict_tax[attr] =  {'Bicycle': 'Private Transportation', 
    'Car, truck, or van': 'Private Transportation', 
    'Bus or trolley bus': 'Public Transportation',
    'Railroad': 'Public Transportation',
    'Subway or elevated': 'Public Transportation',
    'Motorcycle': 'Private Transportation', 
    'Streetcar or trolley car (carro publico in Puerto Rico)': 'Public Transportation',
    'Ferryboat': 'Public Transportation'}

# %% [markdown]
# ## Working weeks

# %%
attr = "WKW"

if attr in df_analysis_proc.columns:
    print(df_analysis_proc[attr].value_counts())
    generalization_dict_tax[attr] =  {'14 to 26 weeks worked during past 12 months': '14 to 39 weeks worked during past 12 months',
    '27 to 39 weeks worked during past 12 months': '14 to 39 weeks worked during past 12 months',
    '40 to 47 weeks worked during past 12 months': '40 to 49 weeks worked during past 12 months',
    '48 to 49 weeks worked during past 12 months': '40 to 49 weeks worked during past 12 months'}

# %% [markdown]
# ## Arrival and departure time at work

# %%
def taxonomy_split_in_slot(values):
    def define_slot(x, v_slot):            
            if int(x)%v_slot == 0:
                slot_value= f"{x}-{x+v_slot}"
                if x == 24:
                    slot_value= f"{x}-{v_slot}"
            else:
                x = x-(int(x)%v_slot)
                slot_value= f"{x}-{x+v_slot}"
            return slot_value
        
    tax = {}

    for val in values:
        if val=="NaN":
            continue
        tmp = val.split(":")
        h = int(tmp[0])
        t = tmp[1].split(" ")[1]
        if h==12:
            if t == "a.m.":
                h = 0    
        else:
            if t=="p.m.":
                h = h+12
        hier1 = h

        tax[val] = str(hier1)

        hier2 = define_slot(h, 2)
        tax[str(hier1)] = hier2
        hier3 = define_slot(h, 4)
        tax[hier2] = hier3
    return tax

# %%
attr = "JWAP"

if attr in df_analysis_proc.columns:
    tax= taxonomy_split_in_slot(df_analysis_proc[attr].unique())

    generalization_dict_tax[attr] = tax

attr = "JWDP"
if attr in df_analysis_proc.columns:
    # We use the same
    generalization_dict_tax[attr] = deepcopy(tax)

# %% [markdown]
# ## Country

# %% [markdown]
# We rename some of the columns for vizualization and mapping reasons.

# %%
if "POBP" in df_analysis_proc.columns:
    df_analysis_proc["POBP"] = df_analysis_proc["POBP"]\
    .replace({"England":"United Kingdom", 'Scotland': "United Kingdom", \
              "United Kingdom, Not Specified": "United Kingdom",  'Northern Ireland': "United Kingdom",\
               "USSR": "Russia", "Hong Kong": "Hong Kong SAR",
             "Democratic Republic of Congo (Zaire)": 'Democratic Republic of the Congo',
             "Trinidad & Tobago": "Trinidad and Tobago", 'Macedonia':'North Macedonia',
             'Antigua & Barbuda': 'Antigua and Barbuda', \
              'Commonwealth of the Northern Mariana Islands':'Northern Mariana Islands',
             'St. Vincent & the Grenadines': 'St. Vincent and the Grenadines', \
              #simplification
             "Azores Islands": "Portugal"})

# %%
# https://statisticstimes.com/geography/countries-by-continents.php
df_taxonomy_country = pd.read_csv("country_hierarchies.csv", header=None, index_col=0)

df_taxonomy_country.columns=["Country or Area","ISO-alpha3 Code", "M49 Code", "Region 1", "Region 2", "Continent"]

df_taxonomy_country["Country or Area"] = df_taxonomy_country["Country or Area"].replace({
    "Viet Nam":"Vietnam", "Bolivia (Plurinational State of)": "Bolivia" ,\
      "Russian Federation": "Russia",'Iran (Islamic Republic of)': 'Iran', \
    "Lao People's Democratic Republic": "Laos", 'Syrian Arab Republic': "Syria", 
    'Venezuela (Bolivarian Republic of)': "Venezuela",
    "Republic of Moldova": "Moldova", "Czechia": "Czech Republic",
        'United Republic of Tanzania': "Tanzania", 'Côte d’Ivoire': "Ivory Coast",
        'United States Virgin Islands': 'US Virgin Islands', 'Saint Lucia': 'St. Lucia', 
    'Saint Kitts and Nevis': 'St. Kitts-Nevis',
    'Saint Vincent and the Grenadines': 'St. Vincent and the Grenadines',
    "United Kingdom of Great Britain and Northern Ireland" : "United Kingdom",\
    "China, Hong Kong Special Administrative Region" : "Hong Kong SAR"
})


g_hierarchy = {}
target_cols = ["Country or Area", "Region 1", "Continent"]
for i, row in df_taxonomy_country.iterrows():
    levels = [col for col in target_cols if pd.notnull(row[col])]
    
    for l in range(len(levels)-1):
        tax_c, tax_p = row[levels[l]], row[levels[l+1]]
        # If already exist but the value is different
        if "Korea" in tax_c:
            tax_c = "Korea"
        
        if tax_c in g_hierarchy and tax_p!=g_hierarchy[tax_c]:
            print(row)
            raise ValueError()
        if tax_c == tax_p:
            continue
        g_hierarchy[tax_c] = tax_p
attr = 'POBP'
#g_hierarchy = {}
g_hierarchy.update({"North America": "America", 
 "South America": "America", 
 "Americas, Not Specified" : "America", 
"Other Europe, Not Specified": "Europe",
"Eastern Africa, Not Specified": "Africa",
"Other Asia, Not Specified": "Asia",
"South Central Asia, Not Specified": "Asia",
"Caribbean, Not Specified": "North America",
"Other US Island Areas, Oceania, Not Specified, or at Sea": "Oceania",
"Other Africa, Not Specified": "Africa",
"Western Africa, Not Specified": "Africa",
                   "Taiwan" : 'Eastern Asia',
                   'Czechoslovakia':'Eastern Europe', 'Yugoslavia':'Southern Europe'})

# %%
generalization_dict_tax_u = deepcopy(g_hierarchy)
delete_values = []
for c, v in df_analysis_proc["POBP"].value_counts().items():
    if c not in g_hierarchy.keys():
        if "/" in c:
            g_hierarchy[c] = "United States of America"
        else:
            delete_values.append(c)

delete_values.append("North America")
delete_values.append("South America")
delete_values.append("Micronesia")

tot_deleted = 0
for c in delete_values:
    print(c, len(df_analysis_proc.loc[df_analysis_proc["POBP"]==c]))
    tot_deleted +=len(df_analysis_proc.loc[df_analysis_proc["POBP"]==c])
print(tot_deleted, round(tot_deleted/len(df_analysis_proc),5))
# Out:
# Asia 54
# Europe 23
# Africa 18
# West Indies 2
# North America 0
# South America 4
# Micronesia 8
# 109 0.00056

# %% [markdown]
# Delete rows for which the detailed information is not available

# %%
df_analysis_proc = df_analysis_proc.loc[df_analysis_proc["POBP"].isin(delete_values)==False]

# %%
df_analysis_proc.loc[df_analysis_proc["POBP"].isin(delete_values)]
# Out:
# Empty DataFrame
# Columns: [AGEP, COW, SCHL, MAR, OCCP, POBP, RELP, WKHP, SEX, RAC1P, income]
# Index: []

# %%
generalization_dict_tax[attr] = generalization_dict_tax_u

# %%
df_analysis_proc.to_csv(os.path.join(os.path.curdir, "datasets", "ACSPUMS", "adult_dataset_income_tax.csv"), index=False)

# %%
import json

with open(os.path.join(os.path.curdir, "datasets", "ACSPUMS", "adult_taxonomies.json"), "w") as fp:
    json.dump(generalization_dict_tax, fp)

# %% [markdown]
# # Tree divergence - income - individual

# %% [markdown]
# ## Tree

# %%
df_analysis.head()
# Out:
#    AGEP                                                COW  \
# 0  30.0  Self-employed in own not incorporated business...
# 1  21.0                          State government employee
# 2  65.0  Employee of a private not-for-profit, tax-exem...
# 3  33.0  Employee of a private for-profit company or bu...
# 4  18.0  Employee of a private not-for-profit, tax-exem...
#
#                                            SCHL  \
# 0                                      Grade 11
# 1                   Regular high school diploma
# 2                               Master's degree
# 3                                      Grade 11
# 4  1 or more years of college credit, no degree
#
#                                    MAR  \
# 0                              Married
# 1  Never married or under 15 years old
# 2  Never married or under 15 years old
# 3                             Divorced
# 4  Never married or under 15 years old
#
#                                                 OCCP           POBP  \
# 0             TRN-Cleaners Of Vehicles And Equipment  California/CA
# 1  SCI-Other Life, Physical, And Social Science T...  California/CA
# 2                                         CMS-Clergy  California/CA
# 3             TRN-Cleaners Of Vehicles And Equipment    New York/NY
# 4                            CMM-Software Developers  California/CA
#
#                                              RELP  WKHP     SEX  \
# 0     Institutionalized group quarters population  40.0    Male
# 1  Noninstitutionalized group quarters population  20.0    Male
# 2  Noninstitutionalized group quarters population   8.0    Male
# 3     Institutionalized group quarters population  40.0    Male
# 4  Noninstitutionalized group quarters population  18.0  Female
#
#                    RAC1P   income
# 0  Some Other Race alone  48500.0
# 1            White alone   7700.0
# 2            White alone  17200.0
# 3            White alone  12000.0
# 4            White alone    300.0

# %%
min_support = 0.1

# %%
metric = "d_outcome"


target = "income"

# %%
from tree_discretization_ranking import TreeDiscretization_ranking

tree_discr = TreeDiscretization_ranking()


type_experiment = "one_at_time"

type_criterion = "weighted_sum_abs_reference_s"


generalization_dict, discretizations = tree_discr.get_tree_discretization(
    df_analysis_proc,
    type_splitting=type_experiment,
    min_support=min_support,
    metric=metric,
    continuous_attributes= list(continuous_attributes),
    storeTree=True,
    type_criterion = type_criterion,
    minimal_gain = 0.0,
    target_col = target
)
tree_discr.printDiscretizationTrees()

dot = {}
for attribute in continuous_attributes:
    if attribute in tree_discr.trees:
        dot[attribute] = tree_discr.trees[attribute].visualizeTreeDiGraph()
# Out:
# AGEP
#  root s=1.00000 --> d_outcome=0.00000
#          AGEP<=34.0 s=0.34460 --> d_outcome=-27957.34967
#                  AGEP<=26.0 s=0.17023 --> d_outcome=-43902.74131
#                  AGEP>=27.0 s=0.17437 --> d_outcome=-12391.18714
#          AGEP>=35.0 s=0.65540 --> d_outcome=14699.71082
#                  AGEP<=45.0 s=0.21916 --> d_outcome=10075.43355
#                          AGEP<=39.0 s=0.10386 --> d_outcome=7208.71884
#                          AGEP>=40.0 s=0.11531 --> d_outcome=12657.49820
#                  AGEP>=46.0 s=0.43623 --> d_outcome=17022.96186
#                          AGEP<=62.0 s=0.33534 --> d_outcome=15339.48589
#                                  AGEP<=56.0 s=0.22497 --> d_outcome=15764.15092
#                                          AGEP<=51.0 s=0.12258 --> d_outcome=15071.81348
#                                          AGEP>=52.0 s=0.10239 --> d_outcome=16592.99880
#                                  AGEP>=57.0 s=0.11037 --> d_outcome=14473.90428
#                          AGEP>=63.0 s=0.10089 --> d_outcome=22618.45031
#
# WKHP
#  root s=1.00000 --> d_outcome=0.00000
#          WKHP<=39.0 s=0.30502 --> d_outcome=-33030.64925
#                  WKHP<=29.0 s=0.18462 --> d_outcome=-40394.30641
#                  WKHP>=30.0 s=0.12040 --> d_outcome=-21738.70744
#          WKHP>=40.0 s=0.69498 --> d_outcome=14496.66073
#                  WKHP<=43.0 s=0.47719 --> d_outcome=589.60246
#                  WKHP>=44.0 s=0.21779 --> d_outcome=44968.10624

# %%
generalization_dict
# Out:
# {'AGEP': {'<=26.0': '<=34.0',
#   '[27.0-34.0]': '<=34.0',
#   '[35.0-45.0]': '>=35.0',
#   '[35.0-39.0]': '[35.0-45.0]',
#   '[40.0-45.0]': '[35.0-45.0]',
#   '>=46.0': '>=35.0',
#   '[46.0-62.0]': '>=46.0',
#   '[46.0-56.0]': '[46.0-62.0]',
#   '[46.0-51.0]': '[46.0-56.0]',
#   '[52.0-56.0]': '[46.0-56.0]',
#   '[57.0-62.0]': '[46.0-62.0]',
#   '>=63.0': '>=46.0'},
#  'WKHP': {'<=29.0': '<=39.0',
#   '[30.0-39.0]': '<=39.0',
#   '[40.0-43.0]': '>=40.0',
#   '>=44.0': '>=40.0'}}

# %%
discretizations
# Out:
# {'AGEP': {'<=26.0': {'rels': ['<='], 'vals': [26.0]},
#   '[27.0-34.0]': {'rels': ['>=', '<='], 'vals': [27.0, 34.0]},
#   '[35.0-39.0]': {'rels': ['>=', '<='], 'vals': [35.0, 39.0]},
#   '[40.0-45.0]': {'rels': ['>=', '<='], 'vals': [40.0, 45.0]},
#   '[46.0-51.0]': {'rels': ['>=', '<='], 'vals': [46.0, 51.0]},
#   '[52.0-56.0]': {'rels': ['>=', '<='], 'vals': [52.0, 56.0]},
#   '[57.0-62.0]': {'rels': ['>=', '<='], 'vals': [57.0, 62.0]},
#   '>=63.0': {'rels': ['>='], 'vals': [63.0]}},
#  'WKHP': {'<=29.0': {'rels': ['<='], 'vals': [29.0]},
#   '[30.0-39.0]': {'rels': ['>=', '<='], 'vals': [30.0, 39.0]},
#   '[40.0-43.0]': {'rels': ['>=', '<='], 'vals': [40.0, 43.0]},
#   '>=44.0': {'rels': ['>='], 'vals': [44.0]}}}

# %%
FP_results = {"base": {}, "generalized": {}}

# %% [markdown]
# ## min_sup_divergence  = 0.05

# %%
generalization_dict_all = deepcopy(generalization_dict)
generalization_dict_all.update(generalization_dict_tax)

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
min_sup_divergence = 0.05

# %% [markdown]
# ### Without Generalization

# %%
import pandas as pd
pd.set_option('max_colwidth', None)

# %%
INFO = ['support', 'itemsets', 'tn', 'fp', 'fn', 'tp', 'd_fpr', 't_value_fp', 'error']

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = False

pattern_type = "generalized" if apply_generalization else "base"
    
FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    #true_class_name=pred_name,
    #predicted_class_name=class_name,
    target_name = target,
    #class_map=class_map,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    allow_overalp = False if type_experiment!="all_attributes" else True
)
# Out:
#                                                   RELP                  RAC1P  \
# 0          Institutionalized group quarters population  Some Other Race alone
# 1       Noninstitutionalized group quarters population            White alone
# 2       Noninstitutionalized group quarters population            White alone
# 3          Institutionalized group quarters population            White alone
# 4       Noninstitutionalized group quarters population            White alone
# ...                                                ...                    ...
# 195660                                Reference person            Asian alone
# 195661                                    Husband/wife            Asian alone
# 195662                                Reference person            White alone
# 195663                                Reference person            Asian alone
# 195664                                Reference person  Some Other Race alone
#
#                                                                                                                  COW  \
# 0                                     Self-employed in own not incorporated business, professional practice, or farm
# 1                                                                                          State government employee
# 2                                       Employee of a private not-for-profit, tax-exempt, or charitable organization
# 3       Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions
# 4                                       Employee of a private not-for-profit, tax-exempt, or charitable organization
# ...                                                                                                              ...
# 195660  Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions
# 195661  Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions
# 195662  Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions
# 195663                                     Self-employed in own incorporated business, professional practice or farm
# 195664  Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions
#
#                  POBP                                  MAR  \
# 0       California/CA                              Married
# 1       California/CA  Never married or under 15 years old
# 2       California/CA  Never married or under 15 years old
# 3         New York/NY                             Divorced
# 4       California/CA  Never married or under 15 years old
# ...               ...                                  ...
# 195660          India                              Married
# 195661          India                              Married
# 195662    Illinois/IL                              Married
# 195663          China                              Married
# 195664         Mexico                              Married
#
#                                                 SCHL  \
# 0                                           Grade 11
# 1                        Regular high school diploma
# 2                                    Master's degree
# 3                                           Grade 11
# 4       1 or more years of college credit, no degree
# ...                                              ...
# 195660                               Master's degree
# 195661                               Master's degree
# 195662  1 or more years of college credit, no degree
# 195663                              Doctorate degree
# 195664                 GED or alternative credential
#
#                                                             OCCP     SEX  \
# 0                         TRN-Cleaners Of Vehicles And Equipment    Male
# 1       SCI-Other Life, Physical, And Social Science Technicians    Male
# 2                                                     CMS-Clergy    Male
# 3                         TRN-Cleaners Of Vehicles And Equipment    Male
# 4                                        CMM-Software Developers  Female
# ...                                                          ...     ...
# 195660                                   CMM-Software Developers    Male
# 195661                                   CMM-Software Developers  Female
# 195662                      OFF-Customer Service Representatives    Male
# 195663                                                CMS-Clergy    Male
# 195664                TRN-Industrial Truck And Tractor Operators    Male
#
#                AGEP         WKHP    income
# 0       [27.0-34.0]  [40.0-43.0]   48500.0
# 1            <=26.0       <=29.0    7700.0
# 2            >=63.0       <=29.0   17200.0
# 3       [27.0-34.0]  [40.0-43.0]   12000.0
# 4            <=26.0       <=29.0     300.0
# ...             ...          ...       ...
# 195660  [35.0-39.0]  [40.0-43.0]  565280.0
# 195661  [35.0-39.0]  [40.0-43.0]  210000.0
# 195662  [57.0-62.0]       >=44.0  105000.0
# 195663       >=63.0       >=44.0   30000.0
# 195664  [40.0-45.0]  [40.0-43.0]   30000.0
#
# [195556 rows x 11 columns]

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 51   0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 113  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 6    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 38   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 51  -40394.306410       122.486801
# 113 -21738.707445        46.955137
# 6      589.602457         1.962819
# 38   44968.106236        72.224167

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#       support  \
# 528  0.051494
# 375  0.063741
# 524  0.051556
# 339  0.067244
# 374  0.063757
#
#                                                                                                                                                                      itemsets  \
# 528                                                                                                                            (WKHP=<=29.0, AGEP=<=26.0, POBP=California/CA)
# 375                                                                                                       (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old)
# 524                              (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 339                                                                                                                                                (WKHP=<=29.0, AGEP=<=26.0)
# 374  (WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
#
#      length  support_count       outcome     d_outcome  t_value_outcome
# 528       3        10070.0   7927.402582 -57257.667843       238.857644
# 375       3        12465.0   7990.126274 -57194.944151       249.298074
# 524       3        10082.0   8009.281293 -57175.789131       236.757609
# 339       2        13150.0   8166.591939 -57018.478486       246.626190
# 374       3        12468.0  10175.319538 -55009.750887       218.028712

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#       support  \
# 341  0.067035
# 468  0.054925
# 450  0.056797
# 541  0.050921
# 408  0.061266
#
#                                                                                                                                                             itemsets  \
# 341                                                                                                          (RAC1P=White alone, WKHP=>=44.0, MAR=Married, SEX=Male)
# 468                                                                                                      (MAR=Married, RELP=Reference person, WKHP=>=44.0, SEX=Male)
# 450  (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RAC1P=White alone, WKHP=>=44.0, MAR=Married)
# 541                                                                                             (RAC1P=White alone, RELP=Reference person, WKHP=>=44.0, MAR=Married)
# 408           (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0, MAR=Married, SEX=Male)
#
#      length  support_count        outcome     d_outcome  t_value_outcome
# 341       4        13109.0  146171.347471  80986.277046        62.329294
# 468       4        10741.0  144403.153710  79218.083285        55.266030
# 450       4        11107.0  144314.136130  79129.065706        56.418323
# 541       4         9958.0  143632.726853  78447.656428        53.882423
# 408       4        11981.0  141333.358651  76148.288226        56.490536

# %%
print(df_analysis["income"].describe()["mean"])
FP_fm.sort_values("length", ascending = True).head(1)
# Out:
# 65192.04881813304
#    support itemsets  length  support_count       outcome  d_outcome  \
# 0      1.0       ()       0       195556.0  65185.070425        0.0
#
#    t_value_outcome
# 0              0.0

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)
# Out:
# 3259.25, 65185.07

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                itemsets   sup  Δ_outcome  \
# 528                   AGEP=<=26.0, POBP=CA, WKHP=<=29.0  0.05 -57257.668
# 375  AGEP=<=26.0, MAR=Never married/<15yrs, WKHP=<=29.0  0.06 -57194.944
# 524    AGEP=<=26.0, COW=Empl. for-profit-c, WKHP=<=29.0  0.05 -57175.789
#
#      t_outcome  ratio
# 528      238.9  0.122
# 375      249.3  0.123
# 524      236.8  0.123

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                         itemsets   sup  \
# 341                MAR=Married, RAC=White, SEX=Male, WKHP=>=44.0  0.07
# 468          MAR=Married, RELP=Ref person, SEX=Male, WKHP=>=44.0  0.05
# 450  COW=Empl. for-profit-c, MAR=Married, RAC=White, WKHP=>=44.0  0.06
#
#      Δ_outcome  t_outcome  ratio
# 341  80986.277       62.3  2.242
# 468  79218.083       55.3  2.215
# 450  79129.066       56.4  2.214

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                                           itemsets   sup  \
# 339                                       AGEP=<=26.0, WKHP=<=29.0  0.07
# 374  COW=Empl. for-profit-c, MAR=Never married/<15yrs, WKHP=<=29.0  0.06
# 368                 MAR=Never married/<15yrs, POBP=CA, WKHP=<=29.0  0.06
#
#      Δ_outcome  t_outcome  ratio
# 339 -57018.478      246.6  0.125
# 374 -55009.751      218.0  0.156
# 368 -54666.190      202.6  0.161

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                                   itemsets   sup  Δ_outcome  t_outcome  ratio
# 339               AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 201  MAR=Never married/<15yrs, WKHP=<=29.0  0.09 -53376.975      206.4  0.181
# 255         AGEP=<=26.0, RELP=Son/daughter  0.08 -49170.757      191.6  0.246

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                                   itemsets   sup  Δ_outcome  t_outcome  ratio
# 339               AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 201  MAR=Never married/<15yrs, WKHP=<=29.0  0.09 -53376.975      206.4  0.181
# 145    COW=Empl. for-profit-c, WKHP=<=29.0  0.11 -46995.221      145.5  0.279

# %%
df_analysis_proc["POBP"]
# Out:
# 0         California/CA
# 1         California/CA
# 2         California/CA
# 3           New York/NY
# 4         California/CA
#               ...
# 195660            India
# 195661            India
# 195662      Illinois/IL
# 195663            China
# 195664           Mexico
# Name: POBP, Length: 195556, dtype: object

# %%
generalization_dict_all['POBP']["Afghanistan"].keys()
# Out:
# dict_keys(['Afghanistan', 'Southern Asia', 'Åland Islands', 'Northern Europe', 'Albania', 'Southern Europe', 'Algeria', 'Northern Africa', 'American Samoa', 'Polynesia', 'Andorra', 'Angola', 'Middle Africa', 'Anguilla', 'Caribbean', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Western Asia', 'Aruba', 'Australia', 'Australia and New Zealand', 'Austria', 'Western Europe', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Eastern Europe', 'Belgium', 'Belize', 'Central America', 'Benin', 'Western Africa', 'Bermuda', 'Northern America', 'Bhutan', 'Bolivia', 'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Botswana', 'Southern Africa', 'Bouvet Island', 'Brazil', 'British Indian Ocean Territory', 'Eastern Africa', 'British Virgin Islands', 'Brunei Darussalam', 'South-eastern Asia', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Eastern Asia', 'Hong Kong SAR', 'China, Macao Special Administrative Region', 'Christmas Island', 'Cocos (Keeling) Islands', 'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Ivory Coast', 'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic', 'Korea', 'Democratic Republic of the Congo', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Falkland Islands (Malvinas)', 'Faroe Islands', 'Fiji', 'Melanesia', 'Finland', 'France', 'French Guiana', 'French Polynesia', 'French Southern Territories', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guadeloupe', 'Guam', 'Micronesia', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Heard Island and McDonald Islands', 'Holy See', 'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Central Asia', 'Kenya', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius', 'Mayotte', 'Mexico', 'Micronesia (Federated States of)', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'Norfolk Island', 'North Macedonia', 'Northern Mariana Islands', 'Norway', 'Oman', 'Pakistan', 'Palau', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar', 'Moldova', 'Réunion', 'Romania', 'Russia', 'Rwanda', 'Saint Barthélemy', 'Saint Helena', 'St. Kitts-Nevis', 'St. Lucia', 'Saint Martin (French Part)', 'Saint Pierre and Miquelon', 'St. Vincent and the Grenadines', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Sark', 'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa', 'South Georgia and the South Sandwich Islands', 'South Sudan', 'Spain', 'Sri Lanka', 'State of Palestine', 'Sudan', 'Suriname', 'Svalbard and Jan Mayen Islands', 'Sweden', 'Switzerland', 'Syria', 'Tajikistan', 'Thailand', 'Timor-Leste', 'Togo', 'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'Tanzania', 'United States Minor Outlying Islands', 'United States of America', 'US Virgin Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam', 'Wallis and Futuna Islands', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe', 'North America', 'South America', 'Americas, Not Specified', 'Other Europe, ...

# %% [markdown]
# ### With Generalization

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = True
pattern_type = "generalized" if apply_generalization else "base"

import time 

st = time.time()

FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    target_name = target,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    considerOnlyContinuos = False,
    allow_overalp = False if type_experiment!="all_attributes" else True
)

print(time.time()-st)
# Out:
# 19.13944911956787

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
display(l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20))
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#        support  \
# 1910  0.051494
# 1301  0.063741
# 1902  0.051556
# 1168  0.067244
# 1554  0.057615
#
#                                                                                                                                           itemsets  \
# 1910                                                                                                (WKHP=<=29.0, AGEP=<=26.0, POBP=California/CA)
# 1301                                                                           (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old)
# 1902  (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 1168                                                                                                                    (WKHP=<=29.0, AGEP=<=26.0)
# 1554                                                       (WKHP=<=29.0, MAR=Never married or under 15 years old, POBP=California/CA, AGEP=<=34.0)
#
#       length  support_count      outcome     d_outcome  t_value_outcome
# 1910       3        10070.0  7927.402582 -57257.667843       238.857644
# 1301       3        12465.0  7990.126274 -57194.944151       249.298074
# 1902       3        10082.0  8009.281293 -57175.789131       236.757609
# 1168       2        13150.0  8166.591939 -57018.478486       246.626190
# 1554       4        11267.0  8883.009142 -56302.061283       228.174844

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#        support  \
# 1858  0.052082
# 1567  0.057298
# 1745  0.054296
# 1950  0.050983
# 1767  0.053729
#
#                                                                   itemsets  \
# 1858                                     (OCCP=MGR, AGEP=>=35.0, SEX=Male)
# 1567  (AGEP=>=35.0, MAR=Married, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1745                     (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR, MAR=Married)
# 1950               (AGEP=>=46.0, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1767                     (AGEP=>=46.0, MAR=Married, WKHP=>=44.0, SEX=Male)
#
#       length  support_count        outcome     d_outcome  t_value_outcome
# 1858       3        10185.0  155389.089838  90204.019413        60.614209
# 1567       5        11205.0  155344.132441  90159.062016        62.025598
# 1745       4        10618.0  155110.010360  89924.939935        64.128105
# 1950       4         9970.0  152503.482849  87318.412424        56.646643
# 1767       4        10507.0  150511.681165  85326.610740        56.369136

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWTR" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i and "JWAP=NaN" not in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.1
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

# %%
display(fpdiv.head(20))
# Out:
#        support  \
# 1910  0.051494
# 1301  0.063741
# 1902  0.051556
# 1168  0.067244
# 1554  0.057615
# 1591  0.056904
# 899   0.075845
# 1261  0.064713
# 1249  0.064989
# 1300  0.063757
# 676   0.088159
# 1690  0.054936
# 1120  0.068548
# 1946  0.051044
# 1080  0.069678
# 1281  0.064176
# 1542  0.057845
# 674   0.088277
# 1959  0.050860
# 997   0.072429
#
#                                                                                                                                                                                                        itemsets  \
# 1910                                                                                                                                                             (WKHP=<=29.0, AGEP=<=26.0, POBP=California/CA)
# 1301                                                                                                                                        (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old)
# 1902                                                               (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 1168                                                                                                                                                                                 (WKHP=<=29.0, AGEP=<=26.0)
# 1554                                                                                                                    (WKHP=<=29.0, MAR=Never married or under 15 years old, POBP=California/CA, AGEP=<=34.0)
# 1591                      (WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, AGEP=<=34.0)
# 899                                                                                                                                         (WKHP=<=29.0, MAR=Never married or under 15 years old, AGEP=<=34.0)
# 1261                                                                                                                                                             (WKHP=<=29.0, POBP=California/CA, AGEP=<=34.0)
# 1249                                                               (WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, AGEP=<=34.0)
# 1300                                   (WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 676                                                                                                                                                                                  (WKHP=<=29.0, AGEP=<=34.0)
# 1690  (POBP=California/CA, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, WKHP=<=39.0)
# 1120                                                                                                                    (WKHP=<=39.0, AGEP=<=26.0, MAR=Never married or under 15 years old, POBP=California/CA)
# 1946                                                                                                                                                                     (WKHP=<=29.0, SEX=Female, AGEP=<=34.0)
# 1080                      (AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, WKHP=<=39.0)
# 1281                                                                                                                                 (WKHP=<=29.0, MAR=Never married or under 15 years old, POBP=California/CA)
# 1542                                           (WKHP=<=39.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, POBP=California/CA)
# 674                                                                                                                                         (AGEP=<=26.0, MAR=Never married or under 15 years old, WKHP=<=39.0)
# 1959                                                                                                                                                              (WKHP=<=29.0, RAC1P=White alone, AGEP=<=34.0)
# 997                                                                                                                                                              (WKHP=<=39.0, AGEP=<=26.0, POBP=California/CA)
#
#       length  support_count       outcome     d_outcome  t_value_outcome
# 1910       3        10070.0   7927.402582 -57257.667843       238.857644
# 1301       3        12465.0   7990.126274 -57194.944151       249.298074
# 1902       3        10082.0   8009.281293 -57175.789131       236.757609
# 1168       2        13150.0   8166.591939 -57018.478486       246.626190
# 1554       4        11267.0   8883.009142 -56302.061283       228.174844
# 1591       4        11128.0   8887.360173 -56297.710252       232.799979
# 899        3        14832.0   9288.519013 -55896.551412       237.604617
# 1261       3        12655.0   9741.661320 -55443.409105       221.588755
# 1249       3        12709.0   9772.428515 -55412.641910       224.874556
# 1300       3        12468.0  10175.319538 -55009.750887       218.028712
# 676        2        17240.0  10338.782135 -54846.288290       227.314599
# 1690       5        10743.0  10360.651959 -54824.418465       218.803714
# 1120       4        13405.0  10399.008131 -54786.062294       227.767525
# 1946       3         9982.0  10488.123021 -54696.947403       201.329016
# 1080       4        13626.0  10504.799207 -54680.271217       227.398456
# 1281       3        12550.0  10518.880000 -54666.190425       202.567461
# 1542       4        11312.0  10556.325495 -54628.744930       220.970176
# 674        3        17263.0  10606.334009 -54578.736416       233.388755
# 1959       3         9946.0  10616.644279 -54568.426146       198.702415
# 997        3        14164.0  10643.271957 -54541.798468       229.263622

# %%
fpdiv_t.head(20)
# Out:
#        support  \
# 1168  0.067244
# 676   0.088159
# 601   0.094413
# 653   0.089739
# 1172  0.067060
# 285   0.135935
# 264   0.139034
# 468   0.108097
# 1642  0.055871
# 174   0.170227
# 1295  0.063895
# 1839  0.052369
# 996   0.072481
# 963   0.073575
# 1008  0.072117
# 144   0.184622
# 301   0.131625
# 142   0.185323
# 979   0.072961
# 1543  0.057845
#
#                                                                                                                              itemsets  \
# 1168                                                                                                       (WKHP=<=29.0, AGEP=<=26.0)
# 676                                                                                                        (WKHP=<=29.0, AGEP=<=34.0)
# 601                                                                                                        (AGEP=<=26.0, WKHP=<=39.0)
# 653                                                                            (WKHP=<=29.0, MAR=Never married or under 15 years old)
# 1172                                                                                   (RELP=Biological son or daughter, WKHP=<=39.0)
# 285                                                                                                        (WKHP=<=39.0, AGEP=<=34.0)
# 264                                                                            (MAR=Never married or under 15 years old, WKHP=<=39.0)
# 468   (WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 1642                                                                                  (SCHL=Regular high school diploma, WKHP=<=39.0)
# 174                                                                                                                     (AGEP=<=26.0)
# 1295                                                                 (WKHP=<=39.0, SCHL=1 or more years of college credit, no degree)
# 1839                                                                                                                       (OCCP=EAT)
# 996                                                                                   (SCHL=Regular high school diploma, AGEP=<=34.0)
# 963                                                                  (AGEP=<=34.0, SCHL=1 or more years of college credit, no degree)
# 1008                                                      (SCHL=Regular high school diploma, MAR=Never married or under 15 years old)
# 144                                                                                                                     (WKHP=<=29.0)
# 301                                                                                                 (RELP=Biological son or daughter)
# 142   (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=<=39.0)
# 979                                      (MAR=Never married or under 15 years old, SCHL=1 or more years of college credit, no degree)
# 1543                                                                                               (SEX=Female, POBP=Central America)
#
#       length  support_count       outcome     d_outcome  t_value_outcome
# 1168       2        13150.0   8166.591939 -57018.478486       246.626190
# 676        2        17240.0  10338.782135 -54846.288290       227.314599
# 601        2        18463.0  10956.889671 -54228.180754       230.807747
# 653        2        17549.0  11808.095846 -53376.974579       206.363504
# 1172       2        13114.0  12223.590819 -52961.479606       222.591009
# 285        2        26583.0  15309.197382 -49875.873043       203.613355
# 264        2        27189.0  17282.848358 -47902.222067       179.669410
# 468        2        21139.0  18189.849283 -46995.221142       145.456512
# 1642       2        10926.0  19104.645799 -46080.424626       120.157673
# 174        1        33289.0  21282.329118 -43902.741307       173.810730
# 1295       2        12495.0  21845.780232 -43339.290193       115.929856
# 1839       1        10241.0  21855.516063 -43329.554362       120.649128
# 996        2        14174.0  23746.763793 -41438.306632       130.380790
# 963        2        14388.0  24651.312483 -40533.757942       128.074362
# 1008       2        14103.0  24651.345813 -40533.724612       126.774310
# 144        1        36104.0  24790.764015 -40394.306410       122.486801
# 301        1        25740.0  24809.083139 -40375.987286       149.754476
# 142        2        36241.0  25248.227532 -39936.842892       131.694853
# 979        2        14268.0  26909.392627 -38275.677798       106.913707
# 1543       2        11312.0  28561.565594 -36623.504831       104.952729

# %%
display(fpdiv.tail(10))
fpdiv_t.tail(10)
# Out:
#        support  \
# 1372  0.061962
# 1900  0.051602
# 1812  0.052967
# 1734  0.054399
# 1895  0.051668
# 1767  0.053729
# 1950  0.050983
# 1745  0.054296
# 1567  0.057298
# 1858  0.052082
#
#                                                                                                                                                                  itemsets  \
# 1372                                                                                                                                 (WKHP=>=40.0, OCCP=MGR, MAR=Married)
# 1900                            (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, AGEP=>=35.0, OCCP=MGR)
# 1812                                                                                                              (RAC1P=White alone, AGEP=>=35.0, OCCP=MGR, WKHP=>=40.0)
# 1734                                                                                                           (AGEP=>=46.0, RAC1P=White alone, WKHP=>=44.0, MAR=Married)
# 1895  (AGEP=>=35.0, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0, SEX=Male)
# 1767                                                                                                                    (AGEP=>=46.0, MAR=Married, WKHP=>=44.0, SEX=Male)
# 1950                                                                                                              (AGEP=>=46.0, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1745                                                                                                                    (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR, MAR=Married)
# 1567                                                                                                 (AGEP=>=35.0, MAR=Married, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1858                                                                                                                                    (OCCP=MGR, AGEP=>=35.0, SEX=Male)
#
#       length  support_count        outcome     d_outcome  t_value_outcome
# 1372       3        12117.0  147351.839564  82166.769139        64.148109
# 1900       3        10091.0  147725.923100  82540.852675        57.753015
# 1812       4        10358.0  149646.473257  84461.402833        61.203329
# 1734       4        10638.0  149774.836811  84589.766387        57.585040
# 1895       5        10104.0  149883.079968  84698.009543        55.774965
# 1767       4        10507.0  150511.681165  85326.610740        56.369136
# 1950       4         9970.0  152503.482849  87318.412424        56.646643
# 1745       4        10618.0  155110.010360  89924.939935        64.128105
# 1567       5        11205.0  155344.132441  90159.062016        62.025598
# 1858       3        10185.0  155389.089838  90204.019413        60.614209
#        support  \
# 1173  0.067035
# 1371  0.061992
# 1372  0.061962
# 1900  0.051602
# 1734  0.054399
# 1767  0.053729
# 1950  0.050983
# 1745  0.054296
# 1567  0.057298
# 1858  0.052082
#
#                                                                                                                                        itemsets  \
# 1173                                                                                    (RAC1P=White alone, WKHP=>=44.0, MAR=Married, SEX=Male)
# 1371                                                                                                       (OCCP=MGR, AGEP=>=35.0, MAR=Married)
# 1372                                                                                                       (WKHP=>=40.0, OCCP=MGR, MAR=Married)
# 1900  (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, AGEP=>=35.0, OCCP=MGR)
# 1734                                                                                 (AGEP=>=46.0, RAC1P=White alone, WKHP=>=44.0, MAR=Married)
# 1767                                                                                          (AGEP=>=46.0, MAR=Married, WKHP=>=44.0, SEX=Male)
# 1950                                                                                    (AGEP=>=46.0, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1745                                                                                          (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR, MAR=Married)
# 1567                                                                       (AGEP=>=35.0, MAR=Married, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1858                                                                                                          (OCCP=MGR, AGEP=>=35.0, SEX=Male)
#
#       length  support_count        outcome     d_outcome  t_value_outcome
# 1173       4        13109.0  146171.347471  80986.277046        62.329294
# 1371       3        12123.0  147197.202838  82012.132413        62.387184
# 1372       3        12117.0  147351.839564  82166.769139        64.148109
# 1900       3        10091.0  147725.923100  82540.852675        57.753015
# 1734       4        10638.0  149774.836811  84589.766387        57.585040
# 1767       4        10507.0  150511.681165  85326.610740        56.369136
# 1950       4         9970.0  152503.482849  87318.412424        56.646643
# 1745       4        10618.0  155110.010360  89924.939935        64.128105
# 1567       5        11205.0  155344.132441  90159.062016        62.025598
# 1858       3        10185.0  155389.089838  90204.019413        60.614209

# %% [markdown]
# #### Analysis

# %%
# FP_fm.loc[FP_fm["length"] == 1].loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "POBP" in i ])>0)].sort_values(metric, ascending = True)

FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = True)
# Out:
#        support  \
# 1839  0.052369
# 1553  0.057666
# 1060  0.070205
# 1718  0.054573
# 1701  0.054803
# 1256  0.064861
# 822   0.080064
# 856   0.077543
# 1992  0.050272
# 430   0.112280
# 1142  0.067950
# 1336  0.062928
# 1877  0.051888
# 1801  0.053090
# 1831  0.052558
# 1888  0.051714
# 1696  0.054900
# 875   0.076617
# 1086  0.069556
# 1424  0.060561
# 826   0.079798
# 1928  0.051325
# 555   0.099900
# 1937  0.051182
# 1259  0.064733
# 1532  0.058178
# 1495  0.058771
# 1850  0.052179
# 467   0.108204
# 906   0.075600
# 1119  0.068558
# 612   0.093492
# 1309  0.063567
# 721   0.085674
# 1364  0.062166
# 1245  0.065122
# 1661  0.055478
# 1043  0.070660
# 1319  0.063399
# 1770  0.053703
# 1407  0.061190
# 1563  0.057406
# 934   0.074598
# 1371  0.061992
# 1592  0.056894
# 1372  0.061962
# 1900  0.051602
# 1812  0.052967
# 1745  0.054296
# 1858  0.052082
#
#                                                                                                                                              itemsets  \
# 1839                                                                                                                                       (OCCP=EAT)
# 1553                     (OCCP=TRN, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 1060                                                                                                                                       (OCCP=TRN)
# 1718         (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=OFF, SEX=Female)
# 1701                                                                                                                             (OCCP=TRN, SEX=Male)
# 1256                                                                                                                   (OCCP=OFF, POBP=California/CA)
# 822                                                                                                                            (OCCP=OFF, SEX=Female)
# 856                      (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=OFF)
# 1992                                                                                                                           (SEX=Female, OCCP=SAL)
# 430                                                                                                                                        (OCCP=OFF)
# 1142                                                                                                                    (RAC1P=White alone, OCCP=OFF)
# 1336                                                                                                                     (WKHP=[40.0-43.0], OCCP=OFF)
# 1877                                                                                                              (AGEP=>=35.0, OCCP=OFF, SEX=Female)
# 1801                                                                                                              (WKHP=>=40.0, OCCP=OFF, SEX=Female)
# 1831        (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=OFF, WKHP=>=40.0)
# 1888                                                                                                                          (OCCP=OFF, MAR=Married)
# 1696                                                                                                                   (POBP=California/CA, OCCP=SAL)
# 875                                                                                                                           (WKHP=>=40.0, OCCP=OFF)
# 1086                                                                                                                          (AGEP=>=35.0, OCCP=OFF)
# 1424                                                                                                                                       (OCCP=EDU)
# 826                      (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=SAL)
# 1928                                                                                                             (WKHP=>=40.0, AGEP=>=35.0, OCCP=OFF)
# 555                                                                                                                                        (OCCP=SAL)
# 1937  (RAC1P=White alone, OCCP=SAL, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 1259                                                                                                                    (RAC1P=White alone, OCCP=SAL)
# 1532                                                                                                                          (AGEP=>=35.0, OCCP=SAL)
# 1495                                                                                                                          (WKHP=>=40.0, OCCP=SAL)
# 1850                                                                                                                                       (OCCP=MED)
# 467                                                                                                                                        (OCCP=MGR)
# 906                                                                                                                     (RAC1P=White alone, OCCP=MGR)
# 1119                     (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=MGR)
# 612                                                                                                                           (WKHP=>=40.0, OCCP=MGR)
# 1309                                                                                                                (OCCP=MGR, RELP=Reference person)
# 721                                                                                                                           (OCCP=MGR, AGEP=>=35.0)
# 1364        (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=MGR, WKHP=>=40.0)
# 1245                                                                                                       (RAC1P=White alone, OCCP=MGR, WKHP=>=40.0)
# 1661                                                                                                   (WKHP=>=40.0, RELP=Reference person, OCCP=MGR)
# 1043                                                                                                                          (OCCP=MGR, MAR=Married)
# 1319                                                                                                                             (OCCP=MGR, SEX=Male)
# 1770                                                                                                   (OCCP=MGR, AGEP=>=35.0, RELP=Reference person)
# 1407                                                                                                       (RAC1P=White alone, AGEP=>=35.0, OCCP=MGR)
# 1563                                                                                                                          (AGEP=>=46.0, OCCP=MGR)
# 934                                                                                                              (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR)
# 1371                                                                                                             (OCCP=MGR, AGEP=>=35.0, MAR=Married)
# 1592                                                                                                                (WKHP=>=40.0, OCCP=MGR, SEX=Male)
# 1372                                                                                                             (WKHP=>=40.0, OCCP=MGR, MAR=Married)
# 1900        (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, AGEP=>=35.0, OCCP=MGR)
# 1812                                                                                          (RAC1P=White alone, AGEP=>=35.0, OCCP=MGR, WKHP=>=40.0)
# 1745                                                                                                (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR, MAR=Married)
# 1858                                                                                                                (OCCP=MGR, AGEP=>=35.0, SEX=Male)
#
#       length  support_count        outcome     d_outcome  t_value_outcome
# 1839       1        10241.0   21855.516063 -43329.554362       120.649128
# 1553       2        11277.0   34750.778576 -30434.291849        73.110690
# 1060       1        13729.0   36495.081943 -28689.988482        70.796573
# 1718       3        10672.0   38881.453336 -26303.617089        61.293815
# 1701       2        10717.0   39517.908930 -25667.161495        55.189505
# 1256       2        12684.0   39574.504888 -25610.565537        60.309615
# 822        2        15657.0   40632.856869 -24552.213556        65.848044
# 856        2        15164.0   40674.680823 -24510.389602        59.144009
# 1992       2         9831.0   42517.137626 -22667.932799        32.115795
# 430        1        21957.0   42589.386073 -22595.684352        62.883211
# 1142       2        13288.0   44170.638922 -21014.431503        45.367552
# 1336       2        12306.0   47732.033155 -17453.037270        43.345844
# 1877       3        10147.0   48291.007194 -16894.063231        35.445655
# 1801       3        10382.0   48879.792911 -16305.277514        37.599705
# 1831       3        10278.0   49943.012259 -15242.058166        29.885822
# 1888       2        10113.0   50750.180955 -14434.889470        26.437100
# 1696       2        10736.0   50904.335879 -14280.734546        18.237285
# 875        2        14983.0   51508.795301 -13676.275123        32.396638
# 1086       2        13602.0   52189.528011 -12995.542414        27.345352
# 1424       1        11843.0   54642.202482 -10542.867942        19.204417
# 826        2        15605.0   54935.430311 -10249.640114        14.409245
# 1928       3        10037.0   58908.450732  -6276.619693        11.474149
# 555        1        19536.0   59503.754607  -5681.315818         8.353871
# 1937       3        10009.0   64062.385853  -1122.684572         1.145706
# 1259       2        12659.0   69418.063828   4232.993403         4.574090
# 1532       2        11377.0   82029.066538  16843.996113        16.465054
# 1495       2        11493.0   83877.535891  18692.465467        19.008161
# 1850       1        10204.0  103688.624069  38503.553644        33.800872
# 467        1        21160.0  121922.835539  56737.765114        63.198308
# 906        2        14784.0  128480.103490  63295.033065        56.952827
# 1119       2        13407.0  128721.809502  63536.739078        54.572407
# 612        2        18283.0  130170.054696  64984.984271        67.217785
# 1309       2        12431.0  132557.251227  67372.180802        56.023502
# 721        2        16754.0  135939.809598  70754.739173        66.863246
# 1364       3        12157.0  136135.414987  70950.344562        57.812642
# 1245       3        12735.0  136604.674519  71419.604094        59.732667
# 1661       3        10849.0  139225.741543  74040.671118        57.767871
# 1043       2        13818.0  139590.401650  74405.331225        61.989538
# 1319       2        12398.0  141752.798839  76567.728414        58.873202
# 1770       3        10502.0  141872.045325  76686.974900        56.646486
# 1407       3        11966.0  141993.524152  76808.453727        59.595621
# 1563       2        11226.0  142563.348477  77378.278052        57.550155
# 934        3        14588.0  143578.596792  78393.526367        69.204062
# 1371       3        12123.0  147197.202838  82012.132413        62.387184
# 1592       3        11126.0  147223.875607  82038.805182        60.119450
# 1372       3        12117.0  147351.839564  82166.769139        64.148109
# 1900       3        10091.0  147725.923100  82540.852675        57.753015
# 1812       4        10358.0  149646.473257  84461.402833        61.203329
# 1745       4        10618.0  155110.010360  89924.939935        64.128105
# 1858       3        10185.0  155389.089838  90204.019413        60.614209

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence

fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=0)
# Out:
#        support  \
# 1858  0.052082
# 1567  0.057298
# 1745  0.054296
# 1950  0.050983
# 1767  0.053729
# ...        ...
# 1554  0.057615
# 1168  0.067244
# 1902  0.051556
# 1301  0.063741
# 1910  0.051494
#
#                                                                                                                                           itemsets  \
# 1858                                                                                                             (OCCP=MGR, AGEP=>=35.0, SEX=Male)
# 1567                                                                          (AGEP=>=35.0, MAR=Married, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1745                                                                                             (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR, MAR=Married)
# 1950                                                                                       (AGEP=>=46.0, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1767                                                                                             (AGEP=>=46.0, MAR=Married, WKHP=>=44.0, SEX=Male)
# ...                                                                                                                                            ...
# 1554                                                       (WKHP=<=29.0, MAR=Never married or under 15 years old, POBP=California/CA, AGEP=<=34.0)
# 1168                                                                                                                    (WKHP=<=29.0, AGEP=<=26.0)
# 1902  (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 1301                                                                           (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old)
# 1910                                                                                                (WKHP=<=29.0, AGEP=<=26.0, POBP=California/CA)
#
#       length  support_count        outcome     d_outcome  t_value_outcome
# 1858       3        10185.0  155389.089838  90204.019413        60.614209
# 1567       5        11205.0  155344.132441  90159.062016        62.025598
# 1745       4        10618.0  155110.010360  89924.939935        64.128105
# 1950       4         9970.0  152503.482849  87318.412424        56.646643
# 1767       4        10507.0  150511.681165  85326.610740        56.369136
# ...      ...            ...            ...           ...              ...
# 1554       4        11267.0    8883.009142 -56302.061283       228.174844
# 1168       2        13150.0    8166.591939 -57018.478486       246.626190
# 1902       3        10082.0    8009.281293 -57175.789131       236.757609
# 1301       3        12465.0    7990.126274 -57194.944151       249.298074
# 1910       3        10070.0    7927.402582 -57257.667843       238.857644
#
# [1940 rows x 7 columns]

# %%
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]

v = mean_outcome*0.1

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
print(v)
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=v)
# Out:
# 6518.507042483994
#        support  \
# 1858  0.052082
# 1567  0.057298
# 1745  0.054296
# 1950  0.050983
# 1767  0.053729
# ...        ...
# 1172  0.067060
# 653   0.089739
# 601   0.094413
# 676   0.088159
# 1168  0.067244
#
#                                                                   itemsets  \
# 1858                                     (OCCP=MGR, AGEP=>=35.0, SEX=Male)
# 1567  (AGEP=>=35.0, MAR=Married, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1745                     (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR, MAR=Married)
# 1950               (AGEP=>=46.0, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1767                     (AGEP=>=46.0, MAR=Married, WKHP=>=44.0, SEX=Male)
# ...                                                                    ...
# 1172                        (RELP=Biological son or daughter, WKHP=<=39.0)
# 653                 (WKHP=<=29.0, MAR=Never married or under 15 years old)
# 601                                             (AGEP=<=26.0, WKHP=<=39.0)
# 676                                             (WKHP=<=29.0, AGEP=<=34.0)
# 1168                                            (WKHP=<=29.0, AGEP=<=26.0)
#
#       length  support_count        outcome     d_outcome  t_value_outcome
# 1858       3        10185.0  155389.089838  90204.019413        60.614209
# 1567       5        11205.0  155344.132441  90159.062016        62.025598
# 1745       4        10618.0  155110.010360  89924.939935        64.128105
# 1950       4         9970.0  152503.482849  87318.412424        56.646643
# 1767       4        10507.0  150511.681165  85326.610740        56.369136
# ...      ...            ...            ...           ...              ...
# 1172       2        13114.0   12223.590819 -52961.479606       222.591009
# 653        2        17549.0   11808.095846 -53376.974579       206.363504
# 601        2        18463.0   10956.889671 -54228.180754       230.807747
# 676        2        17240.0   10338.782135 -54846.288290       227.314599
# 1168       2        13150.0    8166.591939 -57018.478486       246.626190
#
# [499 rows x 7 columns]

# %%
f = fp_divergence_o.getDivergence(th_redundancy=v)

f.loc[f["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = False)
# Out:
#        support  \
# 1858  0.052082
# 1745  0.054296
# 1900  0.051602
# 1372  0.061962
# 1371  0.061992
# 934   0.074598
# 1563  0.057406
# 1319  0.063399
# 1043  0.070660
# 1661  0.055478
# 721   0.085674
# 1309  0.063567
# 612   0.093492
# 1119  0.068558
# 906   0.075600
# 467   0.108204
# 1850  0.052179
# 1928  0.051325
# 1424  0.060561
# 1086  0.069556
# 875   0.076617
# 1888  0.051714
# 430   0.112280
# 1992  0.050272
# 1060  0.070205
# 1839  0.052369
#
#                                                                                                                                        itemsets  \
# 1858                                                                                                          (OCCP=MGR, AGEP=>=35.0, SEX=Male)
# 1745                                                                                          (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR, MAR=Married)
# 1900  (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, AGEP=>=35.0, OCCP=MGR)
# 1372                                                                                                       (WKHP=>=40.0, OCCP=MGR, MAR=Married)
# 1371                                                                                                       (OCCP=MGR, AGEP=>=35.0, MAR=Married)
# 934                                                                                                        (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR)
# 1563                                                                                                                    (AGEP=>=46.0, OCCP=MGR)
# 1319                                                                                                                       (OCCP=MGR, SEX=Male)
# 1043                                                                                                                    (OCCP=MGR, MAR=Married)
# 1661                                                                                             (WKHP=>=40.0, RELP=Reference person, OCCP=MGR)
# 721                                                                                                                     (OCCP=MGR, AGEP=>=35.0)
# 1309                                                                                                          (OCCP=MGR, RELP=Reference person)
# 612                                                                                                                     (WKHP=>=40.0, OCCP=MGR)
# 1119               (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=MGR)
# 906                                                                                                               (RAC1P=White alone, OCCP=MGR)
# 467                                                                                                                                  (OCCP=MGR)
# 1850                                                                                                                                 (OCCP=MED)
# 1928                                                                                                       (WKHP=>=40.0, AGEP=>=35.0, OCCP=OFF)
# 1424                                                                                                                                 (OCCP=EDU)
# 1086                                                                                                                    (AGEP=>=35.0, OCCP=OFF)
# 875                                                                                                                     (WKHP=>=40.0, OCCP=OFF)
# 1888                                                                                                                    (OCCP=OFF, MAR=Married)
# 430                                                                                                                                  (OCCP=OFF)
# 1992                                                                                                                     (SEX=Female, OCCP=SAL)
# 1060                                                                                                                                 (OCCP=TRN)
# 1839                                                                                                                                 (OCCP=EAT)
#
#       length  support_count        outcome     d_outcome  t_value_outcome
# 1858       3        10185.0  155389.089838  90204.019413        60.614209
# 1745       4        10618.0  155110.010360  89924.939935        64.128105
# 1900       3        10091.0  147725.923100  82540.852675        57.753015
# 1372       3        12117.0  147351.839564  82166.769139        64.148109
# 1371       3        12123.0  147197.202838  82012.132413        62.387184
# 934        3        14588.0  143578.596792  78393.526367        69.204062
# 1563       2        11226.0  142563.348477  77378.278052        57.550155
# 1319       2        12398.0  141752.798839  76567.728414        58.873202
# 1043       2        13818.0  139590.401650  74405.331225        61.989538
# 1661       3        10849.0  139225.741543  74040.671118        57.767871
# 721        2        16754.0  135939.809598  70754.739173        66.863246
# 1309       2        12431.0  132557.251227  67372.180802        56.023502
# 612        2        18283.0  130170.054696  64984.984271        67.217785
# 1119       2        13407.0  128721.809502  63536.739078        54.572407
# 906        2        14784.0  128480.103490  63295.033065        56.952827
# 467        1        21160.0  121922.835539  56737.765114        63.198308
# 1850       1        10204.0  103688.624069  38503.553644        33.800872
# 1928       3        10037.0   58908.450732  -6276.619693        11.474149
# 1424       1        11843.0   54642.202482 -10542.867942        19.204417
# 1086       2        13602.0   52189.528011 -12995.542414        27.345352
# 875        2        14983.0   51508.795301 -13676.275123        32.396638
# 1888       2        10113.0   50750.180955 -14434.889470        26.437100
# 430        1        21957.0   42589.386073 -22595.684352        62.883211
# 1992       2         9831.0   42517.137626 -22667.932799        32.115795
# 1060       1        13729.0   36495.081943 -28689.988482        70.796573
# 1839       1        10241.0   21855.516063 -43329.554362       120.649128

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                 itemsets   sup  Δ_outcome  \
# 1910                   AGEP=<=26.0, POBP=CA, WKHP=<=29.0  0.05 -57257.668
# 1301  AGEP=<=26.0, MAR=Never married/<15yrs, WKHP=<=29.0  0.06 -57194.944
# 1902    AGEP=<=26.0, COW=Empl. for-profit-c, WKHP=<=29.0  0.05 -57175.789
#
#       t_outcome  ratio
# 1910      238.9  0.122
# 1301      249.3  0.123
# 1902      236.8  0.123

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                         itemsets   sup  \
# 1858                             AGEP=>=35.0, OCCP=MGR, SEX=Male  0.05
# 1567  AGEP=>=35.0, MAR=Married, RAC=White, SEX=Male, WKHP=>=44.0  0.06
# 1745             AGEP=>=35.0, MAR=Married, OCCP=MGR, WKHP=>=40.0  0.05
#
#       Δ_outcome  t_outcome  ratio
# 1858  90204.019       60.6  2.384
# 1567  90159.062       62.0  2.383
# 1745  89924.940       64.1  2.380

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                                            itemsets   sup  \
# 1168                                       AGEP=<=26.0, WKHP=<=29.0  0.07
# 899              AGEP=<=34.0, MAR=Never married/<15yrs, WKHP=<=29.0  0.08
# 1300  COW=Empl. for-profit-c, MAR=Never married/<15yrs, WKHP=<=29.0  0.06
#
#       Δ_outcome  t_outcome  ratio
# 1168 -57018.478      246.6  0.125
# 899  -55896.551      237.6  0.142
# 1300 -55009.751      218.0  0.156

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                       itemsets   sup  Δ_outcome  t_outcome  ratio
# 1168  AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 676   AGEP=<=34.0, WKHP=<=29.0  0.09 -54846.288      227.3  0.159
# 601   AGEP=<=26.0, WKHP=<=39.0  0.09 -54228.181      230.8  0.168

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                       itemsets   sup  Δ_outcome  t_outcome  ratio
# 1168  AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 676   AGEP=<=34.0, WKHP=<=29.0  0.09 -54846.288      227.3  0.159
# 601   AGEP=<=26.0, WKHP=<=39.0  0.09 -54228.181      230.8  0.168

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167

# %% [markdown]
# ## min_sup_divergence  = 0.025

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
min_sup_divergence = 0.025

# %% [markdown]
# ### Without Generalization

# %%
import pandas as pd
pd.set_option('max_colwidth', None)

# %%
INFO = ['support', 'itemsets', 'tn', 'fp', 'fn', 'tp', 'd_fpr', 't_value_fp', 'error']

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = False

pattern_type = "generalized" if apply_generalization else "base"
    
FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    #true_class_name=pred_name,
    #predicted_class_name=class_name,
    target_name = target,
    #class_map=class_map,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    allow_overalp = False if type_experiment!="all_attributes" else True
)

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 51   0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 113  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 6    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 38   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 51  -40394.306410       122.486801
# 113 -21738.707445        46.955137
# 6      589.602457         1.962819
# 38   44968.106236        72.224167

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#        support  \
# 1276  0.028948
# 1244  0.029470
# 937   0.035524
# 915   0.036179
# 1214  0.029920
#
#                                                                                                                                                                                                                     itemsets  \
# 1276  (AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 1244                                           (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Biological son or daughter)
# 937                                                                                                                     (WKHP=<=29.0, AGEP=<=26.0, RELP=Biological son or daughter, MAR=Never married or under 15 years old)
# 915                                                                                                                                                              (WKHP=<=29.0, AGEP=<=26.0, RELP=Biological son or daughter)
# 1214                                                                                                (POBP=California/CA, AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, MAR=Never married or under 15 years old)
#
#       length  support_count      outcome     d_outcome  t_value_outcome
# 1276       5         5661.0  7339.512454 -57845.557971       243.867037
# 1244       4         5763.0  7354.799584 -57830.270841       244.629639
# 937        4         6947.0  7395.747805 -57789.322620       241.063771
# 915        3         7075.0  7409.028975 -57776.041450       242.071604
# 1214       5         5851.0  7428.044779 -57757.025646       229.182128

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#        support  \
# 1285  0.028790
# 1300  0.028580
# 1425  0.027015
# 998   0.034318
# 1208  0.029997
#
#                                                                                                                                                 itemsets  \
# 1285                                                                                               (SCHL=Professional degree beyond a bachelor's degree)
# 1300  (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SCHL=Master's degree, SEX=Male)
# 1425                                                                               (SCHL=Bachelor's degree, RAC1P=White alone, WKHP=>=44.0, MAR=Married)
# 998                                                                                                        (MAR=Married, SCHL=Master's degree, SEX=Male)
# 1208                                                                                                                 (SCHL=Master's degree, WKHP=>=44.0)
#
#       length  support_count        outcome      d_outcome  t_value_outcome
# 1285       1         5630.0  170441.813499  105256.743074        46.671452
# 1300       3         5589.0  161340.767579   96155.697154        50.093060
# 1425       4         5283.0  158178.654174   92993.583749        46.210936
# 998        3         6711.0  157121.586947   91936.516522        52.763516
# 1208       2         5866.0  156834.481759   91649.411334        48.885913

# %%
print(df_analysis["income"].describe()["mean"])
FP_fm.sort_values("length", ascending = True).head(1)
# Out:
# 65192.04881813304
#    support itemsets  length  support_count       outcome  d_outcome  \
# 0      1.0       ()       0       195556.0  65185.070425        0.0
#
#    t_value_outcome
# 0              0.0

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)
# Out:
# 3259.25, 65185.07

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                                            itemsets  \
# 1276  AGEP=<=26.0, COW=Empl. for-profit-c, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 1244                            AGEP=<=26.0, COW=Empl. for-profit-c, RELP=Son/daughter, WKHP=<=29.0
# 937                           AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
#
#        sup  Δ_outcome  t_outcome  ratio
# 1276  0.03 -57845.558      243.9  0.113
# 1244  0.03 -57830.271      244.6  0.113
# 937   0.04 -57789.323      241.1  0.113

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                 itemsets   sup   Δ_outcome  \
# 1285                           SCHL=Prof beyond bachelor  0.03  105256.743
# 1300       COW=Empl. for-profit-c, SCHL=Master, SEX=Male  0.03   96155.697
# 1425  MAR=Married, RAC=White, SCHL=Bachelor, WKHP=>=44.0  0.03   92993.584
#
#       t_outcome  ratio
# 1285       46.7  2.615
# 1300       50.1  2.475
# 1425       46.2  2.427

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                         itemsets   sup  Δ_outcome  t_outcome  \
# 915  AGEP=<=26.0, RELP=Son/daughter, WKHP=<=29.0  0.04 -57776.041      242.1
# 339                     AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6
# 625               RELP=Son/daughter, WKHP=<=29.0  0.05 -56262.320      229.4
#
#      ratio
# 915  0.114
# 339  0.125
# 625  0.137

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                                   itemsets   sup  Δ_outcome  t_outcome  ratio
# 339               AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 625         RELP=Son/daughter, WKHP=<=29.0  0.05 -56262.320      229.4  0.137
# 201  MAR=Never married/<15yrs, WKHP=<=29.0  0.09 -53376.975      206.4  0.181

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                                   itemsets   sup  Δ_outcome  t_outcome  ratio
# 339               AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 625         RELP=Son/daughter, WKHP=<=29.0  0.05 -56262.320      229.4  0.137
# 201  MAR=Never married/<15yrs, WKHP=<=29.0  0.09 -53376.975      206.4  0.181

# %%
l = FP_results["base"][0.025].loc[FP_results["base"][0.025]["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 51   0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 113  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 6    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 38   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 51  -40394.306410       122.486801
# 113 -21738.707445        46.955137
# 6      589.602457         1.962819
# 38   44968.106236        72.224167

# %% [markdown]
# ### With Generalization

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = True
pattern_type = "generalized" if apply_generalization else "base"

import time 

st = time.time()

FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    target_name = target,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    considerOnlyContinuos = False,
    allow_overalp = False if type_experiment!="all_attributes" else True
)

print(time.time()-st)
# Out:
# 24.775001764297485

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
display(l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20))
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#        support  \
# 5206  0.028948
# 5037  0.029470
# 3680  0.035524
# 3573  0.036179
# 4934  0.029920
#
#                                                                                                                                                                                                                     itemsets  \
# 5206  (AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 5037                                           (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Biological son or daughter)
# 3680                                                                                                                    (WKHP=<=29.0, AGEP=<=26.0, RELP=Biological son or daughter, MAR=Never married or under 15 years old)
# 3573                                                                                                                                                             (WKHP=<=29.0, AGEP=<=26.0, RELP=Biological son or daughter)
# 4934                                                                                                (POBP=California/CA, AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, MAR=Never married or under 15 years old)
#
#       length  support_count      outcome     d_outcome  t_value_outcome
# 5206       5         5661.0  7339.512454 -57845.557971       243.867037
# 5037       4         5763.0  7354.799584 -57830.270841       244.629639
# 3680       4         6947.0  7395.747805 -57789.322620       241.063771
# 3573       3         7075.0  7409.028975 -57776.041450       242.071604
# 4934       5         5851.0  7428.044779 -57757.025646       229.182128

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#        support  \
# 6602  0.025047
# 5850  0.027026
# 6447  0.025445
# 6015  0.026576
# 6612  0.025006
#
#                                                                                                                                                               itemsets  \
# 6602                                                                                                                    (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, SEX=Male)
# 5850                                                                                                                 (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, MAR=Married)
# 6447  (AGEP=>=35.0, OCCP=MGR, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SEX=Male)
# 6015                                                                                    (AGEP=>=35.0, RAC1P=White alone, WKHP=>=40.0, MAR=Married, OCCP=MGR, SEX=Male)
# 6612                                                                                                       (AGEP=>=46.0, WKHP=>=40.0, MAR=Married, OCCP=MGR, SEX=Male)
#
#       length  support_count        outcome      d_outcome  t_value_outcome
# 6602       4         4898.0  184525.279706  119340.209281        50.568105
# 5850       4         5285.0  184364.491958  119179.421534        53.300735
# 6447       5         4976.0  180937.019695  115751.949270        50.479892
# 6015       6         5197.0  178260.681162  113075.610737        51.016658
# 6612       5         4890.0  177898.789366  112713.718941        49.193370

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWTR" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i and "JWAP=NaN" not in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.1
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

# %%
display(fpdiv.head(20))
# Out:
#        support  \
# 5206  0.028948
# 5037  0.029470
# 3680  0.035524
# 3573  0.036179
# 4934  0.029920
# 4790  0.030436
# 5955  0.026744
# 5711  0.027368
# 5211  0.028928
# 3209  0.038521
# 3733  0.035202
# 2059  0.049341
# 2083  0.048963
# 2986  0.040132
# 5284  0.028693
# 5855  0.027020
# 1908  0.051494
# 4368  0.032252
# 5561  0.027813
# 1301  0.063741
#
#                                                                                                                                                                                                                                         itemsets  \
# 5206                      (AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 5037                                                               (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Biological son or daughter)
# 3680                                                                                                                                        (WKHP=<=29.0, AGEP=<=26.0, RELP=Biological son or daughter, MAR=Never married or under 15 years old)
# 3573                                                                                                                                                                                 (WKHP=<=29.0, AGEP=<=26.0, RELP=Biological son or daughter)
# 4934                                                                                                                    (POBP=California/CA, AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 4790                                                                                                                                                             (WKHP=<=29.0, AGEP=<=26.0, RELP=Biological son or daughter, POBP=California/CA)
# 5955                                           (SEX=Female, AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 5711                                                                                                                                         (SEX=Female, POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 5211                                                                                                                                                                                  (WKHP=<=29.0, AGEP=<=26.0, POBP=California/CA, SEX=Female)
# 3209                                   (POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 3733                                                                                                                                                             (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old, SEX=Female)
# 2059                                                                                                                                                     (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old, POBP=California/CA)
# 2083                                                       (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 2986                                                                            (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, POBP=California/CA)
# 5284                                                                                    (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SEX=Female)
# 5855  (POBP=California/CA, RELP=Biological son or daughter, AGEP=<=34.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 1908                                                                                                                                                                                              (WKHP=<=29.0, AGEP=<=26.0, POBP=California/CA)
# 4368                      (RELP=Biological son or daughter, AGEP=<=34.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 5561                                           (POBP=California/CA, RELP=Biological son or daughter, AGEP=<=34.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 1301                                                                                                                                                                         (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old)
#
#       length  support_count      outcome     d_outcome  t_value_outcome
# 5206       5         5661.0  7339.512454 -57845.557971       243.867037
# 5037       4         5763.0  7354.799584 -57830.270841       244.629639
# 3680       4         6947.0  7395.747805 -57789.322620       241.063771
# 3573       3         7075.0  7409.028975 -57776.041450       242.071604
# 4934       5         5851.0  7428.044779 -57757.025646       229.182128
# 4790       4         5952.0  7436.009745 -57749.060680       230.331100
# 5955       5         5230.0  7653.497897 -57531.572528       227.213969
# 5711       5         5352.0  7677.936099 -57507.134326       224.490326
# 5211       4         5657.0  7784.469507 -57400.600918       227.831734
# 3209       5         7533.0  7796.327360 -57388.743065       226.157503
# 3733       4         6884.0  7814.056363 -57371.014062       236.594879
# 2059       4         9649.0  7826.775210 -57358.295215       236.822905
# 2083       4         9575.0  7856.097546 -57328.972879       240.812293
# 2986       4         7848.0  7874.502294 -57310.568131       228.724032
# 5284       4         5611.0  7886.324006 -57298.746418       214.317191
# 5855       6         5284.0  7911.459122 -57273.611303       228.905351
# 1908       3        10070.0  7927.402582 -57257.667843       238.857644
# 4368       5         6307.0  7968.029174 -57217.041251       233.142369
# 5561       5         5439.0  7988.168781 -57196.901644       229.927237
# 1301       3        12465.0  7990.126274 -57194.944151       249.298074

# %%
fpdiv_t.head(20)
# Out:
#        support  \
# 1168  0.067244
# 2322  0.045915
# 676   0.088159
# 601   0.094413
# 653   0.089739
# 1172  0.067060
# 4037  0.033648
# 4090  0.033433
# 285   0.135935
# 2812  0.041497
# 264   0.139034
# 468   0.108097
# 3927  0.034179
# 1642  0.055871
# 5655  0.027537
# 3805  0.034762
# 174   0.170227
# 1295  0.063895
# 1839  0.052369
# 3416  0.037058
#
#                                                                                                                              itemsets  \
# 1168                                                                                                       (WKHP=<=29.0, AGEP=<=26.0)
# 2322                                                                                   (WKHP=<=29.0, RELP=Biological son or daughter)
# 676                                                                                                        (WKHP=<=29.0, AGEP=<=34.0)
# 601                                                                                                        (AGEP=<=26.0, WKHP=<=39.0)
# 653                                                                            (WKHP=<=29.0, MAR=Never married or under 15 years old)
# 1172                                                                                   (RELP=Biological son or daughter, WKHP=<=39.0)
# 4037                                                                                  (WKHP=<=29.0, SCHL=Regular high school diploma)
# 4090                                                                                                          (OCCP=EAT, WKHP=<=39.0)
# 285                                                                                                        (WKHP=<=39.0, AGEP=<=34.0)
# 2812                                                                 (WKHP=<=29.0, SCHL=1 or more years of college credit, no degree)
# 264                                                                            (MAR=Never married or under 15 years old, WKHP=<=39.0)
# 468   (WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 3927                                                                                       (RAC1P=Some Other Race alone, WKHP=<=39.0)
# 1642                                                                                  (SCHL=Regular high school diploma, WKHP=<=39.0)
# 5655                                                                                                       (POBP=Mexico, WKHP=<=39.0)
# 3805                                                                                              (WKHP=<=39.0, POBP=Central America)
# 174                                                                                                                     (AGEP=<=26.0)
# 1295                                                                 (WKHP=<=39.0, SCHL=1 or more years of college credit, no degree)
# 1839                                                                                                                       (OCCP=EAT)
# 3416                                                                                                (POBP=North America, WKHP=<=39.0)
#
#       length  support_count       outcome     d_outcome  t_value_outcome
# 1168       2        13150.0   8166.591939 -57018.478486       246.626190
# 2322       2         8979.0   8922.750863 -56262.319562       229.360368
# 676        2        17240.0  10338.782135 -54846.288290       227.314599
# 601        2        18463.0  10956.889671 -54228.180754       230.807747
# 653        2        17549.0  11808.095846 -53376.974579       206.363504
# 1172       2        13114.0  12223.590819 -52961.479606       222.591009
# 4037       2         6580.0  14767.244681 -50417.825744       118.237561
# 4090       2         6538.0  15102.535944 -50082.534481       147.027199
# 285        2        26583.0  15309.197382 -49875.873043       203.613355
# 2812       2         8115.0  16970.069501 -48215.000924       112.994316
# 264        2        27189.0  17282.848358 -47902.222067       179.669410
# 468        2        21139.0  18189.849283 -46995.221142       145.456512
# 3927       2         6684.0  18212.353381 -46972.717044       118.724154
# 1642       2        10926.0  19104.645799 -46080.424626       120.157673
# 5655       2         5385.0  19877.829155 -45307.241270       105.203092
# 3805       2         6798.0  19929.824949 -45255.245476       118.233925
# 174        1        33289.0  21282.329118 -43902.741307       173.810730
# 1295       2        12495.0  21845.780232 -43339.290193       115.929856
# 1839       1        10241.0  21855.516063 -43329.554362       120.649128
# 3416       2         7247.0  21958.272389 -43226.798036        87.802148

# %%
display(fpdiv.tail(10))
fpdiv_t.tail(10)
# Out:
#        support  \
# 6441  0.025466
# 5579  0.027767
# 5647  0.027552
# 5079  0.029362
# 4793  0.030426
# 6612  0.025006
# 6015  0.026576
# 6447  0.025445
# 5850  0.027026
# 6602  0.025047
#
#                                                                                                                                                               itemsets  \
# 6441                                                                                             (AGEP=>=35.0, RELP=Reference person, MAR=Married, OCCP=MGR, SEX=Male)
# 5579                                                                                                           (RAC1P=White alone, AGEP=>=35.0, WKHP=>=44.0, OCCP=MGR)
# 5647  (OCCP=MGR, WKHP=>=40.0, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SEX=Male)
# 5079                                                                                                 (AGEP=>=35.0, RAC1P=White alone, MAR=Married, OCCP=MGR, SEX=Male)
# 4793                                                                                                                              (OCCP=MGR, WKHP=>=44.0, MAR=Married)
# 6612                                                                                                       (AGEP=>=46.0, WKHP=>=40.0, MAR=Married, OCCP=MGR, SEX=Male)
# 6015                                                                                    (AGEP=>=35.0, RAC1P=White alone, WKHP=>=40.0, MAR=Married, OCCP=MGR, SEX=Male)
# 6447  (AGEP=>=35.0, OCCP=MGR, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SEX=Male)
# 5850                                                                                                                 (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, MAR=Married)
# 6602                                                                                                                    (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, SEX=Male)
#
#       length  support_count        outcome      d_outcome  t_value_outcome
# 6441       5         4980.0  173191.901606  108006.831182        47.601240
# 5579       4         5430.0  174526.918969  109341.848544        51.739930
# 5647       5         5388.0  174558.158872  109373.088447        50.964568
# 5079       5         5742.0  174718.685127  109533.614702        51.353075
# 4793       3         5950.0  176303.536134  111118.465710        53.874208
# 6612       5         4890.0  177898.789366  112713.718941        49.193370
# 6015       6         5197.0  178260.681162  113075.610737        51.016658
# 6447       5         4976.0  180937.019695  115751.949270        50.479892
# 5850       4         5285.0  184364.491958  119179.421534        53.300735
# 6602       4         4898.0  184525.279706  119340.209281        50.568105
#        support  \
# 3539  0.036353
# 5894  0.026918
# 4987  0.029685
# 5248  0.028810
# 6308  0.025783
# 5432  0.028176
# 4793  0.030426
# 6447  0.025445
# 5850  0.027026
# 6602  0.025047
#
#                                                                                                                                                               itemsets  \
# 3539                                                                                                                              (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0)
# 5894                                                                                                              (AGEP=>=46.0, RAC1P=White alone, OCCP=MGR, SEX=Male)
# 4987                                                                                                                                 (OCCP=MGR, WKHP=>=44.0, SEX=Male)
# 5248               (MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=MGR, SEX=Male)
# 6308                                                                                           (AGEP=>=35.0, WKHP=>=40.0, SCHL=Master's degree, MAR=Married, SEX=Male)
# 5432                                                                                                                    (AGEP=>=46.0, OCCP=MGR, MAR=Married, SEX=Male)
# 4793                                                                                                                              (OCCP=MGR, WKHP=>=44.0, MAR=Married)
# 6447  (AGEP=>=35.0, OCCP=MGR, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SEX=Male)
# 5850                                                                                                                 (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, MAR=Married)
# 6602                                                                                                                    (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, SEX=Male)
#
#       length  support_count        outcome      d_outcome  t_value_outcome
# 3539       3         7109.0  170701.136587  105516.066163        57.916484
# 5894       4         5264.0  170963.860182  105778.789758        47.744936
# 4987       3         5805.0  171542.440999  106357.370574        50.680086
# 5248       4         5634.0  172163.954562  106978.884137        50.679673
# 6308       5         5042.0  172959.617215  107774.546791        51.674119
# 5432       4         5510.0  173003.283122  107818.212697        49.522467
# 4793       3         5950.0  176303.536134  111118.465710        53.874208
# 6447       5         4976.0  180937.019695  115751.949270        50.479892
# 5850       4         5285.0  184364.491958  119179.421534        53.300735
# 6602       4         4898.0  184525.279706  119340.209281        50.568105

# %% [markdown]
# #### Analysis

# %%
# FP_fm.loc[FP_fm["length"] == 1].loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "POBP" in i ])>0)].sort_values(metric, ascending = True)

FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = True)
# Out:
#        support  \
# 5626  0.027619
# 6230  0.025987
# 4832  0.030283
# 4090  0.033433
# 6287  0.025839
# ...        ...
# 6612  0.025006
# 6015  0.026576
# 6447  0.025445
# 5850  0.027026
# 6602  0.025047
#
#                                                                                                                                                                                 itemsets  \
# 5626                                                                                                                    (OCCP=EAT, MAR=Never married or under 15 years old, AGEP=<=34.0)
# 6230  (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=EAT, MAR=Never married or under 15 years old, AGEP=<=34.0)
# 4832                                           (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=EAT, WKHP=<=39.0)
# 4090                                                                                                                                                             (OCCP=EAT, WKHP=<=39.0)
# 6287                                                                                                                                                             (AGEP=<=26.0, OCCP=SAL)
# ...                                                                                                                                                                                  ...
# 6612                                                                                                                         (AGEP=>=46.0, WKHP=>=40.0, MAR=Married, OCCP=MGR, SEX=Male)
# 6015                                                                                                      (AGEP=>=35.0, RAC1P=White alone, WKHP=>=40.0, MAR=Married, OCCP=MGR, SEX=Male)
# 6447                    (AGEP=>=35.0, OCCP=MGR, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SEX=Male)
# 5850                                                                                                                                   (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, MAR=Married)
# 6602                                                                                                                                      (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, SEX=Male)
#
#       length  support_count        outcome      d_outcome  t_value_outcome
# 5626       3         5401.0   14708.446584  -50476.623841       165.667236
# 6230       4         5082.0   14749.008264  -50436.062160       161.774657
# 4832       3         5922.0   14939.034110  -50246.036315       148.312365
# 4090       2         6538.0   15102.535944  -50082.534481       147.027199
# 6287       2         5053.0   15682.841876  -49502.228549       115.474898
# ...      ...            ...            ...            ...              ...
# 6612       5         4890.0  177898.789366  112713.718941        49.193370
# 6015       6         5197.0  178260.681162  113075.610737        51.016658
# 6447       5         4976.0  180937.019695  115751.949270        50.479892
# 5850       4         5285.0  184364.491958  119179.421534        53.300735
# 6602       4         4898.0  184525.279706  119340.209281        50.568105
#
# [455 rows x 7 columns]

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence

fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=0)
# Out:
#        support  \
# 6602  0.025047
# 5850  0.027026
# 6447  0.025445
# 6015  0.026576
# 6612  0.025006
# ...        ...
# 4934  0.029920
# 3573  0.036179
# 3680  0.035524
# 5037  0.029470
# 5206  0.028948
#
#                                                                                                                                                                                                                     itemsets  \
# 6602                                                                                                                                                                          (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, SEX=Male)
# 5850                                                                                                                                                                       (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, MAR=Married)
# 6447                                                        (AGEP=>=35.0, OCCP=MGR, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SEX=Male)
# 6015                                                                                                                                          (AGEP=>=35.0, RAC1P=White alone, WKHP=>=40.0, MAR=Married, OCCP=MGR, SEX=Male)
# 6612                                                                                                                                                             (AGEP=>=46.0, WKHP=>=40.0, MAR=Married, OCCP=MGR, SEX=Male)
# ...                                                                                                                                                                                                                      ...
# 4934                                                                                                (POBP=California/CA, AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 3573                                                                                                                                                             (WKHP=<=29.0, AGEP=<=26.0, RELP=Biological son or daughter)
# 3680                                                                                                                    (WKHP=<=29.0, AGEP=<=26.0, RELP=Biological son or daughter, MAR=Never married or under 15 years old)
# 5037                                           (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Biological son or daughter)
# 5206  (AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
#
#       length  support_count        outcome      d_outcome  t_value_outcome
# 6602       4         4898.0  184525.279706  119340.209281        50.568105
# 5850       4         5285.0  184364.491958  119179.421534        53.300735
# 6447       5         4976.0  180937.019695  115751.949270        50.479892
# 6015       6         5197.0  178260.681162  113075.610737        51.016658
# 6612       5         4890.0  177898.789366  112713.718941        49.193370
# ...      ...            ...            ...            ...              ...
# 4934       5         5851.0    7428.044779  -57757.025646       229.182128
# 3573       3         7075.0    7409.028975  -57776.041450       242.071604
# 3680       4         6947.0    7395.747805  -57789.322620       241.063771
# 5037       4         5763.0    7354.799584  -57830.270841       244.629639
# 5206       5         5661.0    7339.512454  -57845.557971       243.867037
#
# [6359 rows x 7 columns]

# %%
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]

v = mean_outcome*0.1

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
print(v)
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=v)
# Out:
# 6518.507042483994
#        support  \
# 6602  0.025047
# 5850  0.027026
# 6447  0.025445
# 4793  0.030426
# 5432  0.028176
# ...        ...
# 653   0.089739
# 601   0.094413
# 676   0.088159
# 2322  0.045915
# 1168  0.067244
#
#                                                                                                                                                               itemsets  \
# 6602                                                                                                                    (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, SEX=Male)
# 5850                                                                                                                 (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, MAR=Married)
# 6447  (AGEP=>=35.0, OCCP=MGR, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SEX=Male)
# 4793                                                                                                                              (OCCP=MGR, WKHP=>=44.0, MAR=Married)
# 5432                                                                                                                    (AGEP=>=46.0, OCCP=MGR, MAR=Married, SEX=Male)
# ...                                                                                                                                                                ...
# 653                                                                                                             (WKHP=<=29.0, MAR=Never married or under 15 years old)
# 601                                                                                                                                         (AGEP=<=26.0, WKHP=<=39.0)
# 676                                                                                                                                         (WKHP=<=29.0, AGEP=<=34.0)
# 2322                                                                                                                    (WKHP=<=29.0, RELP=Biological son or daughter)
# 1168                                                                                                                                        (WKHP=<=29.0, AGEP=<=26.0)
#
#       length  support_count        outcome      d_outcome  t_value_outcome
# 6602       4         4898.0  184525.279706  119340.209281        50.568105
# 5850       4         5285.0  184364.491958  119179.421534        53.300735
# 6447       5         4976.0  180937.019695  115751.949270        50.479892
# 4793       3         5950.0  176303.536134  111118.465710        53.874208
# 5432       4         5510.0  173003.283122  107818.212697        49.522467
# ...      ...            ...            ...            ...              ...
# 653        2        17549.0   11808.095846  -53376.974579       206.363504
# 601        2        18463.0   10956.889671  -54228.180754       230.807747
# 676        2        17240.0   10338.782135  -54846.288290       227.314599
# 2322       2         8979.0    8922.750863  -56262.319562       229.360368
# 1168       2        13150.0    8166.591939  -57018.478486       246.626190
#
# [1247 rows x 7 columns]

# %%
f = fp_divergence_o.getDivergence(th_redundancy=v)

f.loc[f["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = False)
# Out:
#        support  \
# 6602  0.025047
# 5850  0.027026
# 6447  0.025445
# 4793  0.030426
# 5432  0.028176
# ...        ...
# 5142  0.029163
# 3655  0.035662
# 5767  0.027225
# 1839  0.052369
# 4090  0.033433
#
#                                                                                                                                                               itemsets  \
# 6602                                                                                                                    (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, SEX=Male)
# 5850                                                                                                                 (OCCP=MGR, AGEP=>=35.0, WKHP=>=44.0, MAR=Married)
# 6447  (AGEP=>=35.0, OCCP=MGR, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SEX=Male)
# 4793                                                                                                                              (OCCP=MGR, WKHP=>=44.0, MAR=Married)
# 5432                                                                                                                    (AGEP=>=46.0, OCCP=MGR, MAR=Married, SEX=Male)
# ...                                                                                                                                                                ...
# 5142                                                                                                               (OCCP=TRN, MAR=Never married or under 15 years old)
# 3655                                                                                                                                           (OCCP=OFF, WKHP=<=39.0)
# 5767                                                                                                                                           (OCCP=TRN, AGEP=<=34.0)
# 1839                                                                                                                                                        (OCCP=EAT)
# 4090                                                                                                                                           (OCCP=EAT, WKHP=<=39.0)
#
#       length  support_count        outcome      d_outcome  t_value_outcome
# 6602       4         4898.0  184525.279706  119340.209281        50.568105
# 5850       4         5285.0  184364.491958  119179.421534        53.300735
# 6447       5         4976.0  180937.019695  115751.949270        50.479892
# 4793       3         5950.0  176303.536134  111118.465710        53.874208
# 5432       4         5510.0  173003.283122  107818.212697        49.522467
# ...      ...            ...            ...            ...              ...
# 5142       2         5703.0   24241.879712  -40943.190712       104.884368
# 3655       2         6974.0   23426.852595  -41758.217829        89.357806
# 5767       2         5324.0   22513.914350  -42671.156075       119.300494
# 1839       1        10241.0   21855.516063  -43329.554362       120.649128
# 4090       2         6538.0   15102.535944  -50082.534481       147.027199
#
# [164 rows x 7 columns]

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                                            itemsets  \
# 5206  AGEP=<=26.0, COW=Empl. for-profit-c, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 5037                            AGEP=<=26.0, COW=Empl. for-profit-c, RELP=Son/daughter, WKHP=<=29.0
# 3680                          AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
#
#        sup  Δ_outcome  t_outcome  ratio
# 5206  0.03 -57845.558      243.9  0.113
# 5037  0.03 -57830.271      244.6  0.113
# 3680  0.04 -57789.323      241.1  0.113

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                   itemsets  \
# 6602                          AGEP=>=35.0, OCCP=MGR, SEX=Male, WKHP=>=44.0
# 5850                       AGEP=>=35.0, MAR=Married, OCCP=MGR, WKHP=>=44.0
# 6447  AGEP=>=35.0, COW=Empl. for-profit-c, MAR=Married, OCCP=MGR, SEX=Male
#
#        sup   Δ_outcome  t_outcome  ratio
# 6602  0.03  119340.209       50.6  2.831
# 5850  0.03  119179.422       53.3  2.828
# 6447  0.03  115751.949       50.5  2.776

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                          itemsets   sup  Δ_outcome  t_outcome  \
# 3573  AGEP=<=26.0, RELP=Son/daughter, WKHP=<=29.0  0.04 -57776.041      242.1
# 1168                     AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6
# 2775  AGEP=<=34.0, RELP=Son/daughter, WKHP=<=29.0  0.04 -57007.316      237.0
#
#       ratio
# 3573  0.114
# 1168  0.125
# 2775  0.125

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                             itemsets   sup  Δ_outcome  t_outcome  ratio
# 1168        AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 2322  RELP=Son/daughter, WKHP=<=29.0  0.05 -56262.320      229.4  0.137
# 676         AGEP=<=34.0, WKHP=<=29.0  0.09 -54846.288      227.3  0.159

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                             itemsets   sup  Δ_outcome  t_outcome  ratio
# 1168        AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 2322  RELP=Son/daughter, WKHP=<=29.0  0.05 -56262.320      229.4  0.137
# 676         AGEP=<=34.0, WKHP=<=29.0  0.09 -54846.288      227.3  0.159

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167

# %% [markdown]
# ## min_sup_divergence  = 0.01

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
min_sup_divergence = 0.01

# %% [markdown]
# ### Without Generalization

# %%
import pandas as pd
pd.set_option('max_colwidth', None)

# %%
INFO = ['support', 'itemsets', 'tn', 'fp', 'fn', 'tp', 'd_fpr', 't_value_fp', 'error']

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = False

pattern_type = "generalized" if apply_generalization else "base"
    
FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    #true_class_name=pred_name,
    #predicted_class_name=class_name,
    target_name = target,
    #class_map=class_map,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    allow_overalp = False if type_experiment!="all_attributes" else True
)

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 51   0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 113  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 6    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 38   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 51  -40394.306410       122.486801
# 113 -21738.707445        46.955137
# 6      589.602457         1.962819
# 38   44968.106236        72.224167

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#        support  \
# 5265  0.010115
# 3137  0.015080
# 4248  0.011961
# 5103  0.010365
# 4048  0.012411
#
#                                                                                                                                                                                                                      itemsets  \
# 5265                                                                                                              (WKHP=<=29.0, MAR=Never married or under 15 years old, RELP=Noninstitutionalized group quarters population)
# 3137                                                                                                                    (WKHP=<=29.0, AGEP=<=26.0, SCHL=Regular high school diploma, MAR=Never married or under 15 years old)
# 4248                                                                                                (SCHL=Regular high school diploma, POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 5103                                                                                                                                                       (WKHP=<=29.0, RELP=Noninstitutionalized group quarters population)
# 4048  (SCHL=Regular high school diploma, AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
#
#       length  support_count      outcome     d_outcome  t_value_outcome
# 5265       3         1978.0  6795.462083 -58389.608342       200.289408
# 3137       4         2949.0  6948.565615 -58236.504809       174.290882
# 4248       5         2339.0  7044.236853 -58140.833571       150.226670
# 5103       2         2027.0  7057.648742 -58127.421683       195.474882
# 4048       5         2427.0  7111.915946 -58073.154479       154.674865

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#        support  \
# 4388  0.011654
# 4366  0.011695
# 5235  0.010151
# 4651  0.011127
# 4472  0.011460
#
#                                                                                                                                                              itemsets  \
# 4388                                                                                               (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 4366                                                                                     (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 5235                                                                           (SCHL=Professional degree beyond a bachelor's degree, RELP=Reference person, SEX=Male)
# 4651  (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SCHL=Master's degree, WKHP=>=44.0, SEX=Male)
# 4472                                                                               (RAC1P=White alone, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
#
#       length  support_count        outcome      d_outcome  t_value_outcome
# 4388       2         2279.0  228664.931988  163479.861563        40.290922
# 4366       3         2287.0  221697.415829  156512.345404        39.083566
# 5235       3         1985.0  212307.662469  147122.592044        34.782031
# 4651       4         2176.0  209515.284926  144330.214502        39.830737
# 4472       3         2241.0  208800.406069  143615.335644        36.158773

# %%
print(df_analysis["income"].describe()["mean"])
FP_fm.sort_values("length", ascending = True).head(1)
# Out:
# 65192.04881813304
#    support itemsets  length  support_count       outcome  d_outcome  \
# 0      1.0       ()       0       195556.0  65185.070425        0.0
#
#    t_value_outcome
# 0              0.0

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)
# Out:
# 3259.25, 65185.07

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                   itemsets  \
# 5265            MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=29.0
# 3137           AGEP=<=26.0, MAR=Never married/<15yrs, SCHL=HS, WKHP=<=29.0
# 4248  AGEP=<=26.0, MAR=Never married/<15yrs, POBP=CA, SCHL=HS, WKHP=<=29.0
#
#        sup  Δ_outcome  t_outcome  ratio
# 5265  0.01 -58389.608      200.3  0.104
# 3137  0.02 -58236.505      174.3  0.107
# 4248  0.01 -58140.834      150.2  0.108

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                   itemsets   sup   Δ_outcome  \
# 4388                SCHL=Prof beyond bachelor, WKHP=>=44.0  0.01  163479.862
# 4366      MAR=Married, SCHL=Prof beyond bachelor, SEX=Male  0.01  156512.345
# 5235  RELP=Ref person, SCHL=Prof beyond bachelor, SEX=Male  0.01  147122.592
#
#       t_outcome  ratio
# 4388       40.3  3.508
# 4366       39.1  3.401
# 5235       34.8  3.257

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                          itemsets   sup  Δ_outcome  t_outcome  \
# 5103             RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422      195.5
# 2932            AGEP=<=26.0, SCHL=HS, WKHP=<=29.0  0.02 -57926.000      156.5
# 915   AGEP=<=26.0, RELP=Son/daughter, WKHP=<=29.0  0.04 -57776.041      242.1
#
#       ratio
# 5103  0.108
# 2932  0.111
# 915   0.114

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                               itemsets   sup  Δ_outcome  t_outcome  ratio
# 5103  RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422      195.5  0.108
# 339           AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 625     RELP=Son/daughter, WKHP=<=29.0  0.05 -56262.320      229.4  0.137

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                               itemsets   sup  Δ_outcome  t_outcome  ratio
# 5103  RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422      195.5  0.108
# 339           AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 625     RELP=Son/daughter, WKHP=<=29.0  0.05 -56262.320      229.4  0.137

# %%
l = FP_results["base"][0.025].loc[FP_results["base"][0.025]["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 51   0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 113  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 6    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 38   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 51  -40394.306410       122.486801
# 113 -21738.707445        46.955137
# 6      589.602457         1.962819
# 38   44968.106236        72.224167

# %% [markdown]
# ### With Generalization

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = True
pattern_type = "generalized" if apply_generalization else "base"

import time 

st = time.time()

FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    target_name = target,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    considerOnlyContinuos = False,
    allow_overalp = False if type_experiment!="all_attributes" else True
)

print(time.time()-st)
# Out:
# 1 10000
# 2 20000
# 38.97925043106079

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
display(l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20))
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#         support  \
# 23642  0.010846
# 26155  0.010115
# 23265  0.010964
# 19821  0.012222
# 25260  0.010350
#
#                                                                                                                                                                                               itemsets  \
# 23642                                                                         (MAR=Never married or under 15 years old, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=39.0)
# 26155                                                                                      (WKHP=<=29.0, MAR=Never married or under 15 years old, RELP=Noninstitutionalized group quarters population)
# 23265                                                                                                                  (AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=39.0)
# 19821  (AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, OCCP=SAL)
# 25260                                                                                                (POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, MAR=Never married or under 15 years old, OCCP=SAL)
#
#        length  support_count      outcome     d_outcome  t_value_outcome
# 23642       4         2121.0  6721.769920 -58463.300505       203.760619
# 26155       3         1978.0  6795.462083 -58389.608342       200.289408
# 23265       3         2144.0  6831.079291 -58353.991134       200.128757
# 19821       5         2390.0  6857.711297 -58327.359128       237.233403
# 25260       5         2024.0  6873.552372 -58311.518053       226.388457

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#         support  \
# 25541  0.010268
# 24251  0.010652
# 21275  0.011654
# 26256  0.010094
# 21164  0.011695
#
#                                                                                         itemsets  \
# 25541  (WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0, SEX=Male)
# 24251  (MAR=Married, AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21275                         (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 26256               (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21164               (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 25541       4         2008.0  237481.040837  172295.970412        39.344466
# 24251       4         2083.0  228965.972156  163780.901731        38.327022
# 21275       2         2279.0  228664.931988  163479.861563        40.290922
# 26256       3         1974.0  221792.608916  156607.538491        35.238657
# 21164       3         2287.0  221697.415829  156512.345404        39.083566

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWTR" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i and "JWAP=NaN" not in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.1
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

# %%
display(fpdiv.head(20))
# Out:
#         support  \
# 23642  0.010846
# 26155  0.010115
# 23265  0.010964
# 19821  0.012222
# 25260  0.010350
# 25950  0.010171
# 18381  0.012876
# 14560  0.015080
# 18124  0.013004
# 23941  0.010754
# 20482  0.011961
# 25212  0.010365
# 22017  0.011373
# 16689  0.013735
# 19387  0.012411
# 19099  0.012544
# 17852  0.013127
# 18462  0.012835
# 13966  0.015484
# 14497  0.015131
#
#                                                                                                                                                                                                                                                      itemsets  \
# 23642                                                                                                                                (MAR=Never married or under 15 years old, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=39.0)
# 26155                                                                                                                                             (WKHP=<=29.0, MAR=Never married or under 15 years old, RELP=Noninstitutionalized group quarters population)
# 23265                                                                                                                                                                         (AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=39.0)
# 19821                                                         (AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, OCCP=SAL)
# 25260                                                                                                                                                       (POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, MAR=Never married or under 15 years old, OCCP=SAL)
# 25950                                                                              (POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=SAL)
# 18381                                                                                                  (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=SAL)
# 14560                                                                                                                                                   (WKHP=<=29.0, AGEP=<=26.0, SCHL=Regular high school diploma, MAR=Never married or under 15 years old)
# 18124                                                                                                                                                                           (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old, OCCP=SAL)
# 23941                                                                                                                                                                                                (WKHP=<=29.0, AGEP=<=26.0, POBP=California/CA, OCCP=SAL)
# 20482                                                                                                                               (SCHL=Regular high school diploma, POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 25212                                                                                                                                                                                      (WKHP=<=29.0, RELP=Noninstitutionalized group quarters population)
# 22017                                                                                                                                (MAR=Never married or under 15 years old, RELP=Noninstitutionalized group quarters population, WKHP=<=39.0, AGEP=<=34.0)
# 16689                                                                                                                                                                                                                    (WKHP=<=29.0, AGEP=<=26.0, OCCP=SAL)
# 19387                                 (SCHL=Regular high school diploma, AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 19099                                                                                                                                                                        (WKHP=<=29.0, AGEP=<=26.0, SCHL=Regular high school diploma, POBP=California/CA)
# 17852                                           (SEX=Female, POBP=California/CA, AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 18462  (SEX=Female, POBP=California/CA, AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 13966                                                               (SEX=Female, AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 14497                      (SEX=Female, AGEP=<=26.0, RELP=Biological son or daughter, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
#
#        length  support_count      outcome     d_outcome  t_value_outcome
# 23642       4         2121.0  6721.769920 -58463.300505       203.760619
# 26155       3         1978.0  6795.462083 -58389.608342       200.289408
# 23265       3         2144.0  6831.079291 -58353.991134       200.128757
# 19821       5         2390.0  6857.711297 -58327.359128       237.233403
# 25260       5         2024.0  6873.552372 -58311.518053       226.388457
# 25950       5         1989.0  6884.786325 -58300.284100       226.234964
# 18381       4         2518.0  6939.722002 -58245.348423       238.016882
# 14560       4         2949.0  6948.565615 -58236.504809       174.290882
# 18124       4         2543.0  6951.207236 -58233.863189       235.935647
# 23941       4         2103.0  6970.361388 -58214.709036       224.861004
# 20482       5         2339.0  7044.236853 -58140.833571       150.226670
# 25212       2         2027.0  7057.648742 -58127.421683       195.474882
# 22017       4         2224.0  7087.883993 -58097.186432       201.719523
# 16689       3         2686.0  7087.970961 -58097.099464       235.202420
# 19387       5         2427.0  7111.915946 -58073.154479       154.674865
# 19099       4         2453.0  7132.450061 -58052.620364       153.946691
# 17852       6         2567.0  7148.640436 -58036.429989       251.118641
# 18462       7         2510.0  7156.637450 -58028.432975       250.093423
# 13966       5         3028.0  7196.595112 -57988.475313       252.940704
# 14497       6         2959.0  7200.976681 -57984.093744       251.892392

# %%
fpdiv_t.head(20)
# Out:
#         support  \
# 25212  0.010365
# 1168   0.067244
# 2322   0.045915
# 24772  0.010488
# 21438  0.011603
# 676    0.088159
# 601    0.094413
# 8836   0.020787
# 653    0.089739
# 1172   0.067060
# 7476   0.023257
# 14533  0.015106
# 9998   0.019253
# 8238   0.021804
# 18996  0.012585
# 4036   0.033648
# 16032  0.014108
# 4090   0.033433
# 11185  0.017923
# 285    0.135935
#
#                                                                  itemsets  \
# 25212  (WKHP=<=29.0, RELP=Noninstitutionalized group quarters population)
# 1168                                           (WKHP=<=29.0, AGEP=<=26.0)
# 2322                       (WKHP=<=29.0, RELP=Biological son or daughter)
# 24772                                    (WKHP=<=29.0, OCCP=SAL-Cashiers)
# 21438                                    (OCCP=SAL-Cashiers, AGEP=<=26.0)
# 676                                            (WKHP=<=29.0, AGEP=<=34.0)
# 601                                            (AGEP=<=26.0, WKHP=<=39.0)
# 8836                                              (WKHP=<=29.0, OCCP=EAT)
# 653                (WKHP=<=29.0, MAR=Never married or under 15 years old)
# 1172                       (RELP=Biological son or daughter, WKHP=<=39.0)
# 7476                                              (AGEP=<=26.0, OCCP=EAT)
# 14533                         (RELP=Biological son or daughter, OCCP=EAT)
# 9998                           (WKHP=<=29.0, RAC1P=Some Other Race alone)
# 8238                (RELP=Noninstitutionalized group quarters population)
# 18996                                             (WKHP=<=29.0, OCCP=PRS)
# 4036                      (WKHP=<=29.0, SCHL=Regular high school diploma)
# 16032                                          (WKHP=<=29.0, POBP=Mexico)
# 4090                                              (OCCP=EAT, WKHP=<=39.0)
# 11185                                 (WKHP=<=29.0, POBP=Central America)
# 285                                            (WKHP=<=39.0, AGEP=<=34.0)
#
#        length  support_count       outcome     d_outcome  t_value_outcome
# 25212       2         2027.0   7057.648742 -58127.421683       195.474882
# 1168        2        13150.0   8166.591939 -57018.478486       246.626190
# 2322        2         8979.0   8922.750863 -56262.319562       229.360368
# 24772       2         2051.0   9040.068259 -56145.002165       141.678107
# 21438       2         2269.0   9399.171441 -55785.898984       201.619177
# 676         2        17240.0  10338.782135 -54846.288290       227.314599
# 601         2        18463.0  10956.889671 -54228.180754       230.807747
# 8836        2         4065.0  11243.729397 -53941.341028       144.803803
# 653         2        17549.0  11808.095846 -53376.974579       206.363504
# 1172        2        13114.0  12223.590819 -52961.479606       222.591009
# 7476        2         4548.0  12802.069041 -52383.001384       153.320276
# 14533       2         2954.0  13155.142180 -52029.928245       159.578722
# 9998        2         3765.0  13403.343958 -51781.726467       106.597833
# 8238        1         4264.0  14437.292214 -50747.778211       139.868385
# 18996       2         2461.0  14752.673710 -50432.396715        89.050567
# 4036        2         6580.0  14767.244681 -50417.825744       118.237561
# 16032       2         2759.0  15101.348315 -50083.722110        94.120501
# 4090        2         6538.0  15102.535944 -50082.534481       147.027199
# 11185       2         3505.0  15187.389444 -49997.680981       107.439881
# 285         2        26583.0  15309.197382 -49875.873043       203.613355

# %%
display(fpdiv.tail(10))
fpdiv_t.tail(10)
# Out:
#         support  \
# 19787  0.012237
# 21228  0.011674
# 17510  0.013290
# 26286  0.010084
# 24734  0.010498
# 21164  0.011695
# 26256  0.010094
# 21275  0.011654
# 24251  0.010652
# 25541  0.010268
#
#                                                                                                                                                                               itemsets  \
# 19787                                                                                                     (WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21228                                                                                                  (AGEP=>=46.0, WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree)
# 17510                                                                                     (WKHP=>=40.0, AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married)
# 26286                                                                                  (RAC1P=White alone, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0, SEX=Male)
# 24734  (AGEP=>=35.0, SCHL=Master's degree, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0)
# 21164                                                                                                     (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 26256                                                                                                     (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21275                                                                                                               (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 24251                                                                                        (MAR=Married, AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 25541                                                                                        (WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0, SEX=Male)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 19787       3         2393.0  218808.332637  153623.262212        39.524042
# 21228       3         2283.0  219292.229523  154107.159098        38.725222
# 17510       4         2599.0  219292.527895  154107.457471        42.242858
# 26286       4         1972.0  220337.312373  155152.241948        35.768288
# 24734       5         2053.0  221466.678032  156281.607607        40.481408
# 21164       3         2287.0  221697.415829  156512.345404        39.083566
# 26256       3         1974.0  221792.608916  156607.538491        35.238657
# 21275       2         2279.0  228664.931988  163479.861563        40.290922
# 24251       4         2083.0  228965.972156  163780.901731        38.327022
# 25541       4         2008.0  237481.040837  172295.970412        39.344466
#         support  \
# 17345  0.013372
# 19787  0.012237
# 21228  0.011674
# 17510  0.013290
# 24734  0.010498
# 21164  0.011695
# 26256  0.010094
# 21275  0.011654
# 24251  0.010652
# 25541  0.010268
#
#                                                                                                                                                                               itemsets  \
# 17345                                                                                                     (SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0, SEX=Male)
# 19787                                                                                                     (WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21228                                                                                                  (AGEP=>=46.0, WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree)
# 17510                                                                                     (WKHP=>=40.0, AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married)
# 24734  (AGEP=>=35.0, SCHL=Master's degree, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0)
# 21164                                                                                                     (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 26256                                                                                                     (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21275                                                                                                               (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 24251                                                                                        (MAR=Married, AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 25541                                                                                        (WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0, SEX=Male)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 17345       3         2615.0  217735.774379  152550.703954        40.445336
# 19787       3         2393.0  218808.332637  153623.262212        39.524042
# 21228       3         2283.0  219292.229523  154107.159098        38.725222
# 17510       4         2599.0  219292.527895  154107.457471        42.242858
# 24734       5         2053.0  221466.678032  156281.607607        40.481408
# 21164       3         2287.0  221697.415829  156512.345404        39.083566
# 26256       3         1974.0  221792.608916  156607.538491        35.238657
# 21275       2         2279.0  228664.931988  163479.861563        40.290922
# 24251       4         2083.0  228965.972156  163780.901731        38.327022
# 25541       4         2008.0  237481.040837  172295.970412        39.344466

# %% [markdown]
# #### Analysis

# %%
# FP_fm.loc[FP_fm["length"] == 1].loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "POBP" in i ])>0)].sort_values(metric, ascending = True)

FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = True)
# Out:
#         support  \
# 19821  0.012222
# 25260  0.010350
# 25950  0.010171
# 18381  0.012876
# 18124  0.013004
# ...         ...
# 25388  0.010314
# 22257  0.011291
# 24810  0.010478
# 17294  0.013403
# 26203  0.010105
#
#                                                                                                                                                                                                itemsets  \
# 19821   (AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, OCCP=SAL)
# 25260                                                                                                 (POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, MAR=Never married or under 15 years old, OCCP=SAL)
# 25950                        (POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=SAL)
# 18381                                            (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=SAL)
# 18124                                                                                                                     (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old, OCCP=SAL)
# ...                                                                                                                                                                                                 ...
# 25388                                                                                                                                                       (OCCP=MGR-Chief Executives And Legislators)
# 22257                               (OCCP=MGR, AGEP=>=46.0, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0)
# 24810                                  (OCCP=MGR, AGEP=>=46.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0, SEX=Male)
# 17294                     (AGEP=>=35.0, OCCP=MGR, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0, SEX=Male)
# 26203  (AGEP=>=35.0, OCCP=MGR, RAC1P=White alone, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0, SEX=Male)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 19821       5         2390.0    6857.711297  -58327.359128       237.233403
# 25260       5         2024.0    6873.552372  -58311.518053       226.388457
# 25950       5         1989.0    6884.786325  -58300.284100       226.234964
# 18381       4         2518.0    6939.722002  -58245.348423       238.016882
# 18124       4         2543.0    6951.207236  -58233.863189       235.935647
# ...       ...            ...            ...            ...              ...
# 25388       1         2017.0  208556.807139  143371.736714        34.251326
# 22257       5         2208.0  210097.196558  144912.126133        38.777271
# 24810       5         2049.0  210158.799414  144973.728990        37.211200
# 17294       6         2621.0  212623.227776  147438.157351        42.551811
# 26203       7         1976.0  217157.616397  151972.545972        37.858689
#
# [4467 rows x 7 columns]

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence

fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=0)
# Out:
#         support  \
# 25541  0.010268
# 24251  0.010652
# 21275  0.011654
# 26256  0.010094
# 21164  0.011695
# ...         ...
# 25260  0.010350
# 19821  0.012222
# 23265  0.010964
# 26155  0.010115
# 23642  0.010846
#
#                                                                                                                                                                                               itemsets  \
# 25541                                                                                                        (WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0, SEX=Male)
# 24251                                                                                                        (MAR=Married, AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21275                                                                                                                               (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 26256                                                                                                                     (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21164                                                                                                                     (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# ...                                                                                                                                                                                                ...
# 25260                                                                                                (POBP=California/CA, AGEP=<=26.0, WKHP=<=29.0, MAR=Never married or under 15 years old, OCCP=SAL)
# 19821  (AGEP=<=26.0, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, OCCP=SAL)
# 23265                                                                                                                  (AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=39.0)
# 26155                                                                                      (WKHP=<=29.0, MAR=Never married or under 15 years old, RELP=Noninstitutionalized group quarters population)
# 23642                                                                         (MAR=Never married or under 15 years old, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=39.0)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 25541       4         2008.0  237481.040837  172295.970412        39.344466
# 24251       4         2083.0  228965.972156  163780.901731        38.327022
# 21275       2         2279.0  228664.931988  163479.861563        40.290922
# 26256       3         1974.0  221792.608916  156607.538491        35.238657
# 21164       3         2287.0  221697.415829  156512.345404        39.083566
# ...       ...            ...            ...            ...              ...
# 25260       5         2024.0    6873.552372  -58311.518053       226.388457
# 19821       5         2390.0    6857.711297  -58327.359128       237.233403
# 23265       3         2144.0    6831.079291  -58353.991134       200.128757
# 26155       3         1978.0    6795.462083  -58389.608342       200.289408
# 23642       4         2121.0    6721.769920  -58463.300505       203.760619
#
# [25307 rows x 7 columns]

# %%
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]

v = mean_outcome*0.1

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
print(v)
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=v)
# Out:
# 6518.507042483994
#         support  \
# 25541  0.010268
# 24251  0.010652
# 21275  0.011654
# 26256  0.010094
# 21164  0.011695
# ...         ...
# 21438  0.011603
# 24772  0.010488
# 2322   0.045915
# 1168   0.067244
# 25212  0.010365
#
#                                                                                         itemsets  \
# 25541  (WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0, SEX=Male)
# 24251  (MAR=Married, AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21275                         (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 26256               (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21164               (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# ...                                                                                          ...
# 21438                                                           (OCCP=SAL-Cashiers, AGEP=<=26.0)
# 24772                                                           (WKHP=<=29.0, OCCP=SAL-Cashiers)
# 2322                                              (WKHP=<=29.0, RELP=Biological son or daughter)
# 1168                                                                  (WKHP=<=29.0, AGEP=<=26.0)
# 25212                         (WKHP=<=29.0, RELP=Noninstitutionalized group quarters population)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 25541       4         2008.0  237481.040837  172295.970412        39.344466
# 24251       4         2083.0  228965.972156  163780.901731        38.327022
# 21275       2         2279.0  228664.931988  163479.861563        40.290922
# 26256       3         1974.0  221792.608916  156607.538491        35.238657
# 21164       3         2287.0  221697.415829  156512.345404        39.083566
# ...       ...            ...            ...            ...              ...
# 21438       2         2269.0    9399.171441  -55785.898984       201.619177
# 24772       2         2051.0    9040.068259  -56145.002165       141.678107
# 2322        2         8979.0    8922.750863  -56262.319562       229.360368
# 1168        2        13150.0    8166.591939  -57018.478486       246.626190
# 25212       2         2027.0    7057.648742  -58127.421683       195.474882
#
# [3680 rows x 7 columns]

# %%
f = fp_divergence_o.getDivergence(th_redundancy=v)

f.loc[f["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = False)
# Out:
#         support  \
# 17294  0.013403
# 24810  0.010478
# 22257  0.011291
# 25388  0.010314
# 25377  0.010314
# ...         ...
# 14533  0.015106
# 7476   0.023257
# 8836   0.020787
# 21438  0.011603
# 24772  0.010488
#
#                                                                                                                                                                                          itemsets  \
# 17294               (AGEP=>=35.0, OCCP=MGR, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0, SEX=Male)
# 24810                            (OCCP=MGR, AGEP=>=46.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0, SEX=Male)
# 22257                         (OCCP=MGR, AGEP=>=46.0, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0)
# 25388                                                                                                                                                 (OCCP=MGR-Chief Executives And Legislators)
# 25377  (AGEP=>=35.0, OCCP=MGR, RELP=Reference person, MAR=Married, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0)
# ...                                                                                                                                                                                           ...
# 14533                                                                                                                                                 (RELP=Biological son or daughter, OCCP=EAT)
# 7476                                                                                                                                                                      (AGEP=<=26.0, OCCP=EAT)
# 8836                                                                                                                                                                      (WKHP=<=29.0, OCCP=EAT)
# 21438                                                                                                                                                            (OCCP=SAL-Cashiers, AGEP=<=26.0)
# 24772                                                                                                                                                            (WKHP=<=29.0, OCCP=SAL-Cashiers)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 17294       6         2621.0  212623.227776  147438.157351        42.551811
# 24810       5         2049.0  210158.799414  144973.728990        37.211200
# 22257       5         2208.0  210097.196558  144912.126133        38.777271
# 25388       1         2017.0  208556.807139  143371.736714        34.251326
# 25377       6         2017.0  208230.019831  143044.949407        36.626199
# ...       ...            ...            ...            ...              ...
# 14533       2         2954.0   13155.142180  -52029.928245       159.578722
# 7476        2         4548.0   12802.069041  -52383.001384       153.320276
# 8836        2         4065.0   11243.729397  -53941.341028       144.803803
# 21438       2         2269.0    9399.171441  -55785.898984       201.619177
# 24772       2         2051.0    9040.068259  -56145.002165       141.678107
#
# [929 rows x 7 columns]

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                       itemsets  \
# 23642  AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=39.0
# 26155               MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=29.0
# 23265                            AGEP=<=26.0, RELP=Noninstit. GQs, WKHP=<=39.0
#
#         sup  Δ_outcome  t_outcome  ratio
# 23642  0.01 -58463.301      203.8  0.103
# 26155  0.01 -58389.608      200.3  0.104
# 23265  0.01 -58353.991      200.1  0.105

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                             itemsets   sup  \
# 25541  AGEP=>=35.0, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=40.0  0.01
# 24251  AGEP=>=35.0, MAR=Married, SCHL=Prof beyond bachelor, SEX=Male  0.01
# 21275                         SCHL=Prof beyond bachelor, WKHP=>=44.0  0.01
#
#         Δ_outcome  t_outcome  ratio
# 25541  172295.970       39.3  3.643
# 24251  163780.902       38.3  3.513
# 21275  163479.862       40.3  3.508

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                             itemsets   sup  Δ_outcome  \
# 23265  AGEP=<=26.0, RELP=Noninstit. GQs, WKHP=<=39.0  0.01 -58353.991
# 25212               RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422
# 16689             AGEP=<=26.0, OCCP=SAL, WKHP=<=29.0  0.01 -58097.099
#
#        t_outcome  ratio
# 23265      200.1  0.105
# 25212      195.5  0.108
# 16689      235.2  0.109

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                                itemsets   sup  Δ_outcome  t_outcome  ratio
# 25212  RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422      195.5  0.108
# 19230  RELP=Noninstit. GQs, WKHP=<=39.0  0.01 -57115.581      183.2  0.124
# 1168           AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                                itemsets   sup  Δ_outcome  t_outcome  ratio
# 25212  RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422      195.5  0.108
# 1168           AGEP=<=26.0, WKHP=<=29.0  0.07 -57018.478      246.6  0.125
# 2322     RELP=Son/daughter, WKHP=<=29.0  0.05 -56262.320      229.4  0.137

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167

# %% [markdown]
# ## min_sup_divergence  = 0.001

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
min_sup_divergence = 0.005

# %% [markdown]
# ### Without Generalization

# %%
import pandas as pd
pd.set_option('max_colwidth', None)

# %%
INFO = ['support', 'itemsets', 'tn', 'fp', 'fn', 'tp', 'd_fpr', 't_value_fp', 'error']

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = False

pattern_type = "generalized" if apply_generalization else "base"
    
FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    #true_class_name=pred_name,
    #predicted_class_name=class_name,
    target_name = target,
    #class_map=class_map,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    allow_overalp = False if type_experiment!="all_attributes" else True
)
# Out:
# 1 10000

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 51   0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 113  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 6    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 38   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 51  -40394.306410       122.486801
# 113 -21738.707445        46.955137
# 6      589.602457         1.962819
# 38   44968.106236        72.224167

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#         support  \
# 12572  0.005016
# 10233  0.005911
# 10378  0.005850
# 9521   0.006280
# 9597   0.006239
#
#                                                                                                                                                                                                                                          itemsets  \
# 12572                                                                                                                                                                       (WKHP=<=29.0, MAR=Never married or under 15 years old, SCHL=Grade 11)
# 10233                                           (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Noninstitutionalized group quarters population)
# 10378  (AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 9521                                                                                                                                          (WKHP=<=29.0, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, POBP=California/CA)
# 9597                                                                                                 (POBP=California/CA, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
#
#        length  support_count      outcome     d_outcome  t_value_outcome
# 12572       3          981.0  4594.791030 -60590.279395       203.925669
# 10233       4         1156.0  5289.233564 -59895.836861       205.227141
# 10378       5         1144.0  5315.169580 -59869.900844       204.019920
# 9521        4         1228.0  5662.104235 -59522.966190       197.543755
# 9597        5         1220.0  5678.085246 -59506.985179       196.773637

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#         support  \
# 11244  0.005482
# 11627  0.005339
# 10584  0.005748
# 8269   0.007072
# 9743   0.006152
#
#                                                                                                  itemsets  \
# 11244           (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 11627     (RAC1P=White alone, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 10584                                                                               (OCCP=MED-Physicians)
# 8269                         (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 9743   (RAC1P=White alone, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, MAR=Married)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 11244       4         1072.0  277420.419776  212235.349351        33.472128
# 11627       4         1044.0  262434.971264  197249.900840        31.414025
# 10584       1         1124.0  262061.352313  196876.281888        33.230349
# 8269        3         1383.0  258110.115691  192925.045266        34.810372
# 9743        4         1203.0  254145.544472  188960.474047        32.787377

# %%
print(df_analysis["income"].describe()["mean"])
FP_fm.sort_values("length", ascending = True).head(1)
# Out:
# 65192.04881813304
#    support itemsets  length  support_count       outcome  d_outcome  \
# 0      1.0       ()       0       195556.0  65185.070425        0.0
#
#    t_value_outcome
# 0              0.0

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)
# Out:
# 3259.25, 65185.07

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                                               itemsets  \
# 12572                                             MAR=Never married/<15yrs, SCHL=Grade 11, WKHP=<=29.0
# 10233                            AGEP=<=26.0, COW=Empl. for-profit-c, RELP=Noninstit. GQs, WKHP=<=29.0
# 10378  AGEP=<=26.0, COW=Empl. for-profit-c, MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=29.0
#
#         sup  Δ_outcome  t_outcome  ratio
# 12572  0.01 -60590.279      203.9  0.070
# 10233  0.01 -59895.837      205.2  0.081
# 10378  0.01 -59869.901      204.0  0.082

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                             itemsets   sup  \
# 11244  MAR=Married, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=44.0  0.01
# 11627    RAC=White, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=44.0  0.01
# 10584                                            OCCP=MED-Physicians  0.01
#
#         Δ_outcome  t_outcome  ratio
# 11244  212235.349       33.5  4.256
# 11627  197249.901       31.4  4.026
# 10584  196876.282       33.2  4.020

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                                                     itemsets  \
# 12572                   MAR=Never married/<15yrs, SCHL=Grade 11, WKHP=<=29.0
# 10233  AGEP=<=26.0, COW=Empl. for-profit-c, RELP=Noninstit. GQs, WKHP=<=29.0
# 9144                COW=Empl. for-profit-c, RELP=Noninstit. GQs, WKHP=<=29.0
#
#         sup  Δ_outcome  t_outcome  ratio
# 12572  0.01 -60590.279      203.9  0.070
# 10233  0.01 -59895.837      205.2  0.081
# 9144   0.01 -59088.537      195.8  0.094

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                                                       itemsets   sup  \
# 5103                          RELP=Noninstit. GQs, WKHP=<=29.0  0.01
# 6315  AGEP=<=26.0, COW=Empl. for-profit-c, RELP=Noninstit. GQs  0.01
# 9864                                SCHL=Grade 11, WKHP=<=29.0  0.01
#
#       Δ_outcome  t_outcome  ratio
# 5103 -58127.422      195.5  0.108
# 6315 -57889.881      139.2  0.112
# 9864 -57703.870       87.4  0.115

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                               itemsets   sup  Δ_outcome  t_outcome  ratio
# 5103  RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422      195.5  0.108
# 9864        SCHL=Grade 11, WKHP=<=29.0  0.01 -57703.870       87.4  0.115
# 8745        AGEP=<=26.0, SCHL=Grade 11  0.01 -57585.412      142.9  0.117

# %%
l = FP_results["base"][0.025].loc[FP_results["base"][0.025]["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 51   0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 113  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 6    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 38   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 51  -40394.306410       122.486801
# 113 -21738.707445        46.955137
# 6      589.602457         1.962819
# 38   44968.106236        72.224167

# %% [markdown]
# ### With Generalization

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = True
pattern_type = "generalized" if apply_generalization else "base"

import time 

st = time.time()

FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    target_name = target,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    considerOnlyContinuos = False,
    allow_overalp = False if type_experiment!="all_attributes" else True
)

print(time.time()-st)
# Out:
# 1 10000
# 2 20000
# 3 30000
# 4 40000
# 5 50000
# 6 60000
# 7 70000
# 58.37598443031311

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
display(l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20))
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#         support  \
# 70280  0.005016
# 70329  0.005016
# 65032  0.005318
# 63369  0.005415
# 55998  0.005911
#
#                                                                                                                                                                                                 itemsets  \
# 70280                                                                                                                                                          (WKHP=<=29.0, SCHL=Grade 11, AGEP=<=34.0)
# 70329                                                                                                                              (WKHP=<=29.0, MAR=Never married or under 15 years old, SCHL=Grade 11)
# 65032                                                                                                                 (WKHP=<=39.0, AGEP=<=26.0, MAR=Never married or under 15 years old, SCHL=Grade 11)
# 63369                                                                                                                                                          (WKHP=<=39.0, AGEP=<=26.0, SCHL=Grade 11)
# 55998  (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Noninstitutionalized group quarters population)
#
#        length  support_count      outcome     d_outcome  t_value_outcome
# 70280       3          981.0  4410.214067 -60774.856358       213.639704
# 70329       3          981.0  4594.791030 -60590.279395       203.925669
# 65032       4         1040.0  4676.923077 -60508.147348       208.483231
# 63369       3         1059.0  4818.338055 -60366.732370       205.947561
# 55998       4         1156.0  5289.233564 -59895.836861       205.227141

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#         support  \
# 56034  0.005906
# 62302  0.005482
# 63625  0.005400
# 70577  0.005001
# 42645  0.007195
#
#                                                                                                               itemsets  \
# 56034                        (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, AGEP=>=35.0, SEX=Male)
# 62302                        (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 63625  (AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married, RAC1P=White alone, WKHP=>=44.0)
# 70577               (AGEP=>=46.0, RAC1P=White alone, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 42645                     (AGEP=>=35.0, WKHP=>=44.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 56034       4         1155.0  281019.203463  215834.133038        34.792665
# 62302       4         1072.0  277420.419776  212235.349351        33.472128
# 63625       5         1056.0  267271.676136  202086.605712        32.243483
# 70577       4          978.0  266948.680982  201763.610557        30.364818
# 42645       4         1407.0  266824.292822  201639.222397        37.107282

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWTR" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i and "JWAP=NaN" not in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.1
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

# %%
display(fpdiv.head(20))
# Out:
#         support  \
# 70280  0.005016
# 70329  0.005016
# 65032  0.005318
# 63369  0.005415
# 55998  0.005911
# 58850  0.005707
# 56847  0.005850
# 66755  0.005211
# 67997  0.005144
# 51493  0.006280
# 51957  0.006239
# 51752  0.006254
# 52625  0.006182
# 49623  0.006453
# 54358  0.006039
# 49025  0.006510
# 44108  0.007021
# 43310  0.007113
# 50740  0.006351
# 64054  0.005369
#
#                                                                                                                                                                                                                                                              itemsets  \
# 70280                                                                                                                                                                                                                       (WKHP=<=29.0, SCHL=Grade 11, AGEP=<=34.0)
# 70329                                                                                                                                                                                           (WKHP=<=29.0, MAR=Never married or under 15 years old, SCHL=Grade 11)
# 65032                                                                                                                                                                              (WKHP=<=39.0, AGEP=<=26.0, MAR=Never married or under 15 years old, SCHL=Grade 11)
# 63369                                                                                                                                                                                                                       (WKHP=<=39.0, AGEP=<=26.0, SCHL=Grade 11)
# 55998                                                               (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Noninstitutionalized group quarters population)
# 58850                                                                                                                                                                              (WKHP=<=39.0, MAR=Never married or under 15 years old, SCHL=Grade 11, AGEP=<=34.0)
# 56847                      (AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 66755                                           (POBP=California/CA, AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=<=39.0)
# 67997  (POBP=California/CA, AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, WKHP=<=39.0)
# 51493                                                                                                                                                             (WKHP=<=29.0, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, POBP=California/CA)
# 51957                                                                                                                    (POBP=California/CA, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 51752                                                               (WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Noninstitutionalized group quarters population, AGEP=<=34.0)
# 52625                      (AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 49623                                                                                                                    (POBP=California/CA, AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 54358                                                                                                                                                                                                                       (WKHP=<=39.0, SCHL=Grade 11, AGEP=<=34.0)
# 49025                                                                                                                                                             (WKHP=<=29.0, RELP=Noninstitutionalized group quarters population, POBP=California/CA, AGEP=<=34.0)
# 44108                      (AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, WKHP=<=39.0)
# 43310                                                               (AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Noninstitutionalized group quarters population, WKHP=<=39.0)
# 50740                                   (WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, RELP=Noninstitutionalized group quarters population)
# 64054               (POBP=California/CA, RELP=Noninstitutionalized group quarters population, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old, WKHP=<=39.0)
#
#        length  support_count      outcome     d_outcome  t_value_outcome
# 70280       3          981.0  4410.214067 -60774.856358       213.639704
# 70329       3          981.0  4594.791030 -60590.279395       203.925669
# 65032       4         1040.0  4676.923077 -60508.147348       208.483231
# 63369       3         1059.0  4818.338055 -60366.732370       205.947561
# 55998       4         1156.0  5289.233564 -59895.836861       205.227141
# 58850       4         1116.0  5293.422939 -59891.647486       201.374686
# 56847       5         1144.0  5315.169580 -59869.900844       204.019920
# 66755       5         1019.0  5644.017664 -59541.052760       205.466779
# 67997       6         1006.0  5658.502982 -59526.567443       204.153187
# 51493       4         1228.0  5662.104235 -59522.966190       197.543755
# 51957       5         1220.0  5678.085246 -59506.985179       196.773637
# 51752       4         1223.0  5691.491415 -59493.579010       200.215309
# 52625       5         1209.0  5709.258892 -59475.811533       198.981068
# 49623       5         1262.0  5728.339144 -59456.731281       199.921052
# 54358       3         1181.0  5733.099069 -59451.971356       196.270260
# 49025       4         1273.0  5749.696779 -59435.373646       199.920713
# 44108       5         1373.0  5846.914785 -59338.155640       205.617430
# 43310       4         1391.0  5888.004313 -59297.066111       205.216993
# 50740       4         1242.0  5898.521739 -59286.548686       199.286115
# 64054       5         1050.0  5898.641905 -59286.428520       204.400936

# %%
fpdiv_t.head(20)
# Out:
#         support  \
# 25211  0.010365
# 53771  0.006090
# 46745  0.006735
# 1168   0.067244
# 65041  0.005318
# 2322   0.045915
# 24773  0.010488
# 21441  0.011603
# 676    0.088159
# 36389  0.008039
# 601    0.094413
# 8837   0.020787
# 32074  0.008775
# 653    0.089739
# 36943  0.007947
# 1172   0.067060
# 30585  0.009061
# 69250  0.005073
# 7476   0.023257
# 56644  0.005865
#
#                                                                  itemsets  \
# 25211  (WKHP=<=29.0, RELP=Noninstitutionalized group quarters population)
# 53771                                        (WKHP=<=29.0, SCHL=Grade 11)
# 46745                                        (AGEP=<=26.0, SCHL=Grade 11)
# 1168                                           (WKHP=<=29.0, AGEP=<=26.0)
# 65041                    (RELP=Biological son or daughter, SCHL=Grade 11)
# 2322                       (WKHP=<=29.0, RELP=Biological son or daughter)
# 24773                                    (WKHP=<=29.0, OCCP=SAL-Cashiers)
# 21441                                    (OCCP=SAL-Cashiers, AGEP=<=26.0)
# 676                                            (WKHP=<=29.0, AGEP=<=34.0)
# 36389                                        (WKHP=<=39.0, SCHL=Grade 11)
# 601                                            (AGEP=<=26.0, WKHP=<=39.0)
# 8837                                              (WKHP=<=29.0, OCCP=EAT)
# 32074                                        (SCHL=Grade 11, AGEP=<=34.0)
# 653                (WKHP=<=29.0, MAR=Never married or under 15 years old)
# 36943                                             (OCCP=PRS, AGEP=<=26.0)
# 1172                       (RELP=Biological son or daughter, WKHP=<=39.0)
# 30585            (MAR=Never married or under 15 years old, SCHL=Grade 11)
# 69250            (OCCP=OFF-Customer Service Representatives, WKHP=<=29.0)
# 7476                                              (AGEP=<=26.0, OCCP=EAT)
# 56644                           (WKHP=<=29.0, RELP=Housemate or roommate)
#
#        length  support_count       outcome     d_outcome  t_value_outcome
# 25211       2         2027.0   7057.648742 -58127.421683       195.474882
# 53771       2         1191.0   7481.200672 -57703.869753        87.367529
# 46745       2         1317.0   7599.658314 -57585.412110       142.904024
# 1168        2        13150.0   8166.591939 -57018.478486       246.626190
# 65041       2         1040.0   8353.144231 -56831.926194       134.434957
# 2322        2         8979.0   8922.750863 -56262.319562       229.360368
# 24773       2         2051.0   9040.068259 -56145.002165       141.678107
# 21441       2         2269.0   9399.171441 -55785.898984       201.619177
# 676         2        17240.0  10338.782135 -54846.288290       227.314599
# 36389       2         1572.0  10348.861323 -54836.209102        81.517239
# 601         2        18463.0  10956.889671 -54228.180754       230.807747
# 8837        2         4065.0  11243.729397 -53941.341028       144.803803
# 32074       2         1716.0  11394.283217 -53790.787208       121.184930
# 653         2        17549.0  11808.095846 -53376.974579       206.363504
# 36943       2         1554.0  11997.844273 -53187.226152       135.128395
# 1172        2        13114.0  12223.590819 -52961.479606       222.591009
# 30585       2         1772.0  12267.703160 -52917.367265       120.561851
# 69250       2          992.0  12681.058468 -52504.011957        80.582104
# 7476        2         4548.0  12802.069041 -52383.001384       153.320276
# 56644       2         1147.0  13094.725371 -52090.345054       100.851861

# %%
display(fpdiv.tail(10))
fpdiv_t.tail(10)
# Out:
#         support  \
# 43678  0.007072
# 58285  0.005748
# 64709  0.005339
# 65325  0.005298
# 51239  0.006300
# 42645  0.007195
# 70577  0.005001
# 63625  0.005400
# 62302  0.005482
# 56034  0.005906
#
#                                                                                                               itemsets  \
# 43678                                     (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 58285                                                                                            (OCCP=MED-Physicians)
# 64709                  (RAC1P=White alone, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 65325                        (OCCP=MED, WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0)
# 51239                                  (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 42645                     (AGEP=>=35.0, WKHP=>=44.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married)
# 70577               (AGEP=>=46.0, RAC1P=White alone, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 63625  (AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married, RAC1P=White alone, WKHP=>=44.0)
# 62302                        (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 56034                        (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, AGEP=>=35.0, SEX=Male)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 43678       3         1383.0  258110.115691  192925.045266        34.810372
# 58285       1         1124.0  262061.352313  196876.281888        33.230349
# 64709       4         1044.0  262434.971264  197249.900840        31.414025
# 65325       4         1036.0  265348.735521  200163.665096        32.683352
# 51239       3         1232.0  266402.321429  201217.251004        33.719249
# 42645       4         1407.0  266824.292822  201639.222397        37.107282
# 70577       4          978.0  266948.680982  201763.610557        30.364818
# 63625       5         1056.0  267271.676136  202086.605712        32.243483
# 62302       4         1072.0  277420.419776  212235.349351        33.472128
# 56034       4         1155.0  281019.203463  215834.133038        34.792665
#         support  \
# 29482  0.009307
# 69969  0.005032
# 54494  0.006024
# 43678  0.007072
# 58285  0.005748
# 65325  0.005298
# 51239  0.006300
# 42645  0.007195
# 62302  0.005482
# 56034  0.005906
#
#                                                                                                                                                                          itemsets  \
# 29482                                                                                             (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, AGEP=>=35.0)
# 69969  (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, AGEP=>=35.0, OCCP=MGR-Chief Executives And Legislators)
# 54494                                                                      (AGEP=>=46.0, WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married, SEX=Male)
# 43678                                                                                                (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 58285                                                                                                                                                       (OCCP=MED-Physicians)
# 65325                                                                                   (OCCP=MED, WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0)
# 51239                                                                                             (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 42645                                                                                (AGEP=>=35.0, WKHP=>=44.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married)
# 62302                                                                                   (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 56034                                                                                   (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, AGEP=>=35.0, SEX=Male)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 29482       3         1820.0  254248.714286  189063.643861        40.079374
# 69969       3          984.0  255728.790650  190543.720226        29.270607
# 54494       5         1178.0  257434.219015  192249.148590        32.387721
# 43678       3         1383.0  258110.115691  192925.045266        34.810372
# 58285       1         1124.0  262061.352313  196876.281888        33.230349
# 65325       4         1036.0  265348.735521  200163.665096        32.683352
# 51239       3         1232.0  266402.321429  201217.251004        33.719249
# 42645       4         1407.0  266824.292822  201639.222397        37.107282
# 62302       4         1072.0  277420.419776  212235.349351        33.472128
# 56034       4         1155.0  281019.203463  215834.133038        34.792665

# %% [markdown]
# #### Analysis

# %%
# FP_fm.loc[FP_fm["length"] == 1].loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "POBP" in i ])>0)].sort_values(metric, ascending = True)

FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = True)
# Out:
#         support  \
# 46283  0.006786
# 43114  0.007139
# 43121  0.007134
# 62941  0.005441
# 40112  0.007512
# ...         ...
# 69348  0.005068
# 65483  0.005287
# 69969  0.005032
# 58285  0.005748
# 65325  0.005298
#
#                                                                                                                                                                                                                            itemsets  \
# 46283                      (AGEP=<=26.0, OCCP=SAL-Cashiers, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 43114                                                                                                                                        (WKHP=<=29.0, AGEP=<=26.0, MAR=Never married or under 15 years old, OCCP=SAL-Cashiers)
# 43121                                                               (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=SAL-Cashiers)
# 62941  (POBP=California/CA, AGEP=<=26.0, OCCP=SAL-Cashiers, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 40112                                                                                                                                                                                 (WKHP=<=29.0, AGEP=<=26.0, OCCP=SAL-Cashiers)
# ...                                                                                                                                                                                                                             ...
# 69348                                                    (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=MGR-Chief Executives And Legislators, WKHP=>=40.0)
# 65483                                                  (AGEP=>=35.0, OCCP=MGR, SCHL=Master's degree, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0)
# 69969                                                    (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, AGEP=>=35.0, OCCP=MGR-Chief Executives And Legislators)
# 58285                                                                                                                                                                                                         (OCCP=MED-Physicians)
# 65325                                                                                                                                     (OCCP=MED, WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 46283       5         1327.0    6163.896006  -59021.174419       234.808239
# 43114       4         1396.0    6230.351003  -58954.719422       234.288367
# 43121       4         1395.0    6240.501792  -58944.568633       236.427517
# 62941       6         1064.0    6249.915414  -58935.155011       219.318957
# 40112       3         1469.0    6303.458135  -58881.612290       236.240866
# ...       ...            ...            ...            ...              ...
# 69348       3          991.0  248602.441978  183417.371553        29.307662
# 65483       5         1034.0  251942.669246  186757.598821        32.809004
# 69969       3          984.0  255728.790650  190543.720226        29.270607
# 58285       1         1124.0  262061.352313  196876.281888        33.230349
# 65325       4         1036.0  265348.735521  200163.665096        32.683352
#
# [18680 rows x 7 columns]

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence

fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=0)
# Out:
#         support  \
# 56034  0.005906
# 62302  0.005482
# 63625  0.005400
# 70577  0.005001
# 42645  0.007195
# ...         ...
# 55998  0.005911
# 63369  0.005415
# 65032  0.005318
# 70329  0.005016
# 70280  0.005016
#
#                                                                                                                                                                                                 itemsets  \
# 56034                                                                                                          (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, AGEP=>=35.0, SEX=Male)
# 62302                                                                                                          (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 63625                                                                                    (AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married, RAC1P=White alone, WKHP=>=44.0)
# 70577                                                                                                 (AGEP=>=46.0, RAC1P=White alone, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 42645                                                                                                       (AGEP=>=35.0, WKHP=>=44.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married)
# ...                                                                                                                                                                                                  ...
# 55998  (WKHP=<=29.0, AGEP=<=26.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, RELP=Noninstitutionalized group quarters population)
# 63369                                                                                                                                                          (WKHP=<=39.0, AGEP=<=26.0, SCHL=Grade 11)
# 65032                                                                                                                 (WKHP=<=39.0, AGEP=<=26.0, MAR=Never married or under 15 years old, SCHL=Grade 11)
# 70329                                                                                                                              (WKHP=<=29.0, MAR=Never married or under 15 years old, SCHL=Grade 11)
# 70280                                                                                                                                                          (WKHP=<=29.0, SCHL=Grade 11, AGEP=<=34.0)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 56034       4         1155.0  281019.203463  215834.133038        34.792665
# 62302       4         1072.0  277420.419776  212235.349351        33.472128
# 63625       5         1056.0  267271.676136  202086.605712        32.243483
# 70577       4          978.0  266948.680982  201763.610557        30.364818
# 42645       4         1407.0  266824.292822  201639.222397        37.107282
# ...       ...            ...            ...            ...              ...
# 55998       4         1156.0    5289.233564  -59895.836861       205.227141
# 63369       3         1059.0    4818.338055  -60366.732370       205.947561
# 65032       4         1040.0    4676.923077  -60508.147348       208.483231
# 70329       3          981.0    4594.791030  -60590.279395       203.925669
# 70280       3          981.0    4410.214067  -60774.856358       213.639704
#
# [66915 rows x 7 columns]

# %%
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]

v = mean_outcome*0.1

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
print(v)
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=v)
# Out:
# 6518.507042483994
#         support  \
# 56034  0.005906
# 62302  0.005482
# 42645  0.007195
# 51239  0.006300
# 65325  0.005298
# ...         ...
# 65041  0.005318
# 1168   0.067244
# 46745  0.006735
# 53771  0.006090
# 25211  0.010365
#
#                                                                                            itemsets  \
# 56034     (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, AGEP=>=35.0, SEX=Male)
# 62302     (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 42645  (AGEP=>=35.0, WKHP=>=44.0, SCHL=Professional degree beyond a bachelor's degree, MAR=Married)
# 51239               (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 65325     (OCCP=MED, WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0)
# ...                                                                                             ...
# 65041                                              (RELP=Biological son or daughter, SCHL=Grade 11)
# 1168                                                                     (WKHP=<=29.0, AGEP=<=26.0)
# 46745                                                                  (AGEP=<=26.0, SCHL=Grade 11)
# 53771                                                                  (WKHP=<=29.0, SCHL=Grade 11)
# 25211                            (WKHP=<=29.0, RELP=Noninstitutionalized group quarters population)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 56034       4         1155.0  281019.203463  215834.133038        34.792665
# 62302       4         1072.0  277420.419776  212235.349351        33.472128
# 42645       4         1407.0  266824.292822  201639.222397        37.107282
# 51239       3         1232.0  266402.321429  201217.251004        33.719249
# 65325       4         1036.0  265348.735521  200163.665096        32.683352
# ...       ...            ...            ...            ...              ...
# 65041       2         1040.0    8353.144231  -56831.926194       134.434957
# 1168        2        13150.0    8166.591939  -57018.478486       246.626190
# 46745       2         1317.0    7599.658314  -57585.412110       142.904024
# 53771       2         1191.0    7481.200672  -57703.869753        87.367529
# 25211       2         2027.0    7057.648742  -58127.421683       195.474882
#
# [8036 rows x 7 columns]

# %%
f = fp_divergence_o.getDivergence(th_redundancy=v)

f.loc[f["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = False)
# Out:
#         support  \
# 65325  0.005298
# 58285  0.005748
# 69969  0.005032
# 65483  0.005287
# 62790  0.005451
# ...         ...
# 69250  0.005073
# 36943  0.007947
# 8837   0.020787
# 21441  0.011603
# 24773  0.010488
#
#                                                                                                                                                                            itemsets  \
# 65325                                                                                     (OCCP=MED, WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0)
# 58285                                                                                                                                                         (OCCP=MED-Physicians)
# 69969    (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, AGEP=>=35.0, OCCP=MGR-Chief Executives And Legislators)
# 65483  (AGEP=>=35.0, OCCP=MGR, SCHL=Master's degree, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, WKHP=>=44.0)
# 62790                 (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=MGR-Chief Executives And Legislators)
# ...                                                                                                                                                                             ...
# 69250                                                                                                                      (OCCP=OFF-Customer Service Representatives, WKHP=<=29.0)
# 36943                                                                                                                                                       (OCCP=PRS, AGEP=<=26.0)
# 8837                                                                                                                                                        (WKHP=<=29.0, OCCP=EAT)
# 21441                                                                                                                                              (OCCP=SAL-Cashiers, AGEP=<=26.0)
# 24773                                                                                                                                              (WKHP=<=29.0, OCCP=SAL-Cashiers)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 65325       4         1036.0  265348.735521  200163.665096        32.683352
# 58285       1         1124.0  262061.352313  196876.281888        33.230349
# 69969       3          984.0  255728.790650  190543.720226        29.270607
# 65483       5         1034.0  251942.669246  186757.598821        32.809004
# 62790       2         1066.0  246954.174484  181769.104059        29.395599
# ...       ...            ...            ...            ...              ...
# 69250       2          992.0   12681.058468  -52504.011957        80.582104
# 36943       2         1554.0   11997.844273  -53187.226152       135.128395
# 8837        2         4065.0   11243.729397  -53941.341028       144.803803
# 21441       2         2269.0    9399.171441  -55785.898984       201.619177
# 24773       2         2051.0    9040.068259  -56145.002165       141.678107
#
# [2709 rows x 7 columns]

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                 itemsets  \
# 70280                            AGEP=<=34.0, SCHL=Grade 11, WKHP=<=29.0
# 70329               MAR=Never married/<15yrs, SCHL=Grade 11, WKHP=<=29.0
# 65032  AGEP=<=26.0, MAR=Never married/<15yrs, SCHL=Grade 11, WKHP=<=39.0
#
#         sup  Δ_outcome  t_outcome  ratio
# 70280  0.01 -60774.856      213.6  0.068
# 70329  0.01 -60590.279      203.9  0.070
# 65032  0.01 -60508.147      208.5  0.072

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                           itemsets  \
# 56034                AGEP=>=35.0, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=44.0
# 62302                MAR=Married, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=44.0
# 63625  AGEP=>=35.0, MAR=Married, RAC=White, SCHL=Prof beyond bachelor, WKHP=>=44.0
#
#         sup   Δ_outcome  t_outcome  ratio
# 56034  0.01  215834.133       34.8  4.311
# 62302  0.01  212235.349       33.5  4.256
# 63625  0.01  202086.606       32.2  4.100

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                                    itemsets   sup  Δ_outcome  \
# 70280               AGEP=<=34.0, SCHL=Grade 11, WKHP=<=29.0  0.01 -60774.856
# 70329  MAR=Never married/<15yrs, SCHL=Grade 11, WKHP=<=29.0  0.01 -60590.279
# 63369               AGEP=<=26.0, SCHL=Grade 11, WKHP=<=39.0  0.01 -60366.732
#
#        t_outcome  ratio
# 70280      213.6  0.068
# 70329      203.9  0.070
# 63369      205.9  0.074

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                                                    itemsets   sup  Δ_outcome  \
# 54358               AGEP=<=34.0, SCHL=Grade 11, WKHP=<=39.0  0.01 -59451.971
# 53099  MAR=Never married/<15yrs, SCHL=Grade 11, WKHP=<=39.0  0.01 -58943.971
# 25211                      RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422
#
#        t_outcome  ratio
# 54358      196.3  0.088
# 53099      180.9  0.096
# 25211      195.5  0.108

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                                itemsets   sup  Δ_outcome  t_outcome  ratio
# 25211  RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422      195.5  0.108
# 53771        SCHL=Grade 11, WKHP=<=29.0  0.01 -57703.870       87.4  0.115
# 46745        AGEP=<=26.0, SCHL=Grade 11  0.01 -57585.412      142.9  0.117

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167

# %% [markdown]
# ## min_sup_divergence  = 0.005

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
min_sup_divergence = 0.001

# %% [markdown]
# ### Without Generalization

# %%
import pandas as pd
pd.set_option('max_colwidth', None)

# %%
INFO = ['support', 'itemsets', 'tn', 'fp', 'fn', 'tp', 'd_fpr', 't_value_fp', 'error']

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = False

pattern_type = "generalized" if apply_generalization else "base"
    
FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    #true_class_name=pred_name,
    #predicted_class_name=class_name,
    target_name = target,
    #class_map=class_map,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    allow_overalp = False if type_experiment!="all_attributes" else True
)
# Out:
# 1 10000
# 2 20000
# 3 30000
# 4 40000
# 5 50000
# 6 60000
# 7 70000
# 8 80000

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 51   0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 113  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 6    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 38   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 51  -40394.306410       122.486801
# 113 -21738.707445        46.955137
# 6      589.602457         1.962819
# 38   44968.106236        72.224167

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#         support  \
# 66565  0.001202
# 67452  0.001186
# 61822  0.001278
# 61520  0.001284
# 53673  0.001447
#
#                                                                                                                                                                      itemsets  \
# 66565                                           (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0)
# 67452  (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 61822                                     (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, MAR=Never married or under 15 years old, SEX=Male)
# 61520                                                                              (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, SEX=Male)
# 53673                                                                (POBP=California/CA, AGEP=<=26.0, RELP=Biological son or daughter, SCHL=Grade 11, WKHP=<=29.0, SEX=Male)
#
#        length  support_count      outcome     d_outcome  t_value_outcome
# 66565       5          235.0  3305.276596 -61879.793829       200.307841
# 67452       6          232.0  3311.810345 -61873.260080       198.741469
# 61822       7          250.0  3314.120000 -61870.950425       194.430340
# 61520       6          251.0  3380.597610 -61804.472815       190.589818
# 53673       6          283.0  3419.434629 -61765.635796       202.567104

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#         support  \
# 58603  0.001340
# 48891  0.001570
# 66709  0.001197
# 71608  0.001125
# 45349  0.001682
#
#                                                                                                                        itemsets  \
# 58603            (OCCP=MED-Physicians, SCHL=Professional degree beyond a bachelor's degree, MAR=Married, WKHP=>=44.0, SEX=Male)
# 48891                                                                 (MAR=Married, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 66709                                                           (RAC1P=White alone, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 71608  (OCCP=MED-Physicians, SCHL=Professional degree beyond a bachelor's degree, RELP=Reference person, WKHP=>=44.0, SEX=Male)
# 45349                         (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
#
#        length  support_count        outcome      d_outcome  t_value_outcome
# 58603       5          262.0  351761.030534  286575.960110        20.578337
# 48891       4          307.0  347915.602606  282730.532181        22.098218
# 66709       4          234.0  339797.264957  274612.194532        19.186114
# 71608       5          220.0  335527.136364  270342.065939        18.081164
# 45349       4          329.0  331673.404255  266488.333830        20.955622

# %%
print(df_analysis["income"].describe()["mean"])
FP_fm.sort_values("length", ascending = True).head(1)
# Out:
# 65192.04881813304
#    support itemsets  length  support_count       outcome  d_outcome  \
# 0      1.0       ()       0       195556.0  65185.070425        0.0
#
#    t_value_outcome
# 0              0.0

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)
# Out:
# 3259.25, 65185.07

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                                               itemsets  \
# 66565                               AGEP=<=26.0, RELP=Noninstit. GQs, SCHL=HS, SEX=Female, WKHP=<=29.0
# 67452     AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Noninstit. GQs, SCHL=HS, SEX=Female, WKHP=<=29.0
# 61822  AGEP=<=26.0, MAR=Never married/<15yrs, POBP=CA, RAC=White, SCHL=Grade 11, SEX=Male, WKHP=<=29.0
#
#        sup  Δ_outcome  t_outcome  ratio
# 66565  0.0 -61879.794      200.3  0.051
# 67452  0.0 -61873.260      198.7  0.051
# 61822  0.0 -61870.950      194.4  0.051

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                                  itemsets  \
# 58603  MAR=Married, OCCP=MED-Physicians, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=44.0
# 48891                             MAR=Married, OCCP=MED-Physicians, SEX=Male, WKHP=>=44.0
# 66709                               OCCP=MED-Physicians, RAC=White, SEX=Male, WKHP=>=44.0
#
#        sup   Δ_outcome  t_outcome  ratio
# 58603  0.0  286575.960       20.6  5.396
# 48891  0.0  282730.532       22.1  5.337
# 66709  0.0  274612.195       19.2  5.213

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                                                             itemsets  \
# 75741  AGEP=<=26.0, COW=Empl. for-profit-c, RELP=Noninstit. GQs, SCHL=HS, SEX=Female
# 61649                          RELP=Noninstit. GQs, SCHL=HS, SEX=Female, WKHP=<=29.0
# 13623                                        AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0
#
#        sup  Δ_outcome  t_outcome  ratio
# 75741  0.0 -61745.070      193.1  0.053
# 61649  0.0 -61511.047      193.3  0.056
# 13623  0.0 -61216.650      219.6  0.061

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                                                   itemsets  sup  Δ_outcome  \
# 13623              AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0  0.0 -61216.650
# 17696        RELP=Son/daughter, SCHL=Grade 11, WKHP=<=29.0  0.0 -61199.323
# 44152  OCCP=EAT-Fast Food And Counter Workers, WKHP=<=29.0  0.0 -58352.340
#
#        t_outcome  ratio
# 13623      219.6  0.061
# 17696      229.6  0.061
# 44152      104.5  0.105

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                               itemsets   sup  Δ_outcome  t_outcome  ratio
# 5103  RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422      195.5  0.108
# 9872        SCHL=Grade 11, WKHP=<=29.0  0.01 -57703.870       87.4  0.115
# 8748        AGEP=<=26.0, SCHL=Grade 11  0.01 -57585.412      142.9  0.117

# %%
l = FP_results["base"][0.025].loc[FP_results["base"][0.025]["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 51   0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 113  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 6    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 38   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 51  -40394.306410       122.486801
# 113 -21738.707445        46.955137
# 6      589.602457         1.962819
# 38   44968.106236        72.224167

# %% [markdown]
# ### With Generalization

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = True
pattern_type = "generalized" if apply_generalization else "base"

import time 

st = time.time()

FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    target_name = target,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    considerOnlyContinuos = False,
    allow_overalp = False if type_experiment!="all_attributes" else True
)

print(time.time()-st)
# Out:
# 1 10000
# 2 20000
# 3 30000
# 4 40000
# 5 50000
# 6 60000
# 7 70000
# 8 80000
# 9 90000
# 10 100000
# 11 110000
# 12 120000
# 13 130000
# 14 140000
# 15 150000
# 16 160000
# 17 170000
# 18 180000
# 19 190000
# 20 200000
# 21 210000
# 22 220000
# 23 230000
# 24 240000
# 25 250000
# 26 260000
# 27 270000
# 28 280000
# 29 290000
# 30 300000
# 31 310000
# 32 320000
# 33 330000
# 34 340000
# 35 350000
# 36 360000
# 37 370000
# 38 380000
# 39 390000
# 40 400000
# 41 410000
# 42 420000
# 43 430000
# 44 440000
# 45 450000
# 46 460000
# 47 470000
# 48 480000
# 49 490000
# 50 500000
# 51 510000
# 52 520000
# 53 530000
# 54 540000
# 55 550000
# 56 560000
# 57 570000
# 204.33544826507568

# %%
FP_fm = FP_results[pattern_type][min_sup_divergence]

# %%
print(generalization_dict_all.keys())
# Out:
# dict_keys(['AGEP', 'WKHP', 'OCCP', 'POBP'])

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
display(l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20))
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %%
FP_fm.sort_values(metric, ascending = True).head()
# Out:
#          support  \
# 459458  0.001202
# 466068  0.001186
# 424027  0.001278
# 453989  0.001212
# 461231  0.001197
#
#                                                                                                                                                                       itemsets  \
# 459458                                           (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0)
# 466068  (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 424027                                     (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, MAR=Never married or under 15 years old, SEX=Male)
# 453989                                           (SCHL=Regular high school diploma, SEX=Female, AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0)
# 461231  (SCHL=Regular high school diploma, SEX=Female, AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
#
#         length  support_count      outcome     d_outcome  t_value_outcome
# 459458       5          235.0  3305.276596 -61879.793829       200.307841
# 466068       6          232.0  3311.810345 -61873.260080       198.741469
# 424027       7          250.0  3314.120000 -61870.950425       194.430340
# 453989       5          237.0  3371.054852 -61814.015573       198.875479
# 461231       6          234.0  3378.376068 -61806.694356       197.322449

# %%
FP_fm.sort_values(metric, ascending = False).head()
# Out:
#          support  \
# 509859  0.001105
# 483588  0.001151
# 544800  0.001043
# 398927  0.001345
# 559959  0.001023
#
#                                                                                                          itemsets  \
# 509859                                                  (AGEP=>=46.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 483588                                                       (AGEP=[46.0-62.0], WKHP=>=44.0, OCCP=MED-Physicians)
# 544800                                             (AGEP=[46.0-62.0], WKHP=>=40.0, SEX=Male, OCCP=MED-Physicians)
# 398927                                     (AGEP=>=35.0, OCCP=MED-Physicians, MAR=Married, WKHP=>=44.0, SEX=Male)
# 559959  (AGEP=[46.0-62.0], SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, OCCP=MED-Physicians)
#
#         length  support_count        outcome      d_outcome  t_value_outcome
# 509859       4          216.0  391068.055556  325882.985131        21.703299
# 483588       3          225.0  387013.022222  321827.951797        22.473743
# 544800       4          204.0  384804.950980  319619.880556        21.478808
# 398927       5          263.0  382907.528517  317722.458092        23.961065
# 559959       4          200.0  380763.650000  315578.579575        20.590568

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWTR" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "JWAP" in i and "JWAP=NaN" not in i])>0)].sort_values(metric, ascending = True)
# Out:
# Empty DataFrame
# Columns: [support, itemsets, length, support_count, outcome, d_outcome, t_value_outcome]
# Index: []

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "AGEP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count       outcome  \
# 174  0.170227       (AGEP=<=26.0)       1        33289.0  21282.329118
# 26   0.344602       (AGEP=<=34.0)       1        67389.0  37227.720756
# 159  0.174375  (AGEP=[27.0-34.0])       1        34100.0  52793.883284
# 499  0.103858  (AGEP=[35.0-39.0])       1        20310.0  72393.789266
# 94   0.219165  (AGEP=[35.0-45.0])       1        42859.0  75260.503978
# 398  0.115307  (AGEP=[40.0-45.0])       1        22549.0  77842.568628
# 446  0.110372  (AGEP=[57.0-62.0])       1        21584.0  79658.974703
# 2    0.655398       (AGEP=>=35.0)       1       128167.0  79884.781246
# 342  0.122579  (AGEP=[46.0-51.0])       1        23971.0  80256.883901
# 27   0.335341  (AGEP=[46.0-62.0])       1        65578.0  80524.556315
# 82   0.224969  (AGEP=[46.0-56.0])       1        43994.0  80949.221348
# 516  0.102390  (AGEP=[52.0-56.0])       1        20023.0  81778.069220
# 13   0.436233       (AGEP=>=46.0)       1        85308.0  82208.032283
# 537  0.100892       (AGEP=>=63.0)       1        19730.0  87803.520730
#
#         d_outcome  t_value_outcome
# 174 -43902.741307       173.810730
# 26  -27957.349669       104.272437
# 159 -12391.187140        34.097372
# 499   7208.718842        11.706102
# 94   10075.433553        21.481532
# 398  12657.498203        19.562325
# 446  14473.904279        21.234203
# 2    14699.710822        44.135717
# 342  15071.813477        22.759425
# 27   15339.485890        35.776606
# 82   15764.150924        30.935254
# 516  16592.998796        22.687907
# 13   17022.961858        42.983480
# 537  22618.450305        28.076516

# %% [markdown]
# #### Redundancy

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)

v = mean_outcome*0.1
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

# %%
display(fpdiv.head(20))
# Out:
#          support  \
# 459458  0.001202
# 466068  0.001186
# 424027  0.001278
# 453989  0.001212
# 461231  0.001197
# 422439  0.001284
# 362901  0.001447
# 344427  0.001514
# 291344  0.001723
# 294823  0.001708
# 411100  0.001314
# 531583  0.001069
# 366413  0.001437
# 265714  0.001851
# 553003  0.001033
# 262635  0.001872
# 342766  0.001519
# 483788  0.001151
# 208825  0.002230
# 440061  0.001243
#
#                                                                                                                                                                                                                                                                            itemsets  \
# 459458                                                                                                                                                (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0)
# 466068                                                                                                       (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 424027                                                                                                                                          (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, MAR=Never married or under 15 years old, SEX=Male)
# 453989                                                                                                                                                (SCHL=Regular high school diploma, SEX=Female, AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0)
# 461231                                                                                                       (SCHL=Regular high school diploma, SEX=Female, AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 422439                                                                                                                                                                                   (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, SEX=Male)
# 362901                                                                                                                                                                     (POBP=California/CA, AGEP=<=26.0, RELP=Biological son or daughter, SCHL=Grade 11, WKHP=<=29.0, SEX=Male)
# 344427                                                                                                                                                              (AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, MAR=Never married or under 15 years old, SEX=Male)
# 291344                                                                                                                                                                                         (AGEP=<=26.0, RELP=Biological son or daughter, SCHL=Grade 11, WKHP=<=29.0, SEX=Male)
# 294823                                                                                                                                                (AGEP=<=26.0, RELP=Biological son or daughter, SCHL=Grade 11, WKHP=<=29.0, MAR=Never married or under 15 years old, SEX=Male)
# 411100                                                                                                                                          (POBP=California/CA, AGEP=<=34.0, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, MAR=Never married or under 15 years old, SEX=Male)
# 531583                                           (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions)
# 366413                                                                                                                            (POBP=California/CA, AGEP=<=26.0, RELP=Biological son or daughter, SCHL=Grade 11, WKHP=<=29.0, MAR=Never married or under 15 years old, SEX=Male)
# 265714                                                                                                                                                             (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, MAR=Never married or under 15 years old, SEX=Male)
# 553003  (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, MAR=Never married or under 15 years old)
# 262635                                                                                                                                                                                                      (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, SEX=Male)
# 342766                                                                                                                                                                                                       (AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, SEX=Male)
# 483788                                                                                                                                                                      (AGEP=<=26.0, RELP=Biological son or daughter, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, SEX=Male)
# 208825                                                                                                                                                                                 (AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, MAR=Never married or under 15 years old, SEX=Male)
# 440061                                                                                                                    (SCHL=Regular high school diploma, SEX=Female, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
#
#         length  support_count      outcome     d_outcome  t_value_outcome
# 459458       5          235.0  3305.276596 -61879.793829       200.307841
# 466068       6          232.0  3311.810345 -61873.260080       198.741469
# 424027       7          250.0  3314.120000 -61870.950425       194.430340
# 453989       5          237.0  3371.054852 -61814.015573       198.875479
# 461231       6          234.0  3378.376068 -61806.694356       197.322449
# 422439       6          251.0  3380.597610 -61804.472815       190.589818
# 362901       6          283.0  3419.434629 -61765.635796       202.567104
# 344427       6          296.0  3431.216216 -61753.854209       205.960221
# 291344       5          337.0  3435.548961 -61749.521463       215.477090
# 294823       6          334.0  3437.844311 -61747.226113       215.017834
# 411100       7          257.0  3437.859922 -61747.210503       190.870109
# 531583       5          209.0  3440.000000 -61745.070425       193.107660
# 366413       7          281.0  3441.850534 -61743.219891       201.911399
# 265714       6          362.0  3443.701657 -61741.368767       216.357239
# 553003       6          202.0  3462.178218 -61722.892207       188.941652
# 262635       5          366.0  3465.191257 -61719.879168       214.595786
# 342766       5          297.0  3487.003367 -61698.067058       202.696840
# 483788       6          225.0  3498.088889 -61686.981536       188.575318
# 208825       5          436.0  3512.477064 -61672.593361       227.993558
# 440061       5          243.0  3517.613169 -61667.457256       196.538226

# %%
fpdiv_t.head(20)
# Out:
#          support  \
# 25216   0.010365
# 200419  0.002301
# 516577  0.001094
# 53698   0.006090
# 46777   0.006735
# 456821  0.001207
# 1168    0.067244
# 256091  0.001907
# 488930  0.001140
# 65027   0.005318
# 226955  0.002091
# 450166  0.001222
# 2322    0.045915
# 157667  0.002766
# 115734  0.003482
# 24770   0.010488
# 21441   0.011603
# 513596  0.001099
# 173970  0.002562
# 490197  0.001140
#
#                                                                                   itemsets  \
# 25216                   (WKHP=<=29.0, RELP=Noninstitutionalized group quarters population)
# 200419                     (RELP=Noninstitutionalized group quarters population, OCCP=SAL)
# 516577                     (OCCP=PRS, RELP=Noninstitutionalized group quarters population)
# 53698                                                         (WKHP=<=29.0, SCHL=Grade 11)
# 46777                                                         (AGEP=<=26.0, SCHL=Grade 11)
# 456821  (WKHP=<=29.0, OCCP=EAT-Dining Room And Cafeteria Attendants And Bartender Helpers)
# 1168                                                            (WKHP=<=29.0, AGEP=<=26.0)
# 256091                                                      (AGEP=<=26.0, OCCP=EDU-Tutors)
# 488930  (AGEP=<=26.0, OCCP=EAT-Dining Room And Cafeteria Attendants And Bartender Helpers)
# 65027                                     (RELP=Biological son or daughter, SCHL=Grade 11)
# 226955                                         (RELP=Stepson or stepdaughter, WKHP=<=29.0)
# 450166                                                  (OCCP=SAL-Cashiers, SCHL=Grade 11)
# 2322                                        (WKHP=<=29.0, RELP=Biological son or daughter)
# 157667                                                      (WKHP=<=29.0, RELP=Grandchild)
# 115734                                    (WKHP=<=29.0, OCCP=EAT-Food Preparation Workers)
# 24770                                                     (WKHP=<=29.0, OCCP=SAL-Cashiers)
# 21441                                                     (OCCP=SAL-Cashiers, AGEP=<=26.0)
# 513596                                         (WKHP=<=29.0, RELP=Adopted son or daughter)
# 173970                                           (AGEP=<=26.0, OCCP=PRS-Childcare Workers)
# 490197          (OCCP=PRS-Other Entertainment Attendants And Related Workers, AGEP=<=26.0)
#
#         length  support_count       outcome     d_outcome  t_value_outcome
# 25216        2         2027.0   7057.648742 -58127.421683       195.474882
# 200419       2          450.0   7212.400000 -57972.670425       133.254493
# 516577       2          214.0   7446.682243 -57738.388182        56.371489
# 53698        2         1191.0   7481.200672 -57703.869753        87.367529
# 46777        2         1317.0   7599.658314 -57585.412110       142.904024
# 456821       2          236.0   7756.610169 -57428.460255       123.498221
# 1168         2        13150.0   8166.591939 -57018.478486       246.626190
# 256091       2          373.0   8242.439678 -56942.630747        53.350791
# 488930       2          223.0   8319.865471 -56865.204954       106.201798
# 65027        2         1040.0   8353.144231 -56831.926194       134.434957
# 226955       2          409.0   8591.858191 -56593.212234       128.404974
# 450166       2          239.0   8903.807531 -56281.262893        86.225422
# 2322         2         8979.0   8922.750863 -56262.319562       229.360368
# 157667       2          541.0   8982.014787 -56203.055637        50.072378
# 115734       2          681.0   9007.004405 -56178.066020       118.708256
# 24770        2         2051.0   9040.068259 -56145.002165       141.678107
# 21441        2         2269.0   9399.171441 -55785.898984       201.619177
# 513596       2          215.0   9790.883721 -55394.186704        30.996276
# 173970       2          501.0  10021.896208 -55163.174217       106.275695
# 490197       2          223.0  10027.130045 -55157.940380        73.785905

# %%
display(fpdiv.tail(10))
fpdiv_t.tail(10)
# Out:
#          support  \
# 525500  0.001079
# 561679  0.001018
# 385416  0.001381
# 320465  0.001601
# 472886  0.001171
# 559959  0.001023
# 398927  0.001345
# 544800  0.001043
# 483588  0.001151
# 509859  0.001105
#
#                                                                                                                            itemsets  \
# 525500                                             (AGEP=>=35.0, OCCP=MED-Physicians, RELP=Reference person, WKHP=>=44.0, SEX=Male)
# 561679                                                               (AGEP=[46.0-62.0], MAR=Married, SEX=Male, OCCP=MED-Physicians)
# 385416               (AGEP=>=35.0, OCCP=MED-Physicians, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, SEX=Male)
# 320465                                                                    (AGEP=>=35.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 472886  (AGEP=>=35.0, OCCP=MED-Physicians, SCHL=Professional degree beyond a bachelor's degree, MAR=Married, WKHP=>=44.0, SEX=Male)
# 559959                    (AGEP=[46.0-62.0], SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, OCCP=MED-Physicians)
# 398927                                                       (AGEP=>=35.0, OCCP=MED-Physicians, MAR=Married, WKHP=>=44.0, SEX=Male)
# 544800                                                               (AGEP=[46.0-62.0], WKHP=>=40.0, SEX=Male, OCCP=MED-Physicians)
# 483588                                                                         (AGEP=[46.0-62.0], WKHP=>=44.0, OCCP=MED-Physicians)
# 509859                                                                    (AGEP=>=46.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
#
#         length  support_count        outcome      d_outcome  t_value_outcome
# 525500       5          211.0  374314.407583  309129.337158        21.313214
# 561679       4          199.0  374690.351759  309505.281334        20.298544
# 385416       5          270.0  376533.111111  311348.040686        23.136784
# 320465       4          313.0  379176.485623  313991.415198        25.509617
# 472886       6          229.0  379664.104803  314479.034379        21.733546
# 559959       4          200.0  380763.650000  315578.579575        20.590568
# 398927       5          263.0  382907.528517  317722.458092        23.961065
# 544800       4          204.0  384804.950980  319619.880556        21.478808
# 483588       3          225.0  387013.022222  321827.951797        22.473743
# 509859       4          216.0  391068.055556  325882.985131        21.703299
#          support  \
# 404135  0.001330
# 335905  0.001539
# 384672  0.001381
# 548340  0.001038
# 334943  0.001544
# 473447  0.001171
# 320465  0.001601
# 544800  0.001043
# 483588  0.001151
# 509859  0.001105
#
#                                                                                                     itemsets  \
# 404135                          (AGEP=>=35.0, OCCP=MED-Physicians, WKHP=>=40.0, RAC1P=White alone, SEX=Male)
# 335905                                             (AGEP=>=46.0, WKHP=>=40.0, SEX=Male, OCCP=MED-Physicians)
# 384672  (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, OCCP=MED-Physicians)
# 548340                           (AGEP=[46.0-62.0], WKHP=>=40.0, RELP=Reference person, OCCP=MED-Physicians)
# 334943                                                       (AGEP=>=46.0, WKHP=>=44.0, OCCP=MED-Physicians)
# 473447                                                     (AGEP=[46.0-62.0], SEX=Male, OCCP=MED-Physicians)
# 320465                                             (AGEP=>=35.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 544800                                        (AGEP=[46.0-62.0], WKHP=>=40.0, SEX=Male, OCCP=MED-Physicians)
# 483588                                                  (AGEP=[46.0-62.0], WKHP=>=44.0, OCCP=MED-Physicians)
# 509859                                             (AGEP=>=46.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
#
#         length  support_count        outcome      d_outcome  t_value_outcome
# 404135       5          260.0  358431.538462  293246.468037        23.766323
# 335905       4          301.0  360385.946844  295200.876419        24.146196
# 384672       4          270.0  360565.518519  295380.448094        22.384352
# 548340       4          203.0  363662.857143  298477.786718        20.576800
# 334943       3          302.0  367929.437086  302744.366661        24.517022
# 473447       3          229.0  371065.851528  305880.781104        21.537511
# 320465       4          313.0  379176.485623  313991.415198        25.509617
# 544800       4          204.0  384804.950980  319619.880556        21.478808
# 483588       3          225.0  387013.022222  321827.951797        22.473743
# 509859       4          216.0  391068.055556  325882.985131        21.703299

# %% [markdown]
# #### Analysis

# %%
# FP_fm.loc[FP_fm["length"] == 1].loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "POBP" in i ])>0)].sort_values(metric, ascending = True)

FP_fm.loc[FP_fm["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = True)
# Out:
#          support  \
# 503393  0.001115
# 500358  0.001120
# 531570  0.001069
# 528087  0.001074
# 494384  0.001130
# ...          ...
# 559959  0.001023
# 398927  0.001345
# 544800  0.001043
# 483588  0.001151
# 509859  0.001105
#
#                                                                                                                                                                                                                                   itemsets  \
# 503393                                                                                                                    (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, OCCP=EAT, MAR=Never married or under 15 years old)
# 500358                                                                                                                                                             (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, OCCP=EAT)
# 531570  (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=EAT, MAR=Never married or under 15 years old)
# 528087                                           (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, OCCP=EAT)
# 494384                                                                                                                    (POBP=California/CA, AGEP=<=34.0, SCHL=Grade 11, WKHP=<=29.0, OCCP=EAT, MAR=Never married or under 15 years old)
# ...                                                                                                                                                                                                                                    ...
# 559959                                                                                                                           (AGEP=[46.0-62.0], SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, OCCP=MED-Physicians)
# 398927                                                                                                                                                              (AGEP=>=35.0, OCCP=MED-Physicians, MAR=Married, WKHP=>=44.0, SEX=Male)
# 544800                                                                                                                                                                      (AGEP=[46.0-62.0], WKHP=>=40.0, SEX=Male, OCCP=MED-Physicians)
# 483588                                                                                                                                                                                (AGEP=[46.0-62.0], WKHP=>=44.0, OCCP=MED-Physicians)
# 509859                                                                                                                                                                           (AGEP=>=46.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
#
#         length  support_count        outcome      d_outcome  t_value_outcome
# 503393       6          218.0    3578.027523  -61607.042902       183.978958
# 500358       5          219.0    3579.954338  -61605.116087       184.529438
# 531570       7          209.0    3580.191388  -61604.879037       181.746440
# 528087       6          210.0    3582.190476  -61602.879949       182.320646
# 494384       6          221.0    3640.316742  -61544.753683       184.021926
# ...        ...            ...            ...            ...              ...
# 559959       4          200.0  380763.650000  315578.579575        20.590568
# 398927       5          263.0  382907.528517  317722.458092        23.961065
# 544800       4          204.0  384804.950980  319619.880556        21.478808
# 483588       3          225.0  387013.022222  321827.951797        22.473743
# 509859       4          216.0  391068.055556  325882.985131        21.703299
#
# [279197 rows x 7 columns]

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence

fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=0)
# Out:
#          support  \
# 509859  0.001105
# 483588  0.001151
# 544800  0.001043
# 398927  0.001345
# 559959  0.001023
# ...          ...
# 461231  0.001197
# 453989  0.001212
# 424027  0.001278
# 466068  0.001186
# 459458  0.001202
#
#                                                                                                                                                                       itemsets  \
# 509859                                                                                                               (AGEP=>=46.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 483588                                                                                                                    (AGEP=[46.0-62.0], WKHP=>=44.0, OCCP=MED-Physicians)
# 544800                                                                                                          (AGEP=[46.0-62.0], WKHP=>=40.0, SEX=Male, OCCP=MED-Physicians)
# 398927                                                                                                  (AGEP=>=35.0, OCCP=MED-Physicians, MAR=Married, WKHP=>=44.0, SEX=Male)
# 559959                                                               (AGEP=[46.0-62.0], SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0, OCCP=MED-Physicians)
# ...                                                                                                                                                                        ...
# 461231  (SCHL=Regular high school diploma, SEX=Female, AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 453989                                           (SCHL=Regular high school diploma, SEX=Female, AGEP=<=34.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0)
# 424027                                     (POBP=California/CA, AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0, RAC1P=White alone, MAR=Never married or under 15 years old, SEX=Male)
# 466068  (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0, MAR=Never married or under 15 years old)
# 459458                                           (SCHL=Regular high school diploma, SEX=Female, AGEP=<=26.0, RELP=Noninstitutionalized group quarters population, WKHP=<=29.0)
#
#         length  support_count        outcome      d_outcome  t_value_outcome
# 509859       4          216.0  391068.055556  325882.985131        21.703299
# 483588       3          225.0  387013.022222  321827.951797        22.473743
# 544800       4          204.0  384804.950980  319619.880556        21.478808
# 398927       5          263.0  382907.528517  317722.458092        23.961065
# 559959       4          200.0  380763.650000  315578.579575        20.590568
# ...        ...            ...            ...            ...              ...
# 461231       6          234.0    3378.376068  -61806.694356       197.322449
# 453989       5          237.0    3371.054852  -61814.015573       198.875479
# 424027       7          250.0    3314.120000  -61870.950425       194.430340
# 466068       6          232.0    3311.810345  -61873.260080       198.741469
# 459458       5          235.0    3305.276596  -61879.793829       200.307841
#
# [540652 rows x 7 columns]

# %%
mean_outcome = FP_fm.loc[FP_fm["itemsets"]==frozenset()]["outcome"][0]

v = mean_outcome*0.1

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
print(v)
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fp_divergence_o.getDivergence(th_redundancy=v)
# Out:
# 6518.507042483994
#          support  \
# 509859  0.001105
# 483588  0.001151
# 544800  0.001043
# 320465  0.001601
# 473447  0.001171
# ...          ...
# 46777   0.006735
# 53698   0.006090
# 516577  0.001094
# 200419  0.002301
# 25216   0.010365
#
#                                                                   itemsets  \
# 509859           (AGEP=>=46.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 483588                (AGEP=[46.0-62.0], WKHP=>=44.0, OCCP=MED-Physicians)
# 544800      (AGEP=[46.0-62.0], WKHP=>=40.0, SEX=Male, OCCP=MED-Physicians)
# 320465           (AGEP=>=35.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 473447                   (AGEP=[46.0-62.0], SEX=Male, OCCP=MED-Physicians)
# ...                                                                    ...
# 46777                                         (AGEP=<=26.0, SCHL=Grade 11)
# 53698                                         (WKHP=<=29.0, SCHL=Grade 11)
# 516577     (OCCP=PRS, RELP=Noninstitutionalized group quarters population)
# 200419     (RELP=Noninstitutionalized group quarters population, OCCP=SAL)
# 25216   (WKHP=<=29.0, RELP=Noninstitutionalized group quarters population)
#
#         length  support_count        outcome      d_outcome  t_value_outcome
# 509859       4          216.0  391068.055556  325882.985131        21.703299
# 483588       3          225.0  387013.022222  321827.951797        22.473743
# 544800       4          204.0  384804.950980  319619.880556        21.478808
# 320465       4          313.0  379176.485623  313991.415198        25.509617
# 473447       3          229.0  371065.851528  305880.781104        21.537511
# ...        ...            ...            ...            ...              ...
# 46777        2         1317.0    7599.658314  -57585.412110       142.904024
# 53698        2         1191.0    7481.200672  -57703.869753        87.367529
# 516577       2          214.0    7446.682243  -57738.388182        56.371489
# 200419       2          450.0    7212.400000  -57972.670425       133.254493
# 25216        2         2027.0    7057.648742  -58127.421683       195.474882
#
# [45041 rows x 7 columns]

# %%
f = fp_divergence_o.getDivergence(th_redundancy=v)

f.loc[f["itemsets"].apply(lambda x: len([i for i in x if "OCCP" in i])>0)].sort_values(metric, ascending = False)
# Out:
#          support  \
# 509859  0.001105
# 483588  0.001151
# 544800  0.001043
# 320465  0.001601
# 473447  0.001171
# ...          ...
# 488930  0.001140
# 256091  0.001907
# 456821  0.001207
# 516577  0.001094
# 200419  0.002301
#
#                                                                                   itemsets  \
# 509859                           (AGEP=>=46.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 483588                                (AGEP=[46.0-62.0], WKHP=>=44.0, OCCP=MED-Physicians)
# 544800                      (AGEP=[46.0-62.0], WKHP=>=40.0, SEX=Male, OCCP=MED-Physicians)
# 320465                           (AGEP=>=35.0, WKHP=>=44.0, SEX=Male, OCCP=MED-Physicians)
# 473447                                   (AGEP=[46.0-62.0], SEX=Male, OCCP=MED-Physicians)
# ...                                                                                    ...
# 488930  (AGEP=<=26.0, OCCP=EAT-Dining Room And Cafeteria Attendants And Bartender Helpers)
# 256091                                                      (AGEP=<=26.0, OCCP=EDU-Tutors)
# 456821  (WKHP=<=29.0, OCCP=EAT-Dining Room And Cafeteria Attendants And Bartender Helpers)
# 516577                     (OCCP=PRS, RELP=Noninstitutionalized group quarters population)
# 200419                     (RELP=Noninstitutionalized group quarters population, OCCP=SAL)
#
#         length  support_count        outcome      d_outcome  t_value_outcome
# 509859       4          216.0  391068.055556  325882.985131        21.703299
# 483588       3          225.0  387013.022222  321827.951797        22.473743
# 544800       4          204.0  384804.950980  319619.880556        21.478808
# 320465       4          313.0  379176.485623  313991.415198        25.509617
# 473447       3          229.0  371065.851528  305880.781104        21.537511
# ...        ...            ...            ...            ...              ...
# 488930       2          223.0    8319.865471  -56865.204954       106.201798
# 256091       2          373.0    8242.439678  -56942.630747        53.350791
# 456821       2          236.0    7756.610169  -57428.460255       123.498221
# 516577       2          214.0    7446.682243  -57738.388182        56.371489
# 200419       2          450.0    7212.400000  -57972.670425       133.254493
#
# [22638 rows x 7 columns]

# %% [markdown]
# #### Top-3

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                                                                itemsets  \
# 459458                               AGEP=<=26.0, RELP=Noninstit. GQs, SCHL=HS, SEX=Female, WKHP=<=29.0
# 466068     AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Noninstit. GQs, SCHL=HS, SEX=Female, WKHP=<=29.0
# 424027  AGEP=<=26.0, MAR=Never married/<15yrs, POBP=CA, RAC=White, SCHL=Grade 11, SEX=Male, WKHP=<=29.0
#
#         sup  Δ_outcome  t_outcome  ratio
# 459458  0.0 -61879.794      200.3  0.051
# 466068  0.0 -61873.260      198.7  0.051
# 424027  0.0 -61870.950      194.4  0.051

# %%
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)
# Out:
#                                                             itemsets  sup  \
# 509859       AGEP=>=46.0, OCCP=MED-Physicians, SEX=Male, WKHP=>=44.0  0.0
# 483588            AGEP=[46.0-62.0], OCCP=MED-Physicians, WKHP=>=44.0  0.0
# 544800  AGEP=[46.0-62.0], OCCP=MED-Physicians, SEX=Male, WKHP=>=40.0  0.0
#
#          Δ_outcome  t_outcome  ratio
# 509859  325882.985       21.7  5.999
# 483588  321827.952       22.5  5.937
# 544800  319619.881       21.5  5.903

# %% [markdown]
# #### Top-3 redundancy

# %%
v = mean_outcome*0.01
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 651.85, 65185.07
#                                                                              itemsets  \
# 531583  AGEP=<=26.0, COW=Empl. for-profit-c, RELP=Noninstit. GQs, SCHL=HS, SEX=Female
# 422782                          RELP=Noninstit. GQs, SCHL=HS, SEX=Female, WKHP=<=29.0
# 77088                                         AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0
#
#         sup  Δ_outcome  t_outcome  ratio
# 531583  0.0 -61745.070      193.1  0.053
# 422782  0.0 -61511.047      193.3  0.056
# 77088   0.0 -61216.650      219.6  0.061

# %%
v = mean_outcome*0.05
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 3259.25, 65185.07
#                                              itemsets  sup  Δ_outcome  \
# 77088         AGEP=<=26.0, SCHL=Grade 11, WKHP=<=29.0  0.0 -61216.650
# 104238  RELP=Son/daughter, SCHL=Grade 11, WKHP=<=29.0  0.0 -61199.323
# 87720   RELP=Son/daughter, SCHL=Grade 11, WKHP=<=39.0  0.0 -60625.418
#
#         t_outcome  ratio
# 77088       219.6  0.061
# 104238      229.6  0.061
# 87720       219.8  0.070

# %%
v = mean_outcome*0.1
print(f"{v:.2f}, {mean_outcome:.2f}")
fpdiv_t = fp_divergence_o.getDivergence(th_redundancy=v).sort_values(fp_divergence_o.metric, ascending = True)

printable_with_ratio(fpdiv_t.head(3), abbreviations)
# Out:
# 6518.51, 65185.07
#                                 itemsets   sup  Δ_outcome  t_outcome  ratio
# 25216   RELP=Noninstit. GQs, WKHP=<=29.0  0.01 -58127.422      195.5  0.108
# 200419     OCCP=SAL, RELP=Noninstit. GQs  0.00 -57972.670      133.3  0.111
# 516577     OCCP=PRS, RELP=Noninstit. GQs  0.00 -57738.388       56.4  0.114

# %%
l = FP_fm.loc[FP_fm["length"]==1].sort_values("d_outcome")
l.loc[l["itemsets"].apply(lambda x: len([i for i in x if "WKHP" in i])>0)].head(20)
# Out:
#       support            itemsets  length  support_count        outcome  \
# 144  0.184622       (WKHP=<=29.0)       1        36104.0   24790.764015
# 40   0.305017       (WKHP=<=39.0)       1        59648.0   32154.421171
# 358  0.120395  (WKHP=[30.0-39.0])       1        23544.0   43446.362980
# 9    0.477193  (WKHP=[40.0-43.0])       1        93318.0   65774.672882
# 1    0.694983       (WKHP=>=40.0)       1       135908.0   79681.731156
# 95   0.217789       (WKHP=>=44.0)       1        42590.0  110153.176661
#
#         d_outcome  t_value_outcome
# 144 -40394.306410       122.486801
# 40  -33030.649254       108.532595
# 358 -21738.707445        46.955137
# 9      589.602457         1.962819
# 1    14496.660732        45.859105
# 95   44968.106236        72.224167

# %% [markdown]
# # Plot

# %%
def get_summary(FP_results, metric, sort_by_value=None, \
                show_weighted_ratio = True,
                type_gens = ["base", "generalized"], th_redundancy = 0, ascending = True, k = 1, \
                abbreviations = abbreviations, key = None, sups = [0.05, 0.025, 0.01]):
    ds = []
    if sort_by_value is None:
        sort_by_value = metric
    for sup in sups:
        for type_gen in type_gens:
            FP_fm = FP_results[type_gen][sup]
            fp_divergence_o=FP_Divergence(FP_fm, metric)
            fpdiv = fp_divergence_o.getDivergence(th_redundancy=th_redundancy)

            if show_weighted_ratio:
                import math
                fpdiv["wlogr"] = fpdiv["support"] * (fpdiv["outcome"]/mean_outcome).apply(lambda x: math.log(x))
                fpdiv["wlogr2"] = fpdiv["support"] * (mean_outcome/fpdiv["outcome"]).apply(lambda x: math.log(x))
            fpdiv = fpdiv.sort_values(sort_by_value, ascending = ascending, key = key)
            d = printable_with_ratio(fpdiv.head(k), abbreviations, show_weighted_ratio = show_weighted_ratio)
            cols = list(d.columns)
            d["min_sup"] = sup        
            d["type"] = type_gen
            ds.append(d[["min_sup", "type"]+cols])

    return pd.concat(ds)

# %%
40.4-33
# Out:
# 7.399999999999999

# %%
asc = get_summary(FP_results, "d_outcome",  th_redundancy = 0, ascending = True, abbreviations = abbreviations)

print("Divergence")
display(asc)


asc = get_summary(FP_results, "d_outcome", sort_by_value="wlogr",  th_redundancy = 0, ascending = True, abbreviations = abbreviations)

print("Weighted log ratio")
display(asc)
# Out:
# Divergence
#        min_sup         type  \
# 528      0.050         base
# 1910     0.050  generalized
# 1276     0.025         base
# 5206     0.025  generalized
# 5265     0.010         base
# 23642    0.010  generalized
#
#                                                                                             itemsets  \
# 528                                                                AGEP=<=26.0, POBP=CA, WKHP=<=29.0
# 1910                                                               AGEP=<=26.0, POBP=CA, WKHP=<=29.0
# 1276   AGEP=<=26.0, COW=Empl. for-profit-c, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 5206   AGEP=<=26.0, COW=Empl. for-profit-c, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 5265                                      MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=29.0
# 23642                        AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=39.0
#
#         sup  Δ_outcome  t_outcome  ratio  wlogr
# 528    0.05 -57257.668      238.9  0.122 -0.108
# 1910   0.05 -57257.668      238.9  0.122 -0.108
# 1276   0.03 -57845.558      243.9  0.113 -0.063
# 5206   0.03 -57845.558      243.9  0.113 -0.063
# 5265   0.01 -58389.608      200.3  0.104 -0.023
# 23642  0.01 -58463.301      203.8  0.103 -0.025
# Weighted log ratio
#     min_sup         type     itemsets   sup  Δ_outcome  t_outcome  ratio  \
# 58    0.050         base  AGEP=<=26.0  0.17 -43902.741      173.8  0.326
# 40    0.050  generalized  WKHP=<=39.0  0.31 -33030.649      108.5  0.493
# 58    0.025         base  AGEP=<=26.0  0.17 -43902.741      173.8  0.326
# 40    0.025  generalized  WKHP=<=39.0  0.31 -33030.649      108.5  0.493
# 58    0.010         base  AGEP=<=26.0  0.17 -43902.741      173.8  0.326
# 40    0.010  generalized  WKHP=<=39.0  0.31 -33030.649      108.5  0.493
#
#     wlogr
# 58 -0.191
# 40 -0.216
# 58 -0.191
# 40 -0.216
# 58 -0.191
# 40 -0.216

# %%
asc = get_summary(FP_results, "d_outcome",  k = 3, th_redundancy = 0, ascending = True, abbreviations = abbreviations)

print("Divergence")
display(asc)


asc = get_summary(FP_results, "d_outcome", k=3, sort_by_value="wlogr",  th_redundancy = 0, ascending = True, abbreviations = abbreviations)

print("Weighted log ratio")
display(asc)
# Out:
# Divergence
#        min_sup         type  \
# 528      0.050         base
# 375      0.050         base
# 524      0.050         base
# 1910     0.050  generalized
# 1301     0.050  generalized
# 1902     0.050  generalized
# 1276     0.025         base
# 1244     0.025         base
# 937      0.025         base
# 5206     0.025  generalized
# 5037     0.025  generalized
# 3680     0.025  generalized
# 5265     0.010         base
# 3137     0.010         base
# 4248     0.010         base
# 23642    0.010  generalized
# 26155    0.010  generalized
# 23265    0.010  generalized
#
#                                                                                             itemsets  \
# 528                                                                AGEP=<=26.0, POBP=CA, WKHP=<=29.0
# 375                                               AGEP=<=26.0, MAR=Never married/<15yrs, WKHP=<=29.0
# 524                                                 AGEP=<=26.0, COW=Empl. for-profit-c, WKHP=<=29.0
# 1910                                                               AGEP=<=26.0, POBP=CA, WKHP=<=29.0
# 1301                                              AGEP=<=26.0, MAR=Never married/<15yrs, WKHP=<=29.0
# 1902                                                AGEP=<=26.0, COW=Empl. for-profit-c, WKHP=<=29.0
# 1276   AGEP=<=26.0, COW=Empl. for-profit-c, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 1244                             AGEP=<=26.0, COW=Empl. for-profit-c, RELP=Son/daughter, WKHP=<=29.0
# 937                            AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 5206   AGEP=<=26.0, COW=Empl. for-profit-c, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 5037                             AGEP=<=26.0, COW=Empl. for-profit-c, RELP=Son/daughter, WKHP=<=29.0
# 3680                           AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 5265                                      MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=29.0
# 3137                                     AGEP=<=26.0, MAR=Never married/<15yrs, SCHL=HS, WKHP=<=29.0
# 4248                            AGEP=<=26.0, MAR=Never married/<15yrs, POBP=CA, SCHL=HS, WKHP=<=29.0
# 23642                        AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=39.0
# 26155                                     MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=29.0
# 23265                                                  AGEP=<=26.0, RELP=Noninstit. GQs, WKHP=<=39.0
#
#         sup  Δ_outcome  t_outcome  ratio  wlogr
# 528    0.05 -57257.668      238.9  0.122 -0.108
# 375    0.06 -57194.944      249.3  0.123 -0.134
# 524    0.05 -57175.789      236.8  0.123 -0.108
# 1910   0.05 -57257.668      238.9  0.122 -0.108
# 1301   0.06 -57194.944      249.3  0.123 -0.134
# 1902   0.05 -57175.789      236.8  0.123 -0.108
# 1276   0.03 -57845.558      243.9  0.113 -0.063
# 1244   0.03 -57830.271      244.6  0.113 -0.064
# 937    0.04 -57789.323      241.1  0.113 -0.077
# 5206   0.03 -57845.558      243.9  0.113 -0.063
# 5037   0.03 -57830.271      244.6  0.113 -0.064
# 3680   0.04 -57789.323      241.1  0.113 -0.077
# 5265   0.01 -58389.608      200.3  0.104 -0.023
# 3137   0.02 -58236.505      174.3  0.107 -0.034
# 4248   0.01 -58140.834      150.2  0.108 -0.027
# 23642  0.01 -58463.301      203.8  0.103 -0.025
# 26155  0.01 -58389.608      200.3  0.104 -0.023
# 23265  0.01 -58353.991      200.1  0.105 -0.025
# Weighted log ratio
#      min_sup         type                               itemsets   sup  \
# 58     0.050         base                            AGEP=<=26.0  0.17
# 75     0.050         base  AGEP=<=26.0, MAR=Never married/<15yrs  0.15
# 51     0.050         base                            WKHP=<=29.0  0.18
# 40     0.050  generalized                            WKHP=<=39.0  0.31
# 285    0.050  generalized               AGEP=<=34.0, WKHP=<=39.0  0.14
# 26     0.050  generalized                            AGEP=<=34.0  0.34
# 58     0.025         base                            AGEP=<=26.0  0.17
# 75     0.025         base  AGEP=<=26.0, MAR=Never married/<15yrs  0.15
# 51     0.025         base                            WKHP=<=29.0  0.18
# 40     0.025  generalized                            WKHP=<=39.0  0.31
# 285    0.025  generalized               AGEP=<=34.0, WKHP=<=39.0  0.14
# 26     0.025  generalized                            AGEP=<=34.0  0.34
# 58     0.010         base                            AGEP=<=26.0  0.17
# 75     0.010         base  AGEP=<=26.0, MAR=Never married/<15yrs  0.15
# 51     0.010         base                            WKHP=<=29.0  0.18
# 40     0.010  generalized                            WKHP=<=39.0  0.31
# 285    0.010  generalized               AGEP=<=34.0, WKHP=<=39.0  0.14
# 26     0.010  generalized                            AGEP=<=34.0  0.34
#
#      Δ_outcome  t_outcome  ratio  wlogr
# 58  -43902.741      173.8  0.326 -0.191
# 75  -44945.122      175.9  0.310 -0.179
# 51  -40394.306      122.5  0.380 -0.178
# 40  -33030.649      108.5  0.493 -0.216
# 285 -49875.873      203.6  0.235 -0.197
# 26  -27957.350      104.3  0.571 -0.193
# 58  -43902.741      173.8  0.326 -0.191
# 75  -44945.122      175.9  0.310 -0.179
# 51  -40394.306      122.5  0.380 -0.178
# 40  -33030.649      108.5  0.493 -0.216
# 285 -49875.873      203.6  0.235 -0.197
# 26  -27957.350      104.3  0.571 -0.193
# 58  -43902.741      173.8  0.326 -0.191
# 75  -44945.122      175.9  0.310 -0.179
# 51  -40394.306      122.5  0.380 -0.178
# 40  -33030.649      108.5  0.493 -0.216
# 285 -49875.873      203.6  0.235 -0.197
# 26  -27957.350      104.3  0.571 -0.193

# %%
mean_income = df_analysis_proc["income"].mean()

v = mean_income*0.05
        
asc_th = get_summary(FP_results, "d_outcome",  th_redundancy = v, ascending = True, abbreviations = abbreviations)

print("Divergence")
display(asc_th)


asc_th = get_summary(FP_results, "d_outcome", sort_by_value="wlogr",  th_redundancy = v, ascending = True, abbreviations = abbreviations)

print("Weighted log ratio")
display(asc_th)
# Out:
# Divergence
#        min_sup         type                          itemsets   sup  \
# 339      0.050         base          AGEP=<=26.0, WKHP=<=29.0  0.07
# 1168     0.050  generalized          AGEP=<=26.0, WKHP=<=29.0  0.07
# 339      0.025         base          AGEP=<=26.0, WKHP=<=29.0  0.07
# 1168     0.025  generalized          AGEP=<=26.0, WKHP=<=29.0  0.07
# 5103     0.010         base  RELP=Noninstit. GQs, WKHP=<=29.0  0.01
# 25212    0.010  generalized  RELP=Noninstit. GQs, WKHP=<=29.0  0.01
#
#        Δ_outcome  t_outcome  ratio  wlogr
# 339   -57018.478      246.6  0.125 -0.140
# 1168  -57018.478      246.6  0.125 -0.140
# 339   -57018.478      246.6  0.125 -0.140
# 1168  -57018.478      246.6  0.125 -0.140
# 5103  -58127.422      195.5  0.108 -0.023
# 25212 -58127.422      195.5  0.108 -0.023
# Weighted log ratio
#     min_sup         type     itemsets   sup  Δ_outcome  t_outcome  ratio  \
# 58    0.050         base  AGEP=<=26.0  0.17 -43902.741      173.8  0.326
# 40    0.050  generalized  WKHP=<=39.0  0.31 -33030.649      108.5  0.493
# 58    0.025         base  AGEP=<=26.0  0.17 -43902.741      173.8  0.326
# 40    0.025  generalized  WKHP=<=39.0  0.31 -33030.649      108.5  0.493
# 58    0.010         base  AGEP=<=26.0  0.17 -43902.741      173.8  0.326
# 40    0.010  generalized  WKHP=<=39.0  0.31 -33030.649      108.5  0.493
#
#     wlogr
# 58 -0.191
# 40 -0.216
# 58 -0.191
# 40 -0.216
# 58 -0.191
# 40 -0.216

# %%
desc = get_summary(FP_results, "d_outcome",  th_redundancy = 0, ascending = False, abbreviations = abbreviations)

print("Divergence")
display(desc)


desc = get_summary(FP_results, "d_outcome", sort_by_value="wlogr",  th_redundancy = 0, ascending = False, abbreviations = abbreviations)

print("Weighted log ratio")
display(desc)
# Out:
# Divergence
#        min_sup         type  \
# 341      0.050         base
# 1858     0.050  generalized
# 1285     0.025         base
# 6602     0.025  generalized
# 4388     0.010         base
# 25541    0.010  generalized
#
#                                                             itemsets   sup  \
# 341                    MAR=Married, RAC=White, SEX=Male, WKHP=>=44.0  0.07
# 1858                                 AGEP=>=35.0, OCCP=MGR, SEX=Male  0.05
# 1285                                       SCHL=Prof beyond bachelor  0.03
# 6602                    AGEP=>=35.0, OCCP=MGR, SEX=Male, WKHP=>=44.0  0.03
# 4388                          SCHL=Prof beyond bachelor, WKHP=>=44.0  0.01
# 25541  AGEP=>=35.0, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=40.0  0.01
#
#         Δ_outcome  t_outcome  ratio  wlogr
# 341     80986.277       62.3  2.242  0.054
# 1858    90204.019       60.6  2.384  0.045
# 1285   105256.743       46.7  2.615  0.028
# 6602   119340.209       50.6  2.831  0.026
# 4388   163479.862       40.3  3.508  0.015
# 25541  172295.970       39.3  3.643  0.013
# Weighted log ratio
#    min_sup         type                  itemsets   sup  Δ_outcome  t_outcome  \
# 4    0.050         base               MAR=Married  0.52  17200.215       46.8
# 7    0.050  generalized  AGEP=>=35.0, WKHP=>=40.0  0.49  26585.978       69.4
# 4    0.025         base               MAR=Married  0.52  17200.215       46.8
# 7    0.025  generalized  AGEP=>=35.0, WKHP=>=40.0  0.49  26585.978       69.4
# 4    0.010         base               MAR=Married  0.52  17200.215       46.8
# 7    0.010  generalized  AGEP=>=35.0, WKHP=>=40.0  0.49  26585.978       69.4
#
#    ratio  wlogr
# 4  1.264  0.123
# 7  1.408  0.166
# 4  1.264  0.123
# 7  1.408  0.166
# 4  1.264  0.123
# 7  1.408  0.166

# %%
desc = get_summary(FP_results, "d_outcome",  k = 3, th_redundancy = 0, ascending = False, abbreviations = abbreviations)

print("Divergence")
display(desc)


desc = get_summary(FP_results, "d_outcome", k = 3, sort_by_value="wlogr",  th_redundancy = 0, ascending = False, abbreviations = abbreviations)

print("Weighted log ratio")
display(desc)
# Out:
# Divergence
#        min_sup         type  \
# 341      0.050         base
# 468      0.050         base
# 450      0.050         base
# 1858     0.050  generalized
# 1567     0.050  generalized
# 1745     0.050  generalized
# 1285     0.025         base
# 1300     0.025         base
# 1425     0.025         base
# 6602     0.025  generalized
# 5850     0.025  generalized
# 6447     0.025  generalized
# 4388     0.010         base
# 4366     0.010         base
# 5235     0.010         base
# 25541    0.010  generalized
# 24251    0.010  generalized
# 21275    0.010  generalized
#
#                                                                    itemsets  \
# 341                           MAR=Married, RAC=White, SEX=Male, WKHP=>=44.0
# 468                     MAR=Married, RELP=Ref person, SEX=Male, WKHP=>=44.0
# 450             COW=Empl. for-profit-c, MAR=Married, RAC=White, WKHP=>=44.0
# 1858                                        AGEP=>=35.0, OCCP=MGR, SEX=Male
# 1567             AGEP=>=35.0, MAR=Married, RAC=White, SEX=Male, WKHP=>=44.0
# 1745                        AGEP=>=35.0, MAR=Married, OCCP=MGR, WKHP=>=40.0
# 1285                                              SCHL=Prof beyond bachelor
# 1300                          COW=Empl. for-profit-c, SCHL=Master, SEX=Male
# 1425                     MAR=Married, RAC=White, SCHL=Bachelor, WKHP=>=44.0
# 6602                           AGEP=>=35.0, OCCP=MGR, SEX=Male, WKHP=>=44.0
# 5850                        AGEP=>=35.0, MAR=Married, OCCP=MGR, WKHP=>=44.0
# 6447   AGEP=>=35.0, COW=Empl. for-profit-c, MAR=Married, OCCP=MGR, SEX=Male
# 4388                                 SCHL=Prof beyond bachelor, WKHP=>=44.0
# 4366                       MAR=Married, SCHL=Prof beyond bachelor, SEX=Male
# 5235                   RELP=Ref person, SCHL=Prof beyond bachelor, SEX=Male
# 25541         AGEP=>=35.0, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=40.0
# 24251         AGEP=>=35.0, MAR=Married, SCHL=Prof beyond bachelor, SEX=Male
# 21275                                SCHL=Prof beyond bachelor, WKHP=>=44.0
#
#         sup   Δ_outcome  t_outcome  ratio  wlogr
# 341    0.07   80986.277       62.3  2.242  0.054
# 468    0.05   79218.083       55.3  2.215  0.044
# 450    0.06   79129.066       56.4  2.214  0.045
# 1858   0.05   90204.019       60.6  2.384  0.045
# 1567   0.06   90159.062       62.0  2.383  0.050
# 1745   0.05   89924.940       64.1  2.380  0.047
# 1285   0.03  105256.743       46.7  2.615  0.028
# 1300   0.03   96155.697       50.1  2.475  0.026
# 1425   0.03   92993.584       46.2  2.427  0.024
# 6602   0.03  119340.209       50.6  2.831  0.026
# 5850   0.03  119179.422       53.3  2.828  0.028
# 6447   0.03  115751.949       50.5  2.776  0.026
# 4388   0.01  163479.862       40.3  3.508  0.015
# 4366   0.01  156512.345       39.1  3.401  0.014
# 5235   0.01  147122.592       34.8  3.257  0.012
# 25541  0.01  172295.970       39.3  3.643  0.013
# 24251  0.01  163780.902       38.3  3.513  0.013
# 21275  0.01  163479.862       40.3  3.508  0.015
# Weighted log ratio
#     min_sup         type                               itemsets   sup  \
# 4     0.050         base                            MAR=Married  0.52
# 20    0.050         base                  MAR=Married, SEX=Male  0.29
# 38    0.050         base                            WKHP=>=44.0  0.22
# 7     0.050  generalized               AGEP=>=35.0, WKHP=>=40.0  0.49
# 18    0.050  generalized               MAR=Married, WKHP=>=40.0  0.40
# 32    0.050  generalized  AGEP=>=35.0, MAR=Married, WKHP=>=40.0  0.33
# 4     0.025         base                            MAR=Married  0.52
# 20    0.025         base                  MAR=Married, SEX=Male  0.29
# 38    0.025         base                            WKHP=>=44.0  0.22
# 7     0.025  generalized               AGEP=>=35.0, WKHP=>=40.0  0.49
# 18    0.025  generalized               MAR=Married, WKHP=>=40.0  0.40
# 32    0.025  generalized  AGEP=>=35.0, MAR=Married, WKHP=>=40.0  0.33
# 4     0.010         base                            MAR=Married  0.52
# 20    0.010         base                  MAR=Married, SEX=Male  0.29
# 38    0.010         base                            WKHP=>=44.0  0.22
# 7     0.010  generalized               AGEP=>=35.0, WKHP=>=40.0  0.49
# 18    0.010  generalized               MAR=Married, WKHP=>=40.0  0.40
# 32    0.010  generalized  AGEP=>=35.0, MAR=Married, WKHP=>=40.0  0.33
#
#     Δ_outcome  t_outcome  ratio  wlogr
# 4   17200.215       46.8  1.264  0.123
# 20  33802.864       65.7  1.519  0.122
# 38  44968.106       72.2  1.690  0.114
# 7   26585.978       69.4  1.408  0.166
# 18  29142.310       69.0  1.447  0.146
# 32  34991.585       73.7  1.537  0.141
# 4   17200.215       46.8  1.264  0.123
# 20  33802.864       65.7  1.519  0.122
# 38  44968.106       72.2  1.690  0.114
# 7   26585.978       69.4  1.408  0.166
# 18  29142.310       69.0  1.447  0.146
# 32  34991.585       73.7  1.537  0.141
# 4   17200.215       46.8  1.264  0.123
# 20  33802.864       65.7  1.519  0.122
# 38  44968.106       72.2  1.690  0.114
# 7   26585.978       69.4  1.408  0.166
# 18  29142.310       69.0  1.447  0.146
# 32  34991.585       73.7  1.537  0.141

# %%
mean_income = df_analysis_proc["income"].mean()

v = mean_income*0.05
        
desc_th = get_summary(FP_results, "d_outcome",  th_redundancy = v, ascending = False, abbreviations = abbreviations)

print("Divergence")
display(desc_th)


desc_th = get_summary(FP_results, "d_outcome", sort_by_value="wlogr",  th_redundancy = v, ascending = False, abbreviations = abbreviations)

print("Weighted log ratio")
display(desc_th)
# Out:
# Divergence
#        min_sup         type  \
# 341      0.050         base
# 1858     0.050  generalized
# 1285     0.025         base
# 6602     0.025  generalized
# 4388     0.010         base
# 25541    0.010  generalized
#
#                                                             itemsets   sup  \
# 341                    MAR=Married, RAC=White, SEX=Male, WKHP=>=44.0  0.07
# 1858                                 AGEP=>=35.0, OCCP=MGR, SEX=Male  0.05
# 1285                                       SCHL=Prof beyond bachelor  0.03
# 6602                    AGEP=>=35.0, OCCP=MGR, SEX=Male, WKHP=>=44.0  0.03
# 4388                          SCHL=Prof beyond bachelor, WKHP=>=44.0  0.01
# 25541  AGEP=>=35.0, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=40.0  0.01
#
#         Δ_outcome  t_outcome  ratio  wlogr
# 341     80986.277       62.3  2.242  0.054
# 1858    90204.019       60.6  2.384  0.045
# 1285   105256.743       46.7  2.615  0.028
# 6602   119340.209       50.6  2.831  0.026
# 4388   163479.862       40.3  3.508  0.015
# 25541  172295.970       39.3  3.643  0.013
# Weighted log ratio
#    min_sup         type                  itemsets   sup  Δ_outcome  t_outcome  \
# 4    0.050         base               MAR=Married  0.52  17200.215       46.8
# 7    0.050  generalized  AGEP=>=35.0, WKHP=>=40.0  0.49  26585.978       69.4
# 4    0.025         base               MAR=Married  0.52  17200.215       46.8
# 7    0.025  generalized  AGEP=>=35.0, WKHP=>=40.0  0.49  26585.978       69.4
# 4    0.010         base               MAR=Married  0.52  17200.215       46.8
# 7    0.010  generalized  AGEP=>=35.0, WKHP=>=40.0  0.49  26585.978       69.4
#
#    ratio  wlogr
# 4  1.264  0.123
# 7  1.408  0.166
# 4  1.264  0.123
# 7  1.408  0.166
# 4  1.264  0.123
# 7  1.408  0.166

# %% [markdown]
# ## Highest divergence  - ITP

# %%
desc = get_summary(FP_results, "d_outcome",  th_redundancy = 0, key = abs,  ascending = False, abbreviations = abbreviations)

print("Divergence")
desc["Δ_outcome"] =  (desc["Δ_outcome"]/1000).round(1).astype(str) + "k"
desc["ratio"] =  desc["ratio"].round(2)

display(desc)
# Out:
# Divergence
#        min_sup         type  \
# 341      0.050         base
# 1858     0.050  generalized
# 1285     0.025         base
# 6602     0.025  generalized
# 4388     0.010         base
# 25541    0.010  generalized
#
#                                                             itemsets   sup  \
# 341                    MAR=Married, RAC=White, SEX=Male, WKHP=>=44.0  0.07
# 1858                                 AGEP=>=35.0, OCCP=MGR, SEX=Male  0.05
# 1285                                       SCHL=Prof beyond bachelor  0.03
# 6602                    AGEP=>=35.0, OCCP=MGR, SEX=Male, WKHP=>=44.0  0.03
# 4388                          SCHL=Prof beyond bachelor, WKHP=>=44.0  0.01
# 25541  AGEP=>=35.0, SCHL=Prof beyond bachelor, SEX=Male, WKHP=>=40.0  0.01
#
#       Δ_outcome  t_outcome  ratio  wlogr
# 341       81.0k       62.3   2.24  0.054
# 1858      90.2k       60.6   2.38  0.045
# 1285     105.3k       46.7   2.62  0.028
# 6602     119.3k       50.6   2.83  0.026
# 4388     163.5k       40.3   3.51  0.015
# 25541    172.3k       39.3   3.64  0.013

# %%
desc = get_summary(FP_results, "d_outcome", sort_by_value="wlogr",  th_redundancy = 0, ascending = False, abbreviations = abbreviations)

print("Weighted log ratio")
desc["Δ_outcome"] =  (desc["Δ_outcome"]/1000).round(1).astype(str) + "k"
display(desc)
# Out:
# Weighted log ratio
#    min_sup         type                  itemsets   sup Δ_outcome  t_outcome  \
# 4    0.050         base               MAR=Married  0.52     17.2k       46.8
# 7    0.050  generalized  AGEP=>=35.0, WKHP=>=40.0  0.49     26.6k       69.4
# 4    0.025         base               MAR=Married  0.52     17.2k       46.8
# 7    0.025  generalized  AGEP=>=35.0, WKHP=>=40.0  0.49     26.6k       69.4
# 4    0.010         base               MAR=Married  0.52     17.2k       46.8
# 7    0.010  generalized  AGEP=>=35.0, WKHP=>=40.0  0.49     26.6k       69.4
#
#    ratio  wlogr
# 4  1.264  0.123
# 7  1.408  0.166
# 4  1.264  0.123
# 7  1.408  0.166
# 4  1.264  0.123
# 7  1.408  0.166

# %% [markdown]
# ## Ascending

# %%
asc = get_summary(FP_results, "d_outcome",  k=1, th_redundancy = 0, ascending = True, abbreviations = abbreviations)

print("Divergence")
asc["Δ_outcome"] =  (asc["Δ_outcome"]/1000).round(1).astype(str) + "k"
display(asc)
# Out:
# Divergence
#        min_sup         type  \
# 528      0.050         base
# 1910     0.050  generalized
# 1276     0.025         base
# 5206     0.025  generalized
# 5265     0.010         base
# 23642    0.010  generalized
#
#                                                                                             itemsets  \
# 528                                                                AGEP=<=26.0, POBP=CA, WKHP=<=29.0
# 1910                                                               AGEP=<=26.0, POBP=CA, WKHP=<=29.0
# 1276   AGEP=<=26.0, COW=Empl. for-profit-c, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 5206   AGEP=<=26.0, COW=Empl. for-profit-c, MAR=Never married/<15yrs, RELP=Son/daughter, WKHP=<=29.0
# 5265                                      MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=29.0
# 23642                        AGEP=<=26.0, MAR=Never married/<15yrs, RELP=Noninstit. GQs, WKHP=<=39.0
#
#         sup Δ_outcome  t_outcome  ratio  wlogr
# 528    0.05    -57.3k      238.9  0.122 -0.108
# 1910   0.05    -57.3k      238.9  0.122 -0.108
# 1276   0.03    -57.8k      243.9  0.113 -0.063
# 5206   0.03    -57.8k      243.9  0.113 -0.063
# 5265   0.01    -58.4k      200.3  0.104 -0.023
# 23642  0.01    -58.5k      203.8  0.103 -0.025

# %%
asc = get_summary(FP_results, "d_outcome", sort_by_value="wlogr",  th_redundancy = 0, ascending = True, abbreviations = abbreviations)

print("Weighted log ratio")
asc["Δ_outcome"] =  (asc["Δ_outcome"]/1000).round(1).astype(str) + "k"
display(asc)
# Out:
# Weighted log ratio
#     min_sup         type     itemsets   sup Δ_outcome  t_outcome  ratio  wlogr
# 58    0.050         base  AGEP=<=26.0  0.17    -43.9k      173.8  0.326 -0.191
# 40    0.050  generalized  WKHP=<=39.0  0.31    -33.0k      108.5  0.493 -0.216
# 58    0.025         base  AGEP=<=26.0  0.17    -43.9k      173.8  0.326 -0.191
# 40    0.025  generalized  WKHP=<=39.0  0.31    -33.0k      108.5  0.493 -0.216
# 58    0.010         base  AGEP=<=26.0  0.17    -43.9k      173.8  0.326 -0.191
# 40    0.010  generalized  WKHP=<=39.0  0.31    -33.0k      108.5  0.493 -0.216

# %% [markdown]
# ## Highest wlogr2

# %%
desc = get_summary(FP_results, "d_outcome", sort_by_value="wlogr", sups = [0.01], k = 3, key = abs, th_redundancy = 0, ascending = False, abbreviations = abbreviations)
display(desc)
print("Weighted log ratio")
desc["Δ_outcome"] =  (desc["Δ_outcome"]/1000).round(1).astype(str) + "k"
display(desc)
# Out:
#        support  \
# 4388  0.011654
# 4366  0.011695
# 5235  0.010151
# 4651  0.011127
# 4472  0.011460
#
#                                                                                                                                                              itemsets  \
# 4388                                                                                               (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 4366                                                                                     (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 5235                                                                           (SCHL=Professional degree beyond a bachelor's degree, RELP=Reference person, SEX=Male)
# 4651  (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, SCHL=Master's degree, WKHP=>=44.0, SEX=Male)
# 4472                                                                               (RAC1P=White alone, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
#
#       length  support_count        outcome      d_outcome  t_value_outcome  \
# 4388       2         2279.0  228664.931988  163479.861563        40.290922
# 4366       3         2287.0  221697.415829  156512.345404        39.083566
# 5235       3         1985.0  212307.662469  147122.592044        34.782031
# 4651       4         2176.0  209515.284926  144330.214502        39.830737
# 4472       3         2241.0  208800.406069  143615.335644        36.158773
#
#          wlogr    wlogr2
# 4388  0.014626 -0.014626
# 4366  0.014315 -0.014315
# 5235  0.011986 -0.011986
# 4651  0.012992 -0.012992
# 4472  0.013341 -0.013341
#       support                                                itemsets  length  \
# 58   0.170227                                           (AGEP=<=26.0)       1
# 75   0.152897  (AGEP=<=26.0, MAR=Never married or under 15 years old)       2
# 51   0.184622                                           (WKHP=<=29.0)       1
# 11   0.349670               (MAR=Never married or under 15 years old)       1
# 201  0.089739  (WKHP=<=29.0, MAR=Never married or under 15 years old)       2
#
#      support_count       outcome     d_outcome  t_value_outcome     wlogr  \
# 58         33289.0  21282.329118 -43902.741307       173.810730 -0.190545
# 75         29900.0  20239.948629 -44945.121796       175.870942 -0.178825
# 51         36104.0  24790.764015 -40394.306410       122.486801 -0.178485
# 11         68380.0  39469.039544 -25716.030881        91.255149 -0.175434
# 201        17549.0  11808.095846 -53376.974579       206.363504 -0.153314
#
#        wlogr2
# 58   0.190545
# 75   0.178825
# 51   0.178485
# 11   0.175434
# 201  0.153314
#                                  itemsets   sup  Δ_outcome  t_outcome  ratio  \
# 58                            AGEP=<=26.0  0.17 -43902.741      173.8  0.326
# 75  AGEP=<=26.0, MAR=Never married/<15yrs  0.15 -44945.122      175.9  0.310
# 51                            WKHP=<=29.0  0.18 -40394.306      122.5  0.380
#
#     wlogr
# 58 -0.191
# 75 -0.179
# 51 -0.178
#         support  \
# 25541  0.010268
# 24251  0.010652
# 21275  0.011654
# 26256  0.010094
# 21164  0.011695
#
#                                                                                         itemsets  \
# 25541  (WKHP=>=40.0, SCHL=Professional degree beyond a bachelor's degree, AGEP=>=35.0, SEX=Male)
# 24251  (MAR=Married, AGEP=>=35.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21275                         (SCHL=Professional degree beyond a bachelor's degree, WKHP=>=44.0)
# 26256               (AGEP=>=46.0, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
# 21164               (MAR=Married, SCHL=Professional degree beyond a bachelor's degree, SEX=Male)
#
#        length  support_count        outcome      d_outcome  t_value_outcome  \
# 25541       4         2008.0  237481.040837  172295.970412        39.344466
# 24251       4         2083.0  228965.972156  163780.901731        38.327022
# 21275       2         2279.0  228664.931988  163479.861563        40.290922
# 26256       3         1974.0  221792.608916  156607.538491        35.238657
# 21164       3         2287.0  221697.415829  156512.345404        39.083566
#
#           wlogr    wlogr2
# 25541  0.013275 -0.013275
# 24251  0.013382 -0.013382
# 21275  0.014626 -0.014626
# 26256  0.012361 -0.012361
# 21164  0.014315 -0.014315
#       support                                                itemsets  length  \
# 40   0.305017                                           (WKHP=<=39.0)       1
# 285  0.135935                              (WKHP=<=39.0, AGEP=<=34.0)       2
# 26   0.344602                                           (AGEP=<=34.0)       1
# 174  0.170227                                           (AGEP=<=26.0)       1
# 72   0.245613  (MAR=Never married or under 15 years old, AGEP=<=34.0)       2
#
#      support_count       outcome     d_outcome  t_value_outcome     wlogr  \
# 40         59648.0  32154.421171 -33030.649254       108.532595 -0.215550
# 285        26583.0  15309.197382 -49875.873043       203.613355 -0.196940
# 26         67389.0  37227.720756 -27957.349669       104.272437 -0.193038
# 174        33289.0  21282.329118 -43902.741307       173.810730 -0.190545
# 72         48031.0  30080.525994 -35104.544431       133.219640 -0.189945
#
#        wlogr2
# 40   0.215550
# 285  0.196940
# 26   0.193038
# 174  0.190545
# 72   0.189945
#                      itemsets   sup  Δ_outcome  t_outcome  ratio  wlogr
# 40                WKHP=<=39.0  0.31 -33030.649      108.5  0.493 -0.216
# 285  AGEP=<=34.0, WKHP=<=39.0  0.14 -49875.873      203.6  0.235 -0.197
# 26                AGEP=<=34.0  0.34 -27957.350      104.3  0.571 -0.193
#      min_sup         type                               itemsets   sup  \
# 58      0.01         base                            AGEP=<=26.0  0.17
# 75      0.01         base  AGEP=<=26.0, MAR=Never married/<15yrs  0.15
# 51      0.01         base                            WKHP=<=29.0  0.18
# 40      0.01  generalized                            WKHP=<=39.0  0.31
# 285     0.01  generalized               AGEP=<=34.0, WKHP=<=39.0  0.14
# 26      0.01  generalized                            AGEP=<=34.0  0.34
#
#      Δ_outcome  t_outcome  ratio  wlogr
# 58  -43902.741      173.8  0.326 -0.191
# 75  -44945.122      175.9  0.310 -0.179
# 51  -40394.306      122.5  0.380 -0.178
# 40  -33030.649      108.5  0.493 -0.216
# 285 -49875.873      203.6  0.235 -0.197
# 26  -27957.350      104.3  0.571 -0.193
# Weighted log ratio
#      min_sup         type                               itemsets   sup  \
# 58      0.01         base                            AGEP=<=26.0  0.17
# 75      0.01         base  AGEP=<=26.0, MAR=Never married/<15yrs  0.15
# 51      0.01         base                            WKHP=<=29.0  0.18
# 40      0.01  generalized                            WKHP=<=39.0  0.31
# 285     0.01  generalized               AGEP=<=34.0, WKHP=<=39.0  0.14
# 26      0.01  generalized                            AGEP=<=34.0  0.34
#
#     Δ_outcome  t_outcome  ratio  wlogr
# 58     -43.9k      173.8  0.326 -0.191
# 75     -44.9k      175.9  0.310 -0.179
# 51     -40.4k      122.5  0.380 -0.178
# 40     -33.0k      108.5  0.493 -0.216
# 285    -49.9k      203.6  0.235 -0.197
# 26     -28.0k      104.3  0.571 -0.193

# %% [markdown]
# ## Highest wlogr

# %%
desc = get_summary(FP_results, "d_outcome", sort_by_value="wlogr", sups = [0.01], k = 3, key = abs, th_redundancy = 0, ascending = False, abbreviations = abbreviations)

print("Weighted log ratio")
desc["Δ_outcome"] =  (desc["Δ_outcome"]/1000).round(1).astype(str) + "k"
display(desc)

# %% [markdown]
# # Tree divergence - income - combined

# %%
FP_results["generalized"][0.05].sort_values(by = "d_outcome", key=abs, ascending = True)
# Out:
#        support  \
# 0     1.000000
# 379   0.117358
# 231   0.148996
# 495   0.104241
# 135   0.188493
# ...        ...
# 1767  0.053729
# 1950  0.050983
# 1745  0.054296
# 1567  0.057298
# 1858  0.052082
#
#                                                                                                                                                       itemsets  \
# 0                                                                                                                                                           ()
# 379                                                                                                           (WKHP=[40.0-43.0], POBP=California/CA, SEX=Male)
# 231                                                                                                  (WKHP=[40.0-43.0], RAC1P=White alone, POBP=California/CA)
# 495   (COW=Employee of a private for-profit company or business, or of an individual, for wages, salary, or commissions, AGEP=>=35.0, SEX=Female, MAR=Married)
# 135                                                                                                                     (AGEP=>=35.0, SEX=Female, MAR=Married)
# ...                                                                                                                                                        ...
# 1767                                                                                                         (AGEP=>=46.0, MAR=Married, WKHP=>=44.0, SEX=Male)
# 1950                                                                                                   (AGEP=>=46.0, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1745                                                                                                         (WKHP=>=40.0, AGEP=>=35.0, OCCP=MGR, MAR=Married)
# 1567                                                                                      (AGEP=>=35.0, MAR=Married, RAC1P=White alone, WKHP=>=44.0, SEX=Male)
# 1858                                                                                                                         (OCCP=MGR, AGEP=>=35.0, SEX=Male)
#
#       length  support_count        outcome     d_outcome  t_value_outcome
# 0          0       195556.0   65185.070425      0.000000         0.000000
# 379        3        22950.0   65150.460741    -34.609684         0.069512
# 231        3        29137.0   65113.524179    -71.546246         0.162939
# 495        4        20385.0   65259.402011     74.331586         0.123213
# 135        3        36861.0   65104.250292    -80.820133         0.179588
# ...      ...            ...            ...           ...              ...
# 1767       4        10507.0  150511.681165  85326.610740        56.369136
# 1950       4         9970.0  152503.482849  87318.412424        56.646643
# 1745       4        10618.0  155110.010360  89924.939935        64.128105
# 1567       5        11205.0  155344.132441  90159.062016        62.025598
# 1858       3        10185.0  155389.089838  90204.019413        60.614209
#
# [2012 rows x 7 columns]

# %%
aaaa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-272-7bae8076a577> in <module>
# ----> 1 aaaa
#
# NameError: name 'aaaa' is not defined

# %% [markdown]
# ## Tree

# %%
df_analysis_proc.head()

# %%
generalization_dict_all.keys()

# %%
continuous_attributes = ['AGEP', 'WKHP']

# %%
min_support = 0.1

# %%
metric = "d_outcome"

target = "income"

# %%
minimal_gain = 0

# %%
from tree_discretization_ranking import TreeDiscretization_ranking

tree_discr = TreeDiscretization_ranking()


type_experiment = "all_attributes"

type_criterion = "weighted_sum_abs_reference_s"


generalization_dict, discretizations = tree_discr.get_tree_discretization(
    df_analysis_proc,
    type_splitting=type_experiment,
    min_support=0.1,
    metric=metric,
    #class_map=class_map,
    continuous_attributes= list(continuous_attributes),
    #class_and_pred_names=cols_c,
    storeTree=True,
    type_criterion = type_criterion,
    minimal_gain = minimal_gain,
    target_col = target
)
tree_discr.printDiscretizationTrees()

tree_discr.trees.visualizeTreeDiGraph()

# %%
tree_discr.trees.visualizeTreeDiGraph(all_info = False)

# %%
tree_discr.get_number_nodes()

# %% [markdown]
# ## min_sup_divergence  = 0.1

# %%
df_analysis["income"].describe()["mean"]

# %%
allow_overalp = (
    True if type_experiment == "all_attributes" else False
)
allow_overalp

# %% [markdown]
# ### With Generalization

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

FP_fm_True = extract_divergence_generalized(
    df_analysis,
    discretizations,
    generalization_dict,
    continuous_attributes,
    min_sup_divergence=0.1,
    apply_generalization=True,
    #true_class_name=pred_name,
    #predicted_class_name=class_name,
    target_name = target,
    #class_map=class_map,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    allow_overalp = False if type_experiment!="all_attributes" else True
)

# %%
len(FP_fm_True)

# %%
FP_fm_True.sort_values(metric, ascending = False).head()

# %%
len(FP_fm_True)

# %% [markdown]
# ## min_sup_divergence  = 0.05

# %%
df_analysis["income"].describe()["mean"]

# %%
allow_overalp = (
    True if type_experiment == "all_attributes" else False
)
allow_overalp

# %% [markdown]
# ### With Generalization

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

FP_fm_True = extract_divergence_generalized(
    df_analysis,
    discretizations,
    generalization_dict,
    continuous_attributes,
    min_sup_divergence=0.05,
    apply_generalization=True,
    target_name = target,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    allow_overalp = False if type_experiment!="all_attributes" else True
)

# %%
FP_fm_True.sort_values(metric, ascending = False).head()

# %%
len(FP_fm_True)

# %% [markdown]
# # Quantile

# %%
def check_ranges_validity(dfI_discr_quantile, bins, continuous_attributes):
    for cont_attr in continuous_attributes:
        print(
            cont_attr,
            len(dfI_discr_quantile[cont_attr].value_counts()),
            dict(dfI_discr_quantile[cont_attr].value_counts()),
            sum(dfI_discr_quantile[cont_attr].value_counts().values),
        )
        if len(dfI_discr_quantile[cont_attr].value_counts()) != bins:
            print(dict(dfI_discr_quantile[cont_attr].value_counts()))
            raise ValueError

# %%
attrs_discretize = [a for a in df_analysis_proc.columns if a not in [target]]

# %%
from import_datasets import discretize

bins = 5


dfI_discr_quantile = discretize(
    df_analysis_proc,  bins=bins, strategy="quantile", adaptive=True, attributes=attrs_discretize
)

check_ranges_validity(dfI_discr_quantile, bins, continuous_attributes)

# %%
# ### Extract divergence

from divexplorer_generalized_ranking.FP_DivergenceExplorer import FP_DivergenceExplorer_ranking
    
fp_diver = FP_DivergenceExplorer_ranking(
    dfI_discr_quantile,
    target_name=target
)

FP_fm = fp_diver.getFrequentPatternDivergence(
                min_support=0.01, metrics=["d_outcome"]
            )

FP_fm.sort_values("d_outcome", ascending = False).head()

# %%
from divexplorer_generalized_ranking.FP_Divergence import FP_Divergence
fp_divergence_o=FP_Divergence(FP_fm, "d_outcome")
fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = True)
display(printable_with_ratio(fpdiv.head(3), abbreviations))

fpdiv = fp_divergence_o.getDivergence(th_redundancy=0).sort_values(fp_divergence_o.metric, ascending = False)
printable_with_ratio(fpdiv.head(3), abbreviations)

# %% [markdown]
# # Exp

# %%
import pandas as pd
import os
filename = os.path.join(os.path.curdir, "datasets", "ACSPUMS", "PUMS_Data_Dictionary_2018.csv")

# %%
df_mappings = pd.read_csv(filename)

# %%
remapping_cols = {}

# %%
len(df_mappings.loc["VAL"].loc[col_name][cols_i])

# %%
orig_col = "1"
new_col = "Record Type"
cols_i = [orig_col, new_col]


not_conv = []
#col_name = "OCCP"
for col_name in acs_data.columns:
    c = False
    if len(df_mappings.loc["VAL"].loc[col_name])>0:
        if type(acs_data[col_name].values[0])!=str:            
            if (len(df_mappings.loc["VAL"].loc[[col_name]]))>1:
                dict_i = df_mappings.loc["VAL"].loc[col_name][cols_i].set_index(orig_col).to_dict()[new_col]
                dict_i = {float(k) if (k not in ["b", "bb", 'bbb', 'bbbb', "bbbbb", "bbbbbb", "bbbbbbb"]) else -1 :v for k,v in dict_i.items()}
                remapping_cols[col_name] = dict_i
                c = True
    if c == False:
        not_conv.append((col_name, len(df_mappings.loc["VAL"].loc[col_name][cols_i])))

# %%
from copy import deepcopy

acs_data_renamed = deepcopy(acs_data)

for column_name in remapping_cols:
    acs_data_renamed[column_name] = acs_data[column_name].replace(remapping_cols[column_name])

# %%
v, i = 10, 0
for i in range(20,30):
    cols = acs_data_renamed.columns[(i*v):(i*v)+v]
    display(acs_data_renamed[cols].head(7))

# %%
remapping_cols["OCCP"]

# %%
attr = "OCCP"
{x: x.split("-")[0] for x in acs_data_renamed[attr].values if "-" in x}

# %%
acs_data_renamed["JWTR"].value_counts()#.sum()/len(acs_data_renamed)

acs_data_renamed["JWTR"].value_counts()/len(acs_data_renamed)

# %%
FP_fm_s = deepcopy(FP_fm)

# %%
mean_outcome = FP_fm_s.loc[0]["outcome"]
FP_fm_s["ratio"] = FP_fm_s["outcome"] / mean_outcome
import math
FP_fm_s["wlogr"] = FP_fm_s["support"] * (FP_fm_s["ratio"]).apply(lambda x: math.log(x))

# %%
FP_fm_s.sort_values("wlogr", ascending = False)

# %%
import math


b = FP_results["base"][0.05]
g = FP_results["generalized"][0.05]


mean_outcome = b.loc[0]["outcome"]

fp_i = FP_Divergence(b, "d_outcome")
b = fp_i.getDivergence(th_redundancy=0)
b["ratio"] = b["outcome"] / mean_outcome
b["wlogr"] = b["support"] * (b["ratio"]).apply(lambda x: math.log(x))

fp_i = FP_Divergence(g, "d_outcome")
g = fp_i.getDivergence(th_redundancy=0)
g["ratio"] = g["outcome"] / mean_outcome
g["wlogr"] = g["support"] * (g["ratio"]).apply(lambda x: math.log(x))

display(b[["ratio", "wlogr"]].describe())
display(g[["ratio", "wlogr"]].describe())

# %%
import math


b = FP_results["base"][0.01]
g = FP_results["generalized"][0.01]


mean_outcome = b.loc[0]["outcome"]

fp_i = FP_Divergence(b, "d_outcome")
b = fp_i.getDivergence(th_redundancy=0)
b["ratio"] = b["outcome"] / mean_outcome
b["wlogr"] = b["support"] * (b["ratio"]).apply(lambda x: math.log(x))

fp_i = FP_Divergence(g, "d_outcome")
g = fp_i.getDivergence(th_redundancy=0)
g["ratio"] = g["outcome"] / mean_outcome
g["wlogr"] = g["support"] * (g["ratio"]).apply(lambda x: math.log(x))

display(b[["ratio", "wlogr"]].describe())
display(g[["ratio", "wlogr"]].describe())

# %%
# df_analysis["OCCP-hier"] = df_analysis["OCCP"].str.split("-").apply(lambda x: x[0])

# %%
from utils_extract_divergence_generalized_ranking import (
    extract_divergence_generalized,
)

apply_generalization = True

pattern_type = "generalized" if apply_generalization else "base"
min_sup_divergence = 0.01 
import time
s = time.time()
FP_results[pattern_type][min_sup_divergence] = extract_divergence_generalized(
    df_analysis_proc,
    discretizations,
    generalization_dict_all,
    continuous_attributes,
    min_sup_divergence=min_sup_divergence,
    apply_generalization=apply_generalization,
    #true_class_name=pred_name,
    #predicted_class_name=class_name,
    target_name = target,
    #class_map=class_map,
    FPM_type="fpgrowth",
    metrics_divergence = ["d_outcome"],
    type_experiment = type_experiment,
    allow_overalp = False if type_experiment!="all_attributes" else True
)
e = time.time()
# Out:
# 1 10000
# 2 20000

# %%
e-s
# Out:
# 43.469666957855225

# %%
22.5+14
# Out:
# 36.5

# %%
from utils_discretize_df import (
    discretize_df_via_discretizations,
)

df_discreted_d = discretize_df_via_discretizations(
    df_analysis_proc,
    discretizations,
    allow_overalp = False
)

# %%
from divexplorer_generalized_ranking.FP_DivergenceExplorer import (
        FP_DivergenceExplorer_ranking,
    )

s = time.time()
fp_diver = FP_DivergenceExplorer_ranking(
    df_discreted_d,
    true_class_name=None,
    predicted_class_name=None,
    target_name=target,
    class_map={"N": 0, "P": 1},
    generalizations_obj=None,
    preserve_interval=None,
    already_in_one_hot_encoding=False,
)

FP_fm_input = fp_diver.getFrequentPatternDivergence(
    min_support=min_sup_divergence,
    metrics = ["d_outcome"],
    FPM_type="fpgrowth"
)
e = time.time()

# %%
e-s
# Out:
# 15.331115961074829
